# %%
import pandas as pd

# %%
df= pd.read_csv('CovidColombia.csv')

# %%
df.shape
# Out:
# (120281, 21)

# %%
df.columns
# Out:
# Index(['ID de caso', 'Fecha de notificación', 'Código DIVIPOLA',
#        'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
#        'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'FIS',
#        'Fecha de muerte', 'Fecha diagnostico', 'Fecha recuperado',
#        'fecha reporte web', 'Tipo recuperación', 'Codigo departamento',
#        'Codigo pais', 'Pertenencia etnica', 'Nombre grupo etnico'],
#       dtype='object')

# %%
eje = {'Caldas','Quindio', 'Risaralda'}
filtro_eje = df['Departamento o Distrito '].isin(eje)
df_eje = df.loc[filtro_eje, ['Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
       'Sexo', 'Tipo', 'Estado','Fecha de notificación','Fecha diagnostico', 'Fecha recuperado','Fecha de muerte']]

# %%
df_eje
# Out:
#        Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 27            Dosquebradas                Risaralda  Recuperado    22    M
# 30               Manizales                   Caldas  Recuperado    65    M
# 85                 Pereira                Risaralda  Recuperado    29    M
# 99                 Pereira                Risaralda  Recuperado    21    M
# 100           Dosquebradas                Risaralda  Recuperado    18    M
# ...                    ...                      ...         ...   ...  ...
# 118193            Riosucio                   Caldas        Casa    40    M
# 118363             Pereira                Risaralda        Casa    25    M
# 118364             Pereira                Risaralda        Casa    68    M
# 118365        Dosquebradas                Risaralda        Casa    26    M
# 118366        Dosquebradas                Risaralda        Casa    27    F
#
# ...

# %%
eje = {'Manizales'}
filtro_eje = df['Ciudad de ubicación'].isin(eje)
#filtro_eje = df['Ciudad de ubicación'].str.contains('Manizales', na=False)
df_eje_ciudad = df.loc[filtro_eje, ['Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
       'Sexo', 'Tipo', 'Estado','Fecha de notificación','Fecha diagnostico', 'Fecha recuperado','Fecha de muerte']]

# %%
df_eje_ciudad
# Out:
#        Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 30               Manizales                   Caldas  Recuperado    65    M
# 180              Manizales                   Caldas  Recuperado    22    F
# 371              Manizales                   Caldas  Recuperado    70    M
# 452              Manizales                   Caldas  Recuperado    26    F
# 538              Manizales                   Caldas  Recuperado    81    M
# ...                    ...                      ...         ...   ...  ...
# 103854           Manizales                   Caldas        Casa    47    F
# 111007           Manizales                   Caldas        Casa    24    M
# 111008           Manizales                   Caldas        Casa    24    M
# 111848           Manizales                   Caldas        Casa    75    F
# 111849           Manizales                   Caldas        Casa    77    F
#
# ...

# %%
#eje = {'Manizales'}
#filtro_eje = df['Ciudad de ubicación'].isin(eje)
filtro_eje = df['Ciudad de ubicación'].str.contains('Manizales')
df_eje_ciudad = df.loc[filtro_eje, ['Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
       'Sexo', 'Tipo', 'Estado','Fecha de notificación','Fecha diagnostico', 'Fecha recuperado','Fecha de muerte']]

# %%
df_eje_ciudad
# Out:
#        Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 30               Manizales                   Caldas  Recuperado    65    M
# 180              Manizales                   Caldas  Recuperado    22    F
# 371              Manizales                   Caldas  Recuperado    70    M
# 452              Manizales                   Caldas  Recuperado    26    F
# 538              Manizales                   Caldas  Recuperado    81    M
# ...                    ...                      ...         ...   ...  ...
# 103854           Manizales                   Caldas        Casa    47    F
# 111007           Manizales                   Caldas        Casa    24    M
# 111008           Manizales                   Caldas        Casa    24    M
# 111848           Manizales                   Caldas        Casa    75    F
# 111849           Manizales                   Caldas        Casa    77    F
#
# ...

# %%
df_eje_ciudad.drop(columns=['Fecha diagnostico', 'Fecha recuperado'], inplace=True)

# %%
df_eje_ciudad
# Out:
#        Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 30               Manizales                   Caldas  Recuperado    65    M
# 180              Manizales                   Caldas  Recuperado    22    F
# 371              Manizales                   Caldas  Recuperado    70    M
# 452              Manizales                   Caldas  Recuperado    26    F
# 538              Manizales                   Caldas  Recuperado    81    M
# ...                    ...                      ...         ...   ...  ...
# 103854           Manizales                   Caldas        Casa    47    F
# 111007           Manizales                   Caldas        Casa    24    M
# 111008           Manizales                   Caldas        Casa    24    M
# 111848           Manizales                   Caldas        Casa    75    F
# 111849           Manizales                   Caldas        Casa    77    F
#
#               Tipo Estado    Fecha de notificación Fecha de muerte
# ...

# %%
df_eje_ciudad[['Fecha', 'Hora']] = df_eje_ciudad['Fecha de notificación'].str.split('T', expand=True)

# %%
df_eje_ciudad.sort_values(by=['Edad', 'Fecha de notificación'])
# Out:
#       Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 14250           Manizales                   Caldas  Recuperado    10    M
# 14247           Manizales                   Caldas  Recuperado    14    F
# 33205           Manizales                   Caldas  Recuperado    14    F
# 1818            Manizales                   Caldas  Recuperado    18    F
# 69686           Manizales                   Caldas        Casa    19    F
# ...                   ...                      ...         ...   ...  ...
# 31446           Manizales                   Caldas  Recuperado    85    F
# 65896           Manizales                   Caldas        Casa    85    F
# 17103           Manizales                   Caldas  Recuperado    88    F
# 69685           Manizales                   Caldas        Casa    90    F
# 81598           Manizales                   Caldas    Hospital    90    F
#
#               Tipo        Estado    Fecha de notificación Fecha de muerte  \
# ...

# %%
df_eje_ciudad['Edad'].median()
# Out:
# 44.0

# %%
df_eje_ciudad['Edad'].count()
# Out:
# 141

# %%
df_eje_ciudad['Edad'].value_counts(normalize=True).sort_values(ascending=False)
# Out:
# 34    0.049645
# 26    0.042553
# 49    0.035461
# 35    0.035461
# 29    0.035461
#         ...
# 48    0.007092
# 78    0.007092
# 76    0.007092
# 79    0.007092
# 10    0.007092
# Name: Edad, Length: 61, dtype: float64

# %%
mun_group = df.groupby(['Departamento o Distrito '])

# %%
mun_group.get_group('Caldas')
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 30              31  2020-03-12T00:00:00.000            17001
# 122            123  2020-03-17T00:00:00.000            17877
# 180            181  2020-03-18T00:00:00.000            17001
# 217            218  2020-03-19T00:00:00.000            17380
# 218            219  2020-03-19T00:00:00.000            17174
# ...            ...                      ...              ...
# 111008      111049  2020-06-29T00:00:00.000            17001
# 111848      111889  2020-06-26T00:00:00.000            17001
# 111849      111890  2020-06-26T00:00:00.000            17001
# 118192      118233  2020-06-30T00:00:00.000            17042
# 118193      118234  2020-06-30T00:00:00.000            17614
#
#        Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 30               Manizales                   Caldas  Recuperado    65    M
# 122                Viterbo                   Caldas  Recuperado    38    F
# ...

# %%
mun_group['Edad'].value_counts().loc('atención')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-bda68092fc8b> in <module>
# ----> 1 mun_group['Edad'].value_counts().loc('atención')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     576
#     577         if axis is not None:
# --> 578             axis = self.obj._get_axis_number(axis)
#     579         new_self.axis = axis
#     580         return new_self
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named atención for object type <class 'pandas.core.series.Series'>

# %%
df
# Out:
#                      ID de caso    Fecha de notificación  Código DIVIPOLA  \
# Ciudad de ubicación
# Bogotá D.C.                   1  2020-03-02T00:00:00.000            11001
# Guadalajara de Buga           2  2020-03-06T00:00:00.000            76111
# Medellín                      3  2020-03-07T00:00:00.000             5001
# Medellín                      4  2020-03-09T00:00:00.000             5001
# Medellín                      5  2020-03-09T00:00:00.000             5001
# ...                         ...                      ...              ...
# Leticia                  120317  2020-06-12T00:00:00.000            91001
# Leticia                  120318  2020-06-19T00:00:00.000            91001
# Leticia                  120319  2020-06-19T00:00:00.000            91001
# Leticia                  120320  2020-06-19T00:00:00.000            91001
# Leticia                  120321  2020-06-01T00:00:00.000            91001
#
# ...

# %%
mun_group = df.groupby(['Departamento o Distrito '])

# %%
mun_group.get_group('Caldas')
# Out:
#                      ID de caso    Fecha de notificación  Código DIVIPOLA  \
# Ciudad de ubicación
# Manizales                    31  2020-03-12T00:00:00.000            17001
# Viterbo                     123  2020-03-17T00:00:00.000            17877
# Manizales                   181  2020-03-18T00:00:00.000            17001
# La Dorada                   218  2020-03-19T00:00:00.000            17380
# Chinchiná                   219  2020-03-19T00:00:00.000            17174
# ...                         ...                      ...              ...
# Manizales                111049  2020-06-29T00:00:00.000            17001
# Manizales                111889  2020-06-26T00:00:00.000            17001
# Manizales                111890  2020-06-26T00:00:00.000            17001
# Anserma                  118233  2020-06-30T00:00:00.000            17042
# Riosucio                 118234  2020-06-30T00:00:00.000            17614
#
# ...

# %%
Fallecidos = mun_group['Estado'].apply(lambda x:x.str.contains('Fallecido')).sum()

# %%
casos = df['Ciudad de ubicación'].value_counts()

# %%
df_resultado = pd.concat([casos, Fallecidos], axis= 'columns', sort=False)

# %%
df_resultado
