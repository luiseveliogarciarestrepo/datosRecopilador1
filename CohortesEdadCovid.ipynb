# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('CovidColombia.csv', usecols=['Fecha de notificación',
       'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad', 'Estado','Fecha de muerte'],parse_dates=['Fecha de notificación','Fecha de muerte'], low_memory=False)

# %%
df.dtypes
# Out:
# Fecha de notificación       datetime64[ns]
# Ciudad de ubicación                 object
# Departamento o Distrito             object
# atención                            object
# Edad                                 int64
# Estado                              object
# Fecha de muerte                     object
# dtype: object

# %%
df.sort_values(by='Edad', axis = 0, ascending= False, ignore_index=True, inplace=True)
df.head(50)
# Out:
#    Fecha de notificación    Ciudad de ubicación Departamento o Distrito   \
# 0             2020-06-25             Bajo Baudó                    Chocó
# 1             2020-07-12               Medellín                Antioquia
# 2             2020-07-10               Medellín                Antioquia
# 3             2020-07-22                Popayán                    Cauca
# 4             2020-07-13        Barrancabermeja                Santander
# 5             2020-07-07           Barranquilla        Barranquilla D.E.
# 6             2020-07-30               Canalete                  Córdoba
# 7             2020-07-16            Bogotá D.C.              Bogotá D.C.
# 8             2020-07-07            Bogotá D.C.              Bogotá D.C.
# 9             2020-06-09           Barranquilla        Barranquilla D.E.
# 10            2020-05-20    Cartagena de Indias      Cartagena D.T. y C.
# 11            2020-07-16            Bogotá D.C.              Bogotá D.C.
# 12            2020-07-06                  Orito                 Putumayo
# 13            2020-07-02               Magangué                  Bolívar
# 14            2020-04-12            Bogotá D.C.              Bogotá D.C.
# 15            2020-07-02    Cartagena de Indias      Cartagena D.T. y C.
# 16            2020-07-29               Medellín                Antioquia
# 17            2020-06-04                Baranoa                Atlántico
# 18            2020-05-28                Jamundí          Valle del Cauca
# 19            2020-07-13            Bogotá D.C.              Bogotá D.C.
# 20            2020-07-26  Santa Fé de Antioquia                Antioquia
# 21            2020-07-07            Bogotá D.C.              Bogotá D.C.
# 22            2020-07-24            Bogotá D.C.              Bogotá D.C.
# 23            2020-06-05   San Andrés de Tumaco                   Nariño
# 24            2020-07-17            Bogotá D.C.              Bogotá D.C.
# 25            2020-06-30               Timbiquí                    Cauca
# 26            2020-07-19               Montería                  Córdoba
# 27            2020-07-08            Bogotá D.C.              Bogotá D.C.
# 28            2020-07-25                   Cali          Valle del Cauca
# 29            2020-07-17            Bogotá D.C.              Bogotá D.C.
# 30            2020-07-28                 Carepa                Antioquia
# 31            2020-07-05                Córdoba                  Bolívar
# 32            2020-07-18            Bogotá D.C.              Bogotá D.C.
# 33            2020-07-21                  Vianí             Cundinamarca
# 34            2020-07-10               Magangué                  Bolívar
# 35            2020-07-19            Bogotá D.C.              Bogotá D.C.
# 36            2020-07-03            Bogotá D.C.              Bogotá D.C.
# 37            2020-06-13             Santa Rosa                  Bolívar
# 38            2020-07-20            Bogotá D.C.              Bogotá D.C.
# 39            2020-06-03    La Jagua de Ibirico                    Cesar
# 40            2020-07-09              Florencia                  Caquetá
# 41            2020-07-17              Florencia                  Caquetá
# 42            2020-07-14                  Orito                 Putumayo
# 43            2020-07-07            Bogotá D.C.              Bogotá D.C.
# 44            2020-05-02           Barranquilla        Barranquilla D.E.
# 45            2020-05-26            Bogotá D.C.              Bogotá D.C.
# 46            2020-06-30            Bogotá D.C.              Bogotá D.C.
# 47            2020-06-14            Santa Marta    Santa Marta D.T. y C.
# 48            2020-06-11                Malambo                Atlántico
# 49            2020-06-21                Malambo                Atlántico
#
#       atención  Edad        Estado          Fecha de muerte
# 0   Recuperado   120          Leve                      NaN
# 1         Casa   119          Leve                      NaN
# 2         Casa   114          Leve                      NaN
# 3    Fallecido   107     Fallecido  2020-07-22T00:00:00.000
# 4         Casa   106          Leve                      NaN
# 5    Fallecido   104     Fallecido  2020-06-21T00:00:00.000
# 6         Casa   104          Leve                      NaN
# 7     Hospital   104  Asintomático                      NaN
# 8    Fallecido   104     Fallecido  2020-07-30T00:00:00.000
# 9   Recuperado   104          Leve                      NaN
# 10   Fallecido   103     Fallecido  2020-05-28T00:00:00.000
# 11   Fallecido   103     Fallecido  2020-07-26T00:00:00.000
# 12  Recuperado   103          Leve                      NaN
# 13  Recuperado   103          Leve                      NaN
# 14  Recuperado   103          Leve                      NaN
# 15  Recuperado   102          Leve                      NaN
# 16        Casa   102          Leve                      NaN
# 17  Recuperado   102          Leve                      NaN
# 18   Fallecido   102     Fallecido  2020-05-28T00:00:00.000
# 19        Casa   102  Asintomático                      NaN
# 20    Hospital   102      Moderado                      NaN
# 21   Fallecido   101     Fallecido  2020-07-09T00:00:00.000
# 22        Casa   101          Leve                      NaN
# 23  Recuperado   101          Leve                      NaN
# 24   Fallecido   101     Fallecido  2020-07-17T00:00:00.000
# 25   Fallecido   101     Fallecido  2020-07-03T00:00:00.000
# 26   Fallecido   101     Fallecido  2020-07-19T00:00:00.000
# 27        Casa   101          Leve                      NaN
# 28   Fallecido   101     Fallecido  2020-07-26T00:00:00.000
# 29        Casa   101  Asintomático                      NaN
# 30        Casa   101          Leve                      NaN
# 31  Recuperado   101          Leve                      NaN
# 32   Fallecido   101     Fallecido  2020-07-20T00:00:00.000
# 33        Casa   101          Leve                      NaN
# 34        Casa   101          Leve                      NaN
# 35   Fallecido   101     Fallecido  2020-07-23T00:00:00.000
# 36         NaN   101           NaN                      NaN
# 37    Hospital   100      Moderado                      NaN
# 38   Fallecido   100     Fallecido  2020-07-23T00:00:00.000
# 39   Fallecido   100     Fallecido  2020-06-09T00:00:00.000
# 40  Recuperado   100          Leve                      NaN
# 41   Fallecido   100     Fallecido  2020-07-20T00:00:00.000
# 42   Fallecido   100     Fallecido  2020-07-25T00:00:00.000
# 43   Fallecido   100     Fallecido  2020-07-13T00:00:00.000
# 44   Fallecido   100     Fallecido  2020-05-01T00:00:00.000
# 45   Fallecido   100     Fallecido  2020-05-30T00:00:00.000
# 46   Fallecido   100     Fallecido  2020-07-04T00:00:00.000
# 47         NaN   100           NaN  2020-06-16T00:00:00.000
# 48   Fallecido   100     Fallecido  2020-06-11T00:00:00.000
# 49  Recuperado   100          Leve                      NaN

# %%
daneEtareos= pd.read_csv('DaneEtareos.csv', sep=',', usecols = ['REGION', 'Grupos de edad', '2020'])
daneEtareos

# %%
menordeUno= df['Edad'] < 1
UnoCuatro = np.logical_and(df['Edad'] > 0, df['Edad'] < 5)
CincoCatorce = np.logical_and(df['Edad'] > 4, df['Edad'] < 15)
QuinceCuarentayCuatro = np.logical_and(df['Edad'] > 14, df['Edad'] < 45)
CuarentayCincoSesentayCuatro  = np.logical_and(df['Edad'] > 44, df['Edad'] < 65)
SesentayCincoOchentayCuatro = np.logical_and(df['Edad'] > 64, df['Edad'] < 85)
OchentayCincoNoventayNueve = np.logical_and(df['Edad'] > 84, df['Edad'] < 100)
masdeCien = df['Edad'] > 99

# %%
#departamento = 'Atlántico'
#departamento = 'Antioquia'
departamento = 'Caldas'

# %%
grupoEdad = SesentayCincoOchentayCuatro
etareo = '65-84'

# %%
GruposEtareos = df.loc[grupoEdad,['ID de caso','Fecha de notificación', 'Ciudad de ubicación',
       'Departamento o Distrito ', 'atención', 'Edad', 'Sexo', 'Tipo',
       'Estado', 'Fecha de muerte']]

# %%
GruposEtareos

# %%
daneEtareos

# %%
ESTADO = 'Fallecido'
estado = df['Estado'] == ESTADO 
estadoporDpto = GruposEtareos.loc[estado]
filtro = estadoporDpto['Departamento o Distrito '] == departamento
fallecidospordepartamentoygrupoetareo = estadoporDpto.loc[filtro,'ID de caso'].count()
fallecidospordepartamentoygrupoetareo

# %%
GruposEtareos.columns

# %%
filtro = GruposEtareos['Departamento o Distrito '] == departamento 
Persona_por_Grupos_Etareos = GruposEtareos[filtro].count()['ID de caso']
Persona_por_Grupos_Etareos

# %%
TasaLetalidadxGrupoEtareo = (fallecidospordepartamentoygrupoetareo/Persona_por_Grupos_Etareos)*100
TasaLetalidadxGrupoEtareo

# %%
filtro = daneEtareos['REGION'] == departamento
totalDptoEtareos = daneEtareos.loc[filtro]
filtro1 = totalDptoEtareos['Grupos de edad'] == etareo
total = totalDptoEtareos.loc[filtro1]['2020'].astype(int)
total

# %%
MortalidadGrupoEtareo =(fallecidospordepartamentoygrupoetareo/total)*1000000
MortalidadGrupoEtareo

# %% [markdown]
# #####
