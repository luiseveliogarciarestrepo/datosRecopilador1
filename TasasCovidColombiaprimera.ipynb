# %%
import pandas as pd

# %% [markdown]
# #### Definir número de dígitos

# %%
pd.set_option("display.precision", 2)

# %% [markdown]
# #### Lectura de archivos

# %%
mundo= pd.read_csv('poblacionMundial.csv')

# %%
covMun= pd.read_csv('CovidMundoT.csv')

# %%
mundo.set_index('Spanish', inplace=True)

# %%
covCol = pd.read_csv('CovidColombia.csv', usecols= ['Fecha de notificación', 
       'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
       'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'Fecha recuperado', 'Fecha diagnostico','Fecha de muerte', 
       'Tipo recuperación'], parse_dates = ['Fecha de notificación','Fecha de muerte', 'Fecha diagnostico','Fecha recuperado'], low_memory=False)

# %%
covCol
# Out:
#        Fecha de notificación  Ciudad de ubicación Departamento o Distrito   \
# 0                 2020-03-02          Bogotá D.C.              Bogotá D.C.
# 1                 2020-03-06  Guadalajara de Buga          Valle del Cauca
# 2                 2020-03-07             Medellín                Antioquia
# 3                 2020-03-09             Medellín                Antioquia
# 4                 2020-03-09             Medellín                Antioquia
# ...                      ...                  ...                      ...
# 317646            2020-07-22          Bogotá D.C.              Bogotá D.C.
# 317647            2020-07-24          Bogotá D.C.              Bogotá D.C.
# 317648            2020-07-26          Bogotá D.C.              Bogotá D.C.
# 317649            2020-07-29          Bogotá D.C.              Bogotá D.C.
# 317650            2020-07-31          Bogotá D.C.              Bogotá D.C.
#
#           atención  Edad Sexo         Tipo        Estado País de procedencia  \
# 0       Recuperado    19    F    Importado          Leve              ITALIA
# 1       Recuperado    34    M    Importado          Leve              ESPAÑA
# 2       Recuperado    50    F    Importado          Leve              ESPAÑA
# 3       Recuperado    55    M  Relacionado          Leve                 NaN
# 4       Recuperado    25    M  Relacionado          Leve                 NaN
# ...            ...   ...  ...          ...           ...                 ...
# 317646        Casa    54    M   En estudio  Asintomático                 NaN
# 317647        Casa    25    M   En estudio  Asintomático                 NaN
# 317648        Casa    35    M   En estudio  Asintomático                 NaN
# 317649        Casa    40    M   En estudio          Leve                 NaN
# 317650        Casa    33    F   En estudio  Asintomático                 NaN
#
#        Fecha de muerte Fecha diagnostico Fecha recuperado Tipo recuperación
# 0                  NaN        2020-03-06       2020-03-13               PCR
# 1                  NaN        2020-03-09       2020-03-19               PCR
# 2                  NaN        2020-03-09       2020-03-15               PCR
# 3                  NaN        2020-03-11       2020-03-26               PCR
# 4                  NaN        2020-03-11       2020-03-23               PCR
# ...                ...               ...              ...               ...
# 317646             NaN        2020-08-02              NaT               NaN
# 317647             NaN        2020-08-02              NaT               NaN
# 317648             NaN        2020-08-02              NaT               NaN
# 317649             NaN        2020-08-02              NaT               NaN
# 317650             NaN        2020-08-02              NaT               NaN
#
# [317651 rows x 13 columns]

# %%
Col = pd.read_csv('Dane2018_2023.csv').drop(columns = ['2018',
       '2019','2021', '2022', '2023' ])

# %%
covCol['Fecha de muerte'] = pd.to_datetime(covCol['Fecha de muerte'], errors='coerce')

# %%
dates = []
wrong_dates = []

for i in covCol['Fecha de notificación'].unique():
    try: 
        date = pd.to_datetime(i)
        dates.append(i)
    except:
        wrong_dates.append(i)

# %%
wrong_dates
# Out:
# []

# %% [markdown]
# #### Convertir fechas a type "datetime"

# %%
fechas =['Fecha de notificación']
for i in fechas:
    covCol[i] = pd.to_datetime(covCol[i])

# %% [markdown]
# #### Variables a ingresar

# %%
pais = 'Colombia'

departamento = 'Caldas'

municipio = ''

variable_buscar = 'Atención'  # puede ser 'Atención' o 'Estado'

estado = 'Hospital UCI'  # Si atención:  ['Recuperado', 'Hospital', 'Hospital UCI', nan, 'Casa']
                   # Si Estado:   ['Leve', 'Asintomático', 'Fallecido', 'Moderado', 'Grave', nan]

ano = '2020'

# %% [markdown]
# #### Poblaciones

# %%
Poblacion_pais = mundo.loc[pais, ano]

# %%
total_casos_covid_colombia = covCol['Fecha de notificación'].count()

# %%
Fallecidos_pais = covCol['Fecha de muerte'].count()

# %% [markdown]
# #### Seleccionar totales;  igualar nombre de Series seleccionadas en las dataFrame; establecer índice y subíndice.

# %%
filtro = Col['Género'] == 'AMBOS SEXOS'
Col = Col.loc[filtro, :].drop(columns=['Género'])

# %%
Col.set_index(['Dpto', 'Municipio'], inplace=True)

# %%
Col.columns
# Out:
# Index(['2020'], dtype='object')

# %%
covCol.rename(columns={"Departamento o Distrito ": "Dpto", "Ciudad de ubicación": "Municipio", "atención":"Atención", "Fecha diagnostico":"Fecha diagnóstico"}, inplace=True)

# %%
covCol.set_index(['Dpto', 'Municipio'], inplace = True)

# %% [markdown]
# #### Unir las dataFrames

# %%
Tasas = pd.merge(covCol, Col, left_index=True, right_index=True)

# %%
Tasas = Tasas.reset_index()

# %%
Tasas
# Out:
#             Dpto       Municipio Fecha de notificación    Atención  Edad Sexo  \
# 0       Amazonas         Leticia            2020-04-14  Recuperado    26    M
# 1       Amazonas         Leticia            2020-04-13  Recuperado    47    F
# 2       Amazonas         Leticia            2020-04-14  Recuperado    16    F
# 3       Amazonas         Leticia            2020-04-14  Recuperado    41    F
# 4       Amazonas         Leticia            2020-04-16  Recuperado    54    M
# ...          ...             ...                   ...         ...   ...  ...
# 307487    Vaupés         Taraira            2020-07-12  Recuperado     2    M
# 307488    Vaupés         Taraira            2020-07-12  Recuperado    27    M
# 307489   Vichada    La Primavera            2020-07-15    Hospital    78    F
# 307490   Vichada  Puerto Carreño            2020-05-29  Recuperado    20    M
# 307491   Vichada  Puerto Carreño            2020-07-30        Casa    26    F
#
#                Tipo        Estado País de procedencia Fecha de muerte  \
# 0       Relacionado          Leve                 NaN             NaT
# 1         Importado          Leve              BRASIL             NaT
# 2       Relacionado          Leve                 NaN             NaT
# 3         Importado          Leve              BRASIL             NaT
# 4       Relacionado          Leve                 NaN             NaT
# ...             ...           ...                 ...             ...
# 307487  Relacionado          Leve                 NaN             NaT
# 307488  Relacionado          Leve                 NaN             NaT
# 307489   En estudio      Moderado                 NaN             NaT
# 307490   En estudio  Asintomático                 NaN             NaT
# 307491   En estudio          Leve                 NaN             NaT
#
#        Fecha diagnóstico Fecha recuperado Tipo recuperación   2020
# 0             2020-04-17       2020-05-19               PCR  49737
# 1             2020-04-18       2020-05-31            Tiempo  49737
# 2             2020-04-18       2020-05-29               PCR  49737
# 3             2020-04-18       2020-05-29               PCR  49737
# 4             2020-04-21       2020-04-29               PCR  49737
# ...                  ...              ...               ...    ...
# 307487        2020-07-13       2020-07-25            Tiempo   2423
# 307488        2020-07-13       2020-07-25            Tiempo   2423
# 307489        2020-07-17              NaT               NaN   9608
# 307490        2020-05-29       2020-06-07               PCR  20294
# 307491        2020-08-01              NaT               NaN  20294
#
# [307492 rows x 14 columns]

# %%
Tasas['Municipio'].unique()
# Out:
# array(['Leticia', 'Puerto Nariño', 'Abejorral', 'Abriaquí', 'Amagá',
#        'Amalfi', 'Andes', 'Angostura', 'Anorí', 'Apartadó', 'Arboletes',
#        'Armenia', 'Barbosa', 'Bello', 'Belmira', 'Betulia', 'Briceño',
#        'Buriticá', 'Caicedo', 'Caldas', 'Campamento', 'Caracolí',
#        'Carepa', 'Caucasia', 'Cañasgordas', 'Chigorodó', 'Cisneros',
#        'Ciudad Bolívar', 'Cocorná', 'Concepción', 'Concordia',
#        'Copacabana', 'Cáceres', 'Dabeiba', 'Ebéjico', 'El Bagre',
#        'El Carmen de Viboral', 'El Santuario', 'Envigado', 'Fredonia',
#        'Frontino', 'Giraldo', 'Girardota', 'Granada', 'Guadalupe',
#        'Guarne', 'Guatapé', 'Gómez Plata', 'Heliconia', 'Hispania',
#        'Ituango', 'Jericó', 'La Ceja', 'La Estrella', 'La Pintada',
#        'La Unión', 'Liborina', 'Maceo', 'Marinilla', 'Medellín',
#        'Montebello', 'Murindó', 'Mutatá', 'Nechí', 'Necoclí', 'Olaya',
#        'Peque', 'Peñol', 'Puerto Berrío', 'Puerto Nare', 'Puerto Triunfo',
#        'Remedios', 'Retiro', 'Rionegro', 'Sabaneta', 'Salgar',
#        'San Carlos', 'San Francisco', 'San Jerónimo', 'San Juan de Urabá',
#        'San Luis', 'San Pedro de Urabá', 'San Rafael', 'San Roque',
#        'Santa Bárbara', 'Santa Rosa de Osos', 'Santo Domingo', 'Segovia',
#        'Sonsón', 'Sopetrán', 'Tarazá', 'Tarso', 'Titiribí', 'Toledo',
#        'Turbo', 'Támesis', 'Uramita', 'Urrao', 'Valdivia', 'Valparaíso',
#        'Venecia', 'Vigía del Fuerte', 'Yarumal', 'Yolombó', 'Yondó',
#        'Zaragoza', 'Arauca', 'Arauquita', 'Saravena', 'Tame',
#        'Providencia', 'San Andrés', 'Baranoa', 'Candelaria', 'Galapa',
#        'Juan de Acosta', 'Luruaco', 'Malambo', 'Manatí',
#        'Palmar de Varela', 'Piojó', 'Polonuevo', 'Ponedera',
#        'Puerto Colombia', 'Repelón', 'Sabanagrande', 'Sabanalarga',
#        'Santa Lucía', 'Santo Tomás', 'Soledad', 'Suan', 'Tubará',
#        'Usiacurí', 'Barranquilla', 'Bogotá D.C.', 'Achí',
#        'Altos del Rosario', 'Arenal', 'Arjona', 'Arroyohondo',
#        'Barranco de Loba', 'Calamar', 'Cantagallo', 'Cicuco', 'Clemencia',
#        'Córdoba', 'El Carmen de Bolívar', 'El Guamo', 'El Peñón',
#        'Hatillo de Loba', 'Magangué', 'Mahates', 'Mompós', 'Montecristo',
#        'Morales', 'Norosí', 'Pinillos', 'Regidor', 'San Cristóbal',
#        'San Estanislao', 'San Jacinto', 'San Jacinto del Cauca',
#        'San Juan Nepomuceno', 'San Pablo', 'Santa Catalina', 'Santa Rosa',
#        'Santa Rosa del Sur', 'Soplaviento', 'Talaigua Nuevo', 'Tiquisio',
#        'Turbaco', 'Turbaná', 'Villanueva', 'Zambrano', 'Aquitania',
#        'Arcabuco', 'Belén', 'Boyacá', 'Buenavista', 'Chiquinquirá',
#        'Chíquiza', 'Ciénega', 'Coper', 'Corrales', 'Covarachía', 'Cubará',
#        'Cucaita', 'Cuítiva', 'Cómbita', 'Duitama', 'Firavitoba',
#        'Garagoa', 'Guateque', 'Guayatá', 'Iza', 'Maripí', 'Miraflores',
#        'Monguí', 'Moniquirá', 'Motavita', 'Muzo', 'Nobsa', 'Nuevo Colón',
#        'Oicatá', 'Paipa', 'Pauna', 'Paya', 'Pesca', 'Puerto Boyacá',
#        'Quípama', 'Ramiriquí', 'Saboyá', 'Samacá', 'San Miguel de Sema',
#        'Santa Rosa de Viterbo', 'Santa Sofía', 'Santana', 'Siachoque',
#        'Soatá', 'Socha', 'Sogamoso', 'Soracá', 'Susacón', 'Sutamarchán',
#        'Sáchica', 'Tasco', 'Tenza', 'Tibaná', 'Tibasosa', 'Tinjacá',
#        'Tipacoque', 'Toca', 'Togüí', 'Tunja', 'Turmequé', 'Tuta',
#        'Ventaquemada', 'Villa de Leyva', 'Viracachá', 'Buenaventura',
#        'Aguadas', 'Anserma', 'Aranzazu', 'Belalcázar', 'Chinchiná',
#        'La Dorada', 'Manizales', 'Manzanares', 'Marmato', 'Marquetalia',
#        'Neira', 'Norcasia', 'Palestina', 'Pácora', 'Riosucio',
#        'Risaralda', 'Salamina', 'Samaná', 'Supía', 'Villamaría',
#        'Viterbo', 'Albania', 'Cartagena del Chairá', 'Curillo',
#        'El Doncello', 'Florencia', 'La Montañita', 'Milán', 'Morelia',
#        'Puerto Rico', 'San José del Fragua', 'San Vicente del Caguán',
#        'Solano', 'Solita', 'Cartagena de Indias', 'Aguazul',
#        'Hato Corozal', 'Maní', 'Monterrey', 'Orocué', 'Paz de Ariporo',
#        'Pore', 'Tauramena', 'Trinidad', 'Yopal', 'Argelia', 'Balboa',
#        'Buenos Aires', 'Cajibío', 'Caldono', 'Caloto', 'Corinto',
#        'El Tambo', 'Jambaló', 'La Sierra', 'Mercaderes', 'Miranda',
#        'Padilla', 'Patía', 'Piendamó', 'Popayán', 'Puerto Tejada',
#        'Rosas', 'Santander de Quilichao', 'Silvia', 'Suárez', 'Timbiquí',
#        'Timbío', 'Totoró', 'Aguachica', 'Agustín Codazzi', 'Astrea',
#        'Becerril', 'Bosconia', 'Chimichagua', 'Chiriguaná', 'Curumaní',
#        'El Copey', 'El Paso', 'Gamarra', 'González', 'La Gloria',
#        'La Jagua de Ibirico', 'La Paz', 'Pailitas', 'Pelaya',
#        'Pueblo Bello', 'Río de Oro', 'San Alberto', 'San Diego',
#        'San Martín', 'Tamalameque', 'Valledupar', 'Acandí', 'Atrato',
#        'Bagadó', 'Bahía Solano', 'Bajo Baudó', 'Condoto', 'Cértegui',
#        'El Carmen de Atrato', 'Istmina', 'Lloró', 'Medio Atrato',
#        'Medio Baudó', 'Medio San Juan', 'Nuquí', 'Nóvita', 'Quibdó',
#        'Río Quito', 'Tadó', 'Unguía', 'Unión Panamericana',
#        'Agua de Dios', 'Albán', 'Anapoima', 'Anolaima', 'Apulo',
#        'Arbeláez', 'Beltrán', 'Bituima', 'Bojacá', 'Cabrera', 'Cachipay',
#        'Cajicá', 'Caparrapí', 'Carmen de Carupa', 'Chipaque', 'Choachí',
#        'Chocontá', 'Chía', 'Cogua', 'Cota', 'Cucunubá', 'El Colegio',
#        'El Rosal', 'Facatativá', 'Fosca', 'Funza', 'Fusagasugá',
#        'Fúquene', 'Gachancipá', 'Gachetá', 'Gama', 'Girardot', 'Guachetá',
#        'Guaduas', 'Guasca', 'Guataquí', 'Guatavita', 'Junín', 'La Calera',
#        'La Mesa', 'La Palma', 'La Vega', 'Lenguazaque', 'Madrid', 'Manta',
#        'Mosquera', 'Nariño', 'Nemocón', 'Nilo', 'Nimaima', 'Pacho',
#        'Pandi', 'Pasca', 'Puerto Salgar', 'Quebradanegra', 'Quetame',
#        'Ricaurte', 'San Antonio del Tequendama', 'San Bernardo',
#        'Sasaima', 'Sesquilé', 'Sibaté', 'Silvania', 'Simijaca', 'Soacha',
#        'Sopó', 'Subachoque', 'Suesca', 'Tabio', 'Tausa', 'Tena', 'Tenjo',
#        'Tocaima', 'Tocancipá', 'Ubalá', 'Ubaque', 'Une', 'Vianí',
#        'Villapinzón', 'Villeta', 'Viotá', 'Yacopí', 'Zipacón',
#        'Zipaquirá', 'Útica', 'Inírida', 'San José del Guaviare',
#        'Acevedo', 'Agrado', 'Aipe', 'Algeciras', 'Baraya', 'Campoalegre',
#        'Colombia', 'Garzón', 'Gigante', 'Hobo', 'Isnos', 'La Argentina',
#        'La Plata', 'Neiva', 'Nátaga', 'Oporapa', 'Paicol', 'Palermo',
#        'Pital', 'Pitalito', 'Rivera', 'Saladoblanco', 'San Agustín',
#        'Suaza', 'Tarqui', 'Tello', 'Teruel', 'Timaná', 'Villavieja',
#        'Yaguará', 'Barrancas', 'Dibulla', 'Distracción', 'El Molino',
#        'Fonseca', 'Hatonuevo', 'La Jagua del Pilar', 'Maicao', 'Manaure',
#        'Riohacha', 'San Juan del Cesar', 'Uribia', 'Urumita', 'Algarrobo',
#        'Aracataca', 'Ariguaní', 'Chivolo', 'Ciénaga', 'El Banco',
#        'El Retén', 'Fundación', 'Guamal', 'Nueva Granada', 'Pedraza',
#        'Pijiño del Carmen', 'Pivijay', 'Plato', 'Puebloviejo', 'Remolino',
#        'San Sebastián de Buenavista', 'San Zenón', 'Santa Ana',
#        'Santa Bárbara de Pinto', 'Sitionuevo', 'Zona Bananera', 'Acacías',
#        'Cabuyaro', 'Castilla la Nueva', 'Cumaral', 'El Castillo',
#        'Fuente de Oro', 'Mapiripán', 'Mesetas', 'Puerto Gaitán',
#        'Puerto López', 'Restrepo', 'San Carlos de Guaroa',
#        'San Juan de Arama', 'Villavicencio', 'Vistahermosa', 'Aldana',
#        'Ancuyá', 'Arboleda', 'Barbacoas', 'Buesaco', 'Chachagüí', 'Colón',
#        'Contadero', 'Cumbal', 'Cumbitara', 'El Charco', 'El Peñol',
#        'Francisco Pizarro', 'Funes', 'Guachucal', 'Guaitarilla',
#        'Gualmatán', 'Imués', 'Ipiales', 'La Cruz', 'La Florida',
#        'La Llanada', 'La Tola', 'Leiva', 'Linares', 'Los Andes',
#        'Mallama', 'Olaya Herrera', 'Pasto', 'Potosí', 'Puerres',
#        'Pupiales', 'Roberto Payán', 'Samaniego', 'San Andrés de Tumaco',
#        'San Lorenzo', 'San Pedro de Cartago', 'Sandoná', 'Santacruz',
#        'Taminango', 'Tangua', 'Túquerres', 'Yacuanquer', 'Arboledas',
#        'Bochalema', 'Chinácota', 'Chitagá', 'Convención', 'Cácota',
#        'Cúcuta', 'Durania', 'El Tarra', 'El Zulia', 'Gramalote',
#        'La Esperanza', 'La Playa', 'Labateca', 'Los Patios', 'Mutiscua',
#        'Ocaña', 'Pamplona', 'Pamplonita', 'Puerto Santander',
#        'Ragonvalia', 'San Calixto', 'San Cayetano', 'Santiago',
#        'Sardinata', 'Silos', 'Teorama', 'Tibú', 'Villa del Rosario',
#        'Mocoa', 'Orito', 'Puerto Asís', 'Puerto Caicedo', 'Puerto Guzmán',
#        'San Miguel', 'Sibundoy', 'Valle del Guamuez', 'Villagarzón',
#        'Circasia', 'Filandia', 'Génova', 'La Tebaida', 'Montenegro',
#        'Quimbaya', 'Salento', 'Apía', 'Belén de Umbría', 'Dosquebradas',
#        'La Celia', 'La Virginia', 'Marsella', 'Pereira', 'Pueblo Rico',
#        'Quinchía', 'Santa Rosa de Cabal', 'Santuario', 'Santa Marta',
#        'Aguada', 'Aratoca', 'Barichara', 'Barrancabermeja', 'Bolívar',
#        'Bucaramanga', 'California', 'Carcasí', 'Cepitá', 'Cimitarra',
#        'Curití', 'El Carmen de Chucurí', 'El Playón', 'Floridablanca',
#        'Galán', 'Girón', 'Guapotá', 'Hato', 'La Belleza', 'Landázuri',
#        'Lebrija', 'Los Santos', 'Matanza', 'Mogotes', 'Málaga', 'Oiba',
#        'Onzaga', 'Piedecuesta', 'Puerto Parra', 'Puerto Wilches',
#        'Páramo', 'Sabana de Torres', 'San Gil', 'San Joaquín',
#        'San José de Miranda', 'San Vicente de Chucurí',
#        'Santa Helena del Opón', 'Socorro', 'Suaita', 'Valle de San José',
#        'Vélez', 'Zapatoca', 'Caimito', 'Chalán', 'Coloso', 'Corozal',
#        'Coveñas', 'El Roble', 'Galeras', 'Guaranda', 'Los Palmitos',
#        'Majagual', 'Morroa', 'Ovejas', 'Palmito', 'Sampués',
#        'San Juan de Betulia', 'San Luis de Sincé', 'San Marcos',
#        'San Onofre', 'San Pedro', 'Santiago de Tolú', 'Sincelejo',
#        'Sucre', 'Tolú Viejo', 'Alpujarra', 'Ambalema', 'Anzoátegui',
#        'Ataco', 'Cajamarca', 'Carmen de Apicalá', 'Casabianca',
#        'Chaparral', 'Coyaima', 'Dolores', 'Espinal', 'Flandes', 'Fresno',
#        'Guamo', 'Herveo', 'Honda', 'Ibagué', 'Icononzo', 'Lérida',
#        'Líbano', 'Melgar', 'Natagaima', 'Ortega', 'Piedras', 'Planadas',
#        'Prado', 'Purificación', 'Rioblanco', 'Rovira', 'Saldaña',
#        'San Antonio', 'Venadillo', 'Villarrica', 'Alcalá', 'Andalucía',
#        'Ansermanuevo', 'Bugalagrande', 'Caicedonia', 'Cali', 'Calima',
#        'Cartago', 'Dagua', 'El Cairo', 'El Cerrito', 'El Dovio',
#        'El Águila', 'Florida', 'Ginebra', 'Guacarí',
#        'Guadalajara de Buga', 'Jamundí', 'La Cumbre', 'La Victoria',
#        'Obando', 'Palmira', 'Pradera', 'Roldanillo', 'Sevilla', 'Toro',
#        'Trujillo', 'Tuluá', 'Ulloa', 'Versalles', 'Vijes', 'Yotoco',
#        'Yumbo', 'Zarzal', 'Mitú', 'Taraira', 'La Primavera',
#        'Puerto Carreño'], dtype=object)

# %% [markdown]
# ####  Agrupar por Departamento o Municipio para hacer dataFrame con Total casos, Fallecidos y Recuperados

# %%
Casos_a_Fecha = Tasas.groupby(['Dpto', 'Municipio'])[['Fecha de notificación', 'Fecha de muerte',
        'Fecha recuperado']].count().loc[[departamento, municipio]]

# %%
Cuadro_Tasas = pd.merge(Casos_a_Fecha, Col, left_index=True, right_index=True)

# %%
Cuadro_Tasas.rename({'Fecha de notificación':'Total casos', 
                     'Fecha de muerte':'Fallecidos', 
                     'Fecha recuperado': 'Recuperados', 
                     '2020': 'Población'}, axis = 'columns', inplace=True)

# %% [markdown]
# ##### Agregando columnas de tasas de letalidad y de mortalidad

# %%
Cuadro_Tasas['Tasa de letalidad por 100 habitantes'] = (Cuadro_Tasas['Fallecidos']/Cuadro_Tasas['Total casos'])*100
Cuadro_Tasas['Tasa de mortalidad por 100.000 habitantes'] = (Cuadro_Tasas['Fallecidos']/Cuadro_Tasas['Población'])*100000

# %%
Cuadro_Tasas
# Out:
#                     Total casos  Fallecidos  Recuperados  Población  \
# Dpto   Municipio
# Caldas Marmato               43           0            1       9167
#        Aranzazu               2           0            1      10556
#        Manzanares            17           1            3      17794
#        Norcasia               1           1            0       6128
#        Marquetalia            8           0            7      13490
#        Chinchiná             49           1           13      52267
#        Belalcázar             1           0            0      10650
#        Neira                 12           2            2      21114
#        La Dorada            181           3           91      74006
#        Riosucio              25           0            5      51956
#        Samaná                 4           0            2      19967
#        Anserma               22           0            2      36691
#        Risaralda              3           0            1      10568
#        Villamaría            42           2           16      67429
#        Pácora                 3           0            0      15324
#        Palestina              1           0            0      15681
#        Viterbo                7           0            3      12853
#        Manizales            535           6          168     446160
#        Salamina               3           0            0      19393
#        Supía                 20           2            1      29363
#        Aguadas               44           0            1      23048
#
#                     Tasa de letalidad por 100 habitantes  \
# Dpto   Municipio
# Caldas Marmato                                      0.00
#        Aranzazu                                     0.00
#        Manzanares                                   5.88
#        Norcasia                                   100.00
#        Marquetalia                                  0.00
#        Chinchiná                                    2.04
#        Belalcázar                                   0.00
#        Neira                                       16.67
#        La Dorada                                    1.66
#        Riosucio                                     0.00
#        Samaná                                       0.00
#        Anserma                                      0.00
#        Risaralda                                    0.00
#        Villamaría                                   4.76
#        Pácora                                       0.00
#        Palestina                                    0.00
#        Viterbo                                      0.00
#        Manizales                                    1.12
#        Salamina                                     0.00
#        Supía                                       10.00
#        Aguadas                                      0.00
#
#                     Tasa de mortalidad por 100.000 habitantes
# Dpto   Municipio
# Caldas Marmato                                           0.00
#        Aranzazu                                          0.00
#        Manzanares                                        5.62
#        Norcasia                                         16.32
#        Marquetalia                                       0.00
#        Chinchiná                                         1.91
#        Belalcázar                                        0.00
#        Neira                                             9.47
#        La Dorada                                         4.05
#        Riosucio                                          0.00
#        Samaná                                            0.00
#        Anserma                                           0.00
#        Risaralda                                         0.00
#        Villamaría                                        2.97
#        Pácora                                            0.00
#        Palestina                                         0.00
#        Viterbo                                           0.00
#        Manizales                                         1.34
#        Salamina                                          0.00
#        Supía                                             6.81
#        Aguadas                                           0.00

# %% [markdown]
# #### Condiciones de búsqueda

# %%
if departamento == '' and municipio== '':
    print('Debe ingresar mínimo el Departamento.  Inténtelo nuevamente')
    pass
else:
    if municipio == '':
        Total_casos = Cuadro_Tasas.loc[departamento, 'Total casos'].astype(int) 
        Fallecidos_dpto_munic = Cuadro_Tasas.loc[(departamento), 'Fallecidos'].astype(int)
        Poblacion_dpto_munic = Cuadro_Tasas.loc[(departamento), 'Población'].astype(int)
    
    else:
        Total_casos = Cuadro_Tasas.loc[(departamento, municipio), 'Total casos'].astype(int)
        Fallecidos_dpto_munic = Cuadro_Tasas.loc[(departamento, municipio), 'Fallecidos'].astype(int)
        Poblacion_dpto_munic = Cuadro_Tasas.loc[(departamento, municipio), 'Población'].astype(int)

# %%
total_casos_covid_colombia
# Out:
# 317651

# %%
Fallecidos_dpto_munic
# Out:
# Municipio
# Marmato        0
# Aranzazu       0
# Manzanares     1
# Norcasia       1
# Marquetalia    0
# Chinchiná      1
# Belalcázar     0
# Neira          2
# La Dorada      3
# Riosucio       0
# Samaná         0
# Anserma        0
# Risaralda      0
# Villamaría     2
# Pácora         0
# Palestina      0
# Viterbo        0
# Manizales      6
# Salamina       0
# Supía          2
# Aguadas        0
# Name: Fallecidos, dtype: int64

# %%
Fallecidos_pais
# Out:
# 11150

# %%
Poblacion_dpto_munic
# Out:
# Municipio
# Marmato          9167
# Aranzazu        10556
# Manzanares      17794
# Norcasia         6128
# Marquetalia     13490
# Chinchiná       52267
# Belalcázar      10650
# Neira           21114
# La Dorada       74006
# Riosucio        51956
# Samaná          19967
# Anserma         36691
# Risaralda       10568
# Villamaría      67429
# Pácora          15324
# Palestina       15681
# Viterbo         12853
# Manizales      446160
# Salamina        19393
# Supía           29363
# Aguadas         23048
# Name: Población, dtype: int64

# %%
Poblacion_dpto_munic.sum()
# Out:
# 963605

# %%
poblacionDpto = Col.loc[(departamento),'2020'].sum()
poblacionDpto
# Out:
# 1018453

# %%
Poblacion_pais
# Out:
# 50883000

# %%
Total_casos
# Out:
# Municipio
# Marmato         43
# Aranzazu         2
# Manzanares      17
# Norcasia         1
# Marquetalia      8
# Chinchiná       49
# Belalcázar       1
# Neira           12
# La Dorada      181
# Riosucio        25
# Samaná           4
# Anserma         22
# Risaralda        3
# Villamaría      42
# Pácora           3
# Palestina        1
# Viterbo          7
# Manizales      535
# Salamina         3
# Supía           20
# Aguadas         44
# Name: Total casos, dtype: int64

# %%
Total_casos_dpto = Total_casos.sum()

Total_casos_dpto
# Out:
# 1023

# %% [markdown]
# #### Aplicar filtro propuesto en variable "estado" por Departamento o Municipio

# %%
hoy = pd.Timestamp.today()

# %%
filtro= Tasas[variable_buscar]== estado
if municipio == '':
    Cuadro_filtrados = Tasas.loc[filtro, 'Atención': 'Tipo recuperación'].loc[(Tasas['Dpto'] == departamento)]
    numero_estados= Cuadro_filtrados.loc[:, variable_buscar].count()
    print('Según datos reportados al ', hoy, ' por el INS Colombiano, de los ' + str(Total_casos_dpto)
          + ' casos de '+ departamento + ', ' + str(numero_estados) +' casos, es decir el '
          + str(((numero_estados/Total_casos_dpto)*100).round(2))+' %, está en condición: '
          + variable_buscar + ' ' + estado + ' y representan el ' 
          + str(((numero_estados/Col.loc[(departamento),'2020'].sum())*100).round(6)) 
          + ' %  de los '+ str(Col.loc[(departamento),'2020'].sum()) + ' habitantes de ' + departamento)
   
    print('La tasa de mortalidad en los municipios del Departamento de ' + departamento + ' por cien mil habitantes es: '
          + str(((Fallecidos_dpto_munic/poblacionDpto)*100000).round(2)))
    
    print('La tasa de letalidad en los municipios del Departamento de ' + departamento + 
          ' por cien enfermos de CoVid-19, es: ' + str(((Fallecidos_dpto_munic/Total_casos)*100).round(2)))

else:
    Cuadro_filtrados = Tasas.loc[filtro, 'Atención': 'Tipo recuperación'].loc[(Tasas['Dpto'] == departamento) & (Tasas['Municipio']== municipio)]
    numero_estados= Cuadro_filtrados.loc[:, variable_buscar].count()
    print('Según datos reportados al', hoy, 'por el INS Colombiano, de los ' + str(Total_casos) + ' casos de '+ municipio + ', ' 
          + str(numero_estados) +' casos, es decir el '+ str(((numero_estados/Total_casos)*100).round(2))
          +' %, están en '+ variable_buscar + ': ' + estado + ' y representan el '
          + str(((numero_estados/Poblacion_dpto_munic.sum())*100).round(6)) 
          + ' % de los ' + str(Poblacion_dpto_munic.sum()) + ' habitantes de ' + municipio +'.','\n')
    
    print('La tasa de letalidad en el municipio de '+ municipio + ',' + ' Departamento de ' 
          + departamento + ' es de ' + str(((Fallecidos_dpto_munic/Total_casos)*100).round(2)) 
          + ' por cien enfermos de CoVid-19.','\n')
    
    print('La tasa de mortalidad en el municipio de '+ municipio + ',' + ' Departamento de ' 
          + departamento + ' es de ' + str(((Fallecidos_dpto_munic/Poblacion_dpto_munic)*100000).round(2)) 
          + ' por cien mil habitantes.','\n')
    
print('La tasa de mortalidad de ' + pais+ ' por CoV-2 ' + 'es de ' + str(((Fallecidos_pais/Poblacion_pais)*1000000).round(1))+ ' por millón de habitantes.','\n')

print('La tasa de letalidad de '+pais+ ' por CoV-2 ' + 'es de ' + str(((Fallecidos_pais/total_casos_covid_colombia)*100).round(2))+ ' por cien enfermos de CoVid-19.','\n')
# Out:
# Según datos reportados al  2020-08-03 14:48:07.782199  por el INS Colombiano, de los 1023 casos de Caldas, 10 casos, es decir el 0.98 %, está en condición: Atención Hospital UCI y representan el 0.000982 %  de los 1018453 habitantes de Caldas
# La tasa de mortalidad en los municipios del Departamento de Caldas por cien mil habitantes es: Municipio
# Marmato        0.00
# Aranzazu       0.00
# Manzanares     0.10
# Norcasia       0.10
# Marquetalia    0.00
# Chinchiná      0.10
# Belalcázar     0.00
# Neira          0.20
# La Dorada      0.29
# Riosucio       0.00
# Samaná         0.00
# Anserma        0.00
# Risaralda      0.00
# Villamaría     0.20
# Pácora         0.00
# Palestina      0.00
# Viterbo        0.00
# Manizales      0.59
# Salamina       0.00
# Supía          0.20
# Aguadas        0.00
# Name: Fallecidos, dtype: float64
# La tasa de letalidad en los municipios del Departamento de Caldas por cien enfermos de CoVid-19, es: Municipio
# Marmato          0.00
# Aranzazu         0.00
# Manzanares       5.88
# Norcasia       100.00
# Marquetalia      0.00
# Chinchiná        2.04
# Belalcázar       0.00
# Neira           16.67
# La Dorada        1.66
# Riosucio         0.00
# Samaná           0.00
# Anserma          0.00
# Risaralda        0.00
# Villamaría       4.76
# Pácora           0.00
# Palestina        0.00
# Viterbo          0.00
# Manizales        1.12
# Salamina         0.00
# Supía           10.00
# Aguadas          0.00
# dtype: float64
# La tasa de mortalidad de Colombia por CoV-2 es de 219.1 por millón de habitantes.
#
# La tasa de letalidad de Colombia por CoV-2 es de 3.51 por cien enfermos de CoVid-19.
