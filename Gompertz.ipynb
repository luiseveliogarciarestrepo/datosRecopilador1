# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 500)

# %%
gompertz = pd.read_csv('CovidColombia.csv', low_memory=False, usecols= ['ID de caso', 'Fecha de notificación', 
                                                                        'Ciudad de ubicación', 
                                                                        'Departamento o Distrito '], 
                                                                        parse_dates=['Fecha de notificación'] )

# %%
gompertz.sort_values(by=['Fecha de notificación'],inplace=True)

# %%
df = pd.DataFrame(gompertz['Fecha de notificación']).loc[0]

# %%
a = gompertz.loc[0,'Fecha de notificación']

# %%
b = np.datetime64('today') 
b
# Out:
# numpy.datetime64('2020-07-24')

# %%
longitud = (b-a)/ np.timedelta64(1, 'D')
longitud=int(longitud)-1
longitud
# Out:
# 143

# %%
df_fechas = pd.DataFrame(df).transpose()
df_fechas
# Out:
#   Fecha de notificación
# 0            2020-03-02

# %%
df_fechas['ID de caso']=0

# %%
df_fechas
# Out:
#   Fecha de notificación  ID de caso
# 0            2020-03-02           0

# %%
pd.to_datetime([df_fechas.loc[0,'Fecha de notificación']])
# Out:
# DatetimeIndex(['2020-03-02'], dtype='datetime64[ns]', freq=None)

# %%
(np.datetime64(df_fechas.loc[0, 'Fecha de notificación']) + np.timedelta64(1,'D'))
# Out:
# numpy.datetime64('2020-03-03T00:00:00.000000')

# %%
for i in range(1,longitud):
    df_fechas.loc[(i)] = [(np.datetime64(df_fechas.loc[i-1, 'Fecha de notificación']) + np.timedelta64(1,'D')),0]

# %%
df_fechas
# Out:
#     Fecha de notificación  ID de caso
# 0              2020-03-02           0
# 1              2020-03-03           0
# 2              2020-03-04           0
# 3              2020-03-05           0
# 4              2020-03-06           0
# 5              2020-03-07           0
# 6              2020-03-08           0
# 7              2020-03-09           0
# 8              2020-03-10           0
# 9              2020-03-11           0
# 10             2020-03-12           0
# 11             2020-03-13           0
# 12             2020-03-14           0
# 13             2020-03-15           0
# 14             2020-03-16           0
# 15             2020-03-17           0
# 16             2020-03-18           0
# 17             2020-03-19           0
# 18             2020-03-20           0
# 19             2020-03-21           0
# 20             2020-03-22           0
# 21             2020-03-23           0
# 22             2020-03-24           0
# 23             2020-03-25           0
# ...

# %%
gompertz
# Out:
#         ID de caso Fecha de notificación  Ciudad de ubicación  \
# 0                1            2020-03-02          Bogotá D.C.
# 1                2            2020-03-06  Guadalajara de Buga
# 2                3            2020-03-07             Medellín
# 6                7            2020-03-08  Cartagena de Indias
# 8                9            2020-03-08          Bogotá D.C.
# ...            ...                   ...                  ...
# 225480      225521            2020-07-22             Medellín
# 225470      225511            2020-07-22             Medellín
# 225582      225623            2020-07-22                Pasto
# 225919      225960            2020-07-23  Cartagena de Indias
# 225782      225823            2020-07-23  Cartagena de Indias
#
#        Departamento o Distrito
# 0                   Bogotá D.C.
# 1               Valle del Cauca
# 2                     Antioquia
# 6           Cartagena D.T. y C.
# 8                   Bogotá D.C.
# ...

# %%
gompertz_final=gompertz.append(df_fechas).sort_values(by=['Fecha de notificación'], ignore_index=True)

# %%
gompertz_final
# Out:
#         ID de caso Fecha de notificación  Ciudad de ubicación  \
# 0                1            2020-03-02          Bogotá D.C.
# 1                0            2020-03-02                  NaN
# 2                0            2020-03-03                  NaN
# 3                0            2020-03-04                  NaN
# 4                0            2020-03-05                  NaN
# ...            ...                   ...                  ...
# 226511      225757            2020-07-22             Sabaneta
# 226512      225754            2020-07-22             Buriticá
# 226513      225624            2020-07-22                Pasto
# 226514      225823            2020-07-23  Cartagena de Indias
# 226515      225960            2020-07-23  Cartagena de Indias
#
#        Departamento o Distrito
# 0                   Bogotá D.C.
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...

# %%
longitud1 = gompertz_final['ID de caso'].size
longitud1
# Out:
# 226516

# %%
gompertz_final.columns
# Out:
# Index(['ID de caso', 'Fecha de notificación', 'Ciudad de ubicación',
#        'Departamento o Distrito '],
#       dtype='object')

# %%
for i in range(0, longitud1):
    if gompertz_final.loc[i, 'ID de caso'] == 0:
        pass
    else:
        gompertz_final.loc[i, 'ID de caso'] = 1

# %%
gompertz_final
# Out:
#         ID de caso Fecha de notificación  Ciudad de ubicación  \
# 0                1            2020-03-02          Bogotá D.C.
# 1                0            2020-03-02                  NaN
# 2                0            2020-03-03                  NaN
# 3                0            2020-03-04                  NaN
# 4                0            2020-03-05                  NaN
# ...            ...                   ...                  ...
# 226511           1            2020-07-22             Sabaneta
# 226512           1            2020-07-22             Buriticá
# 226513           1            2020-07-22                Pasto
# 226514           1            2020-07-23  Cartagena de Indias
# 226515           1            2020-07-23  Cartagena de Indias
#
#        Departamento o Distrito
# 0                   Bogotá D.C.
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...

# %%
gompertz_final['Acumulados']= 0
gompertz_final['Día número']=0
gompertz_final['Penetración real']=0
gompertz_final
# Out:
#         ID de caso Fecha de notificación  Ciudad de ubicación  \
# 0                1            2020-03-02          Bogotá D.C.
# 1                0            2020-03-02                  NaN
# 2                0            2020-03-03                  NaN
# 3                0            2020-03-04                  NaN
# 4                0            2020-03-05                  NaN
# ...            ...                   ...                  ...
# 226511           1            2020-07-22             Sabaneta
# 226512           1            2020-07-22             Buriticá
# 226513           1            2020-07-22                Pasto
# 226514           1            2020-07-23  Cartagena de Indias
# 226515           1            2020-07-23  Cartagena de Indias
#
#        Departamento o Distrito   Acumulados  Día número  Penetración real
# 0                   Bogotá D.C.           0           0                 0
# ...

# %%
gompertz_final.index
# Out:
# RangeIndex(start=0, stop=226516, step=1)

# %%
longitud2 = trabajo['Casos Notificados diarios'].size
longitud2

# %%
trabajo.loc[0, 'Acumulados']= trabajo.loc[0, 'Casos Notificados diarios']
for i in range(1, longitud2):
    trabajo.loc[i,'Acumulados'] = trabajo.loc[i, 'Casos Notificados diarios'] + trabajo.loc[i-1, 'Acumulados']

# %%
trabajo

# %%
trabajo.loc[longitud2-1, 'Acumulados']

# %%
trabajo.loc[0, 'Día número'] = 1
for i in range(1, longitud2):
    trabajo.loc[i,'Penetración real'] = trabajo.loc[i, 'Acumulados']/ trabajo.loc[longitud2-1, 'Acumulados']
    trabajo.loc[i,'Día número'] = i+1

# %%
trabajo

# %%
#trabajo.to_excel('datosTotalesparaGompertz1.xlsx')
trabajo.to_excel('datosTotalesparaGompertzDpto1.xlsx')
#trabajo.to_excel('datosTotalesparaGompertzCiudad1.xlsx')
