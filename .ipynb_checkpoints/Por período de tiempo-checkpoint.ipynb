# %%
import pandas as pd
import datetime

# %%
pd.set_option('display.max_rows', 1000)

# %%
df = pd.read_csv('CovidColombia.csv', parse_dates =['Fecha de notificación','Fecha de muerte', 'Fecha diagnostico', 'Fecha recuperado',
       'fecha reporte web'])

# %%
df.drop(columns = ['ID de caso', 'Código DIVIPOLA','FIS','Codigo departamento','Codigo pais'], inplace=True)

# %%
df.columns
# Out:
# Index(['Fecha de notificación', 'Ciudad de ubicación',
#        'Departamento o Distrito ', 'atención', 'Edad', 'Sexo', 'Tipo',
#        'Estado', 'País de procedencia', 'Fecha de muerte', 'Fecha diagnostico',
#        'Fecha recuperado', 'fecha reporte web', 'Tipo recuperación',
#        'Pertenencia etnica', 'Nombre grupo etnico'],
#       dtype='object')

# %%
df = df.set_index('Fecha de notificación').loc['Envigado']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-5e6f7182670c> in <module>
# ----> 1 df = df.set_index('Fecha de notificación').loc['Envigado']
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Fecha de notificación'] are in the columns"

# %%
df
# Out:
#                        Ciudad de ubicación Departamento o Distrito   \
# Fecha de notificación
# 2020-03-02                     Bogotá D.C.              Bogotá D.C.
# 2020-03-06             Guadalajara de Buga          Valle del Cauca
# 2020-03-07                        Medellín                Antioquia
# 2020-03-09                        Medellín                Antioquia
# 2020-03-09                        Medellín                Antioquia
# ...                                    ...                      ...
# 2020-06-29                     Bogotá D.C.              Bogotá D.C.
# 2020-07-01                     Bogotá D.C.              Bogotá D.C.
# 2020-06-26                     Bogotá D.C.              Bogotá D.C.
# 2020-06-27                     Bogotá D.C.              Bogotá D.C.
# 2020-05-16                     Bogotá D.C.              Bogotá D.C.
#
#                          atención  Edad Sexo         Tipo Estado  \
# Fecha de notificación
# ...

# %%
df['2020']['Edad'].mean()
# Out:
# 39.384124442233244

# %%
df.columns
# Out:
# Index(['Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
#        'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'Fecha de muerte',
#        'Fecha diagnostico', 'Fecha recuperado', 'fecha reporte web',
#        'Tipo recuperación', 'Pertenencia etnica', 'Nombre grupo etnico'],
#       dtype='object')

# %%
df.resample('W').agg({'Edad': 'max'})
# Out:
#                             Edad
# Fecha de notificación
# 2020-03-08             43.200000
# 2020-03-15             40.423077
# 2020-03-22             42.372038
# 2020-03-29             42.362390
# 2020-04-05             44.398319
# 2020-04-12             41.789954
# 2020-04-19             39.724547
# 2020-04-26             38.715066
# 2020-05-03             38.492664
# 2020-05-10             38.341856
# 2020-05-17             38.051416
# 2020-05-24             38.914744
# 2020-05-31             38.697165
# 2020-06-07             38.996636
# 2020-06-14             39.348132
# 2020-06-21             39.491734
# 2020-06-28             39.570673
# 2020-07-05             40.285950
# 2020-07-12             40.089947

# %%
df['Edad'].agg(['median', 'mean', 'max', 'min']).loc['']
# Out:
# median     37.000000
# mean       39.384124
# max       111.000000
# min         0.000000
# Name: Edad, dtype: float64

# %%
# %matplotlib inline

# %%
variable = df['Edad'].resample('D').agg(['median', 'mean','max', 'min'])

# %%
variable.plot()
