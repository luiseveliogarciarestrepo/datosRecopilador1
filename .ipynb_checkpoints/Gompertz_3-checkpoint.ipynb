# %%
import pandas as pd
import numpy as np

# %%
gompertz = pd.read_csv('CovidColombia.csv', low_memory=False, usecols= ['ID de caso', 'Fecha de notificación', 
                                                                        'Ciudad de ubicación', 
                                                                        'Departamento o Distrito '], 
                                                                        parse_dates=['Fecha de notificación'] )

# %%
gompertz.dtypes
# Out:
# ID de caso                           int64
# Fecha de notificación       datetime64[ns]
# Ciudad de ubicación                 object
# Departamento o Distrito             object
# dtype: object

# %%
gompertz.loc[0,'Fecha de notificación'].date()
# Out:
# datetime.date(2020, 3, 2)

# %%
filtro = gompertz.loc[0,'Fecha de notificación'].date() == gompertz.loc[1,'Fecha de notificación'].date() 
filtro
# Out:
# False

# %%
new_rows =[]
for i in range(0,gompertz['ID de caso'].size):
    if filtro==True:
        pass
    else:
        new_row= (pd.to_datetime(np.datetime64(gompertz.loc[i,'Fecha de notificación']) + np.timedelta64(1,'D')))
        #new_row.to_pydatetime()
        new_rows.append(new_row)
new_rows
# Out:
# [Timestamp('2020-03-03 00:00:00'),
#  Timestamp('2020-03-07 00:00:00'),
#  Timestamp('2020-03-08 00:00:00'),
#  Timestamp('2020-03-10 00:00:00'),
#  Timestamp('2020-03-10 00:00:00'),
#  Timestamp('2020-03-11 00:00:00'),
#  Timestamp('2020-03-09 00:00:00'),
#  Timestamp('2020-03-10 00:00:00'),
#  Timestamp('2020-03-09 00:00:00'),
#  Timestamp('2020-03-13 00:00:00'),
#  Timestamp('2020-03-12 00:00:00'),
#  Timestamp('2020-03-11 00:00:00'),
#  Timestamp('2020-03-11 00:00:00'),
#  Timestamp('2020-03-11 00:00:00'),
#  Timestamp('2020-03-14 00:00:00'),
#  Timestamp('2020-03-12 00:00:00'),
#  Timestamp('2020-03-12 00:00:00'),
#  Timestamp('2020-03-12 00:00:00'),
#  Timestamp('2020-03-13 00:00:00'),
#  Timestamp('2020-03-12 00:00:00'),
#  Timestamp('2020-03-12 00:00:00'),
#  Timestamp('2020-03-13 00:00:00'),
#  Timestamp('2020-03-13 00:00:00'),
#  Timestamp('2020-03-13 00:00:00'),
#  Timestamp('2020-03-14 00:00:00'),
#  Timestamp('2020-03-16 00:00:00'),
#  Timestamp('2020-03-16 00:00:00'),
# ...

# %%
gompertz.append()

# %%
diferencia_dias=((gompertz.loc[(1),'Fecha de notificación']- gompertz.loc[0,'Fecha de notificación']).days)
diferencia_dias
# Out:
# 4

# %%
new_row = pd.DataFrame(1, columns = ['ID de caso'], index=[row_to_add])
new_row
# Out:
#             ID de caso
# 2020-03-03           1

# %%
gompertz.set_index('Fecha de notificación', inplace=True)

# %%
gompertz=pd.concat([gompertz, pd.DataFrame(new_row)], ignore_index=False)

# %%
gompertz.sort_index(inplace=True)
gompertz
# Out:
#             ID de caso     Ciudad de ubicación Departamento o Distrito
# 2020-03-02           1             Bogotá D.C.              Bogotá D.C.
# 2020-03-03           1                     NaN                      NaN
# 2020-03-06           2     Guadalajara de Buga          Valle del Cauca
# 2020-03-07           3                Medellín                Antioquia
# 2020-03-08           7     Cartagena de Indias      Cartagena D.T. y C.
# ...                ...                     ...                      ...
# 2020-07-17      177713  Santa Bárbara de Pinto                Magdalena
# 2020-07-17      177474         Barrancabermeja                Santander
# 2020-07-17      177475         Barrancabermeja                Santander
# 2020-07-17      177466                Medellín                Antioquia
# 2020-07-17      177557               Sincelejo                    Sucre
#
# [182141 rows x 3 columns]
