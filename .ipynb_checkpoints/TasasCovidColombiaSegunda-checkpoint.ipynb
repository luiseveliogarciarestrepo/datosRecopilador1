# %% [raw]
# # Bases de datos
#
# Para los análisis se toman las bases de datos, última actualización, de organizaciones internacionales y nacionales:
#
#     - ONU
#     - OMS
#     - INS
#     - DANE

# %% [markdown]
# ### Variables para análisis:

# %%
pais = 'Colombia'

departamento = 'Caldas'

municipio = ''

variable_buscar = 'Atención'  # puede ser 'Atención' o 'Estado'

estado = 'Hospital UCI'  # Si atención:  ['Recuperado', 'Hospital', 'Hospital UCI', nan, 'Casa']
                   # Si Estado:   ['Leve', 'Asintomático', 'Fallecido', 'Moderado', 'Grave', nan]

ano = '2020'

fechaInicial = '2020-08-01'

fechaFinal = '2020-08-31'

# %%
import pandas as pd
pd.set_option("display.precision", 2)
pd.set_option('display.max_rows',100)

from matplotlib import pyplot as plt
#print(plt.style.available)
#plt.style.use('fivethirtyeight')
plt.xkcd()
from textwrap import wrap

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Población mundial por países y proyección 2020  a 2100

# %%
#mundo= pd.read_csv('poblacionMundial.csv', usecols= ['Country', '2020', 'Spanish'])

#mundo.set_index('Spanish', inplace=True)
#mundo

# %% [markdown]
# ## Total casos y número de fallecidos por país

# %%
#covMun= pd.read_csv('CovidMundoT.csv', usecols= ['País', 'Total_Casos','Fallecidos'])
#covMun

# %% [markdown]
# ## Total casos y número de fallecidos Colombia por fecha, departamento, municipio, atención, edad, género, fechas de diagnóstico, recuperación o muerte.

# %%
covCol = pd.read_csv('CovidColombia.csv', usecols= ['Fecha de notificación', 
       'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
       'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'Fecha recuperado', 'Fecha diagnostico','Fecha de muerte', 
       'Tipo recuperación'], parse_dates = ['Fecha de notificación','Fecha de muerte', 'Fecha diagnostico','Fecha recuperado'], low_memory=False)

covCol['Fecha de muerte'] = pd.to_datetime(covCol['Fecha de muerte'], errors='coerce')

fechas =['Fecha de notificación']
for i in fechas:
    covCol[i] = pd.to_datetime(covCol[i])

cuadro_basico = covCol    
    
covCol
# Out:
#        Fecha de notificación  Ciudad de ubicación Departamento o Distrito   \
# 0                 2020-03-02          Bogotá D.C.              Bogotá D.C.
# 1                 2020-03-06  Guadalajara de Buga          Valle del Cauca
# 2                 2020-03-07             Medellín                Antioquia
# 3                 2020-03-09             Medellín                Antioquia
# 4                 2020-03-09             Medellín                Antioquia
# ...                      ...                  ...                      ...
# 666516            2020-08-29                 Cali          Valle del Cauca
# 666517            2020-08-28                 Cali          Valle del Cauca
# 666518            2020-08-24                 Cali          Valle del Cauca
# 666519            2020-08-28                 Cali          Valle del Cauca
# 666520            2020-08-28                 Cali          Valle del Cauca
#
#           atención  Edad Sexo         Tipo Estado País de procedencia  \
# 0       Recuperado    19    F    Importado   Leve              ITALIA
# 1       Recuperado    34    M    Importado   Leve              ESPAÑA
# 2       Recuperado    50    F    Importado   Leve              ESPAÑA
# 3       Recuperado    55    M  Relacionado   Leve                 NaN
# 4       Recuperado    25    M  Relacionado   Leve                 NaN
# ...            ...   ...  ...          ...    ...                 ...
# 666516        Casa    86    M   En estudio   Leve                 NaN
# 666517        Casa    58    M   En estudio   Leve                 NaN
# 666518        Casa    38    F   En estudio   Leve                 NaN
# 666519        Casa    68    M   En estudio   Leve                 NaN
# 666520        Casa    39    F   En estudio   Leve                 NaN
#
#        Fecha de muerte Fecha diagnostico Fecha recuperado Tipo recuperación
# 0                  NaT        2020-03-06       2020-03-13               PCR
# 1                  NaT        2020-03-09       2020-03-19               PCR
# 2                  NaT        2020-03-09       2020-03-15               PCR
# 3                  NaT        2020-03-11       2020-03-26               PCR
# 4                  NaT        2020-03-11       2020-03-23               PCR
# ...                ...               ...              ...               ...
# 666516             NaT        2020-08-30              NaT               NaN
# 666517             NaT        2020-08-30              NaT               NaN
# 666518             NaT        2020-08-30              NaT               NaN
# 666519             NaT        2020-08-30              NaT               NaN
# 666520             NaT        2020-08-30              NaT               NaN
#
# [666521 rows x 13 columns]

# %% [markdown]
# ### Última fecha de notificación

# %%
covCol['Fecha de notificación'].max()
# Out:
# Timestamp('2020-09-05 00:00:00')

# %%
filtrofechas = (covCol['Fecha de notificación']>= fechaInicial) & (covCol['Fecha de notificación']<= fechaFinal)
covCol1 = covCol.loc[filtrofechas]
covCol1
# Out:
#        Fecha de notificación Ciudad de ubicación Departamento o Distrito   \
# 102233            2020-08-24            Mosquera             Cundinamarca
# 194707            2020-08-01         Bogotá D.C.              Bogotá D.C.
# 209531            2020-08-16              Cúcuta       Norte de Santander
# 220942            2020-08-08               Pasto                   Nariño
# 221122            2020-08-10              Cúcuta       Norte de Santander
# ...                      ...                 ...                      ...
# 666516            2020-08-29                Cali          Valle del Cauca
# 666517            2020-08-28                Cali          Valle del Cauca
# 666518            2020-08-24                Cali          Valle del Cauca
# 666519            2020-08-28                Cali          Valle del Cauca
# 666520            2020-08-28                Cali          Valle del Cauca
#
#           atención  Edad Sexo        Tipo    Estado País de procedencia  \
# 102233  Recuperado    27    F  En estudio      Leve                 NaN
# 194707  Recuperado    74    M  En estudio  Moderado                 NaN
# 209531  Recuperado    26    F  En estudio      Leve                 NaN
# 220942  Recuperado    29    F  En estudio      Leve                 NaN
# 221122  Recuperado    48    M  En estudio      Leve                 NaN
# ...            ...   ...  ...         ...       ...                 ...
# 666516        Casa    86    M  En estudio      Leve                 NaN
# 666517        Casa    58    M  En estudio      Leve                 NaN
# 666518        Casa    38    F  En estudio      Leve                 NaN
# 666519        Casa    68    M  En estudio      Leve                 NaN
# 666520        Casa    39    F  En estudio      Leve                 NaN
#
#        Fecha de muerte Fecha diagnostico Fecha recuperado Tipo recuperación
# 102233             NaT        2020-09-04       2020-08-31            Tiempo
# 194707             NaT        2020-08-11       2020-08-12               PCR
# 209531             NaT        2020-08-20       2020-08-30            Tiempo
# 220942             NaT               NaT       2020-09-01            Tiempo
# 221122             NaT        2020-08-27       2020-08-31            Tiempo
# ...                ...               ...              ...               ...
# 666516             NaT        2020-08-30              NaT               NaN
# 666517             NaT        2020-08-30              NaT               NaN
# 666518             NaT        2020-08-30              NaT               NaN
# 666519             NaT        2020-08-30              NaT               NaN
# 666520             NaT        2020-08-30              NaT               NaN
#
# [256658 rows x 13 columns]

# %% [markdown]
# ## Población Colombia por departamento, municipio y género proyectada para el año 2020.

# %%
Col = pd.read_csv('Dane2018_2023.csv').drop(columns = ['2018',
       '2019','2021', '2022', '2023' ])
Col
# Out:
#            Dpto  Municipio       Género      2020
# 0     Antioquia   Medellín  AMBOS SEXOS   2533424
# 1     Antioquia   Medellín      HOMBRES   1193791
# 2     Antioquia   Medellín      MUJERES   1339633
# 3     Antioquia  Abejorral  AMBOS SEXOS     20287
# 4     Antioquia  Abejorral      HOMBRES     10558
# ...         ...        ...          ...       ...
# 3364    Vichada   Cumaribo      HOMBRES     41840
# 3365    Vichada   Cumaribo      MUJERES     37023
# 3366   País_Col   País_Col  AMBOS SEXOS  50372424
# 3367   País_Col   País_Col      HOMBRES  24594882
# 3368   País_Col   País_Col      MUJERES  25777542
#
# [3369 rows x 4 columns]

# %% [markdown]
# #### Poblaciones

# %% [markdown]
# #### Colombia

# %%
Poblacion_pais = 50883000
Poblacion_pais
# Out:
# 50883000

# %% [markdown]
# #### Total casos COVID-19

# %%
total_casos_covid_colombia = covCol1['Fecha de notificación'].count()
total_casos_covid_colombia
# Out:
# 256658

# %% [markdown]
# #### Total Fallecidos por COVID-19

# %%
Fallecidos_pais = covCol1['Fecha de muerte'].count()
Fallecidos_pais
# Out:
# 6678

# %%
filtro = Col['Género'] == 'AMBOS SEXOS'
Col = Col.loc[filtro, :].drop(columns=['Género'])

Col.set_index(['Dpto', 'Municipio'], inplace=True)

# %%
covCol1= covCol1.rename(columns={"Departamento o Distrito ": "Dpto", "Ciudad de ubicación": "Municipio", "atención":"Atención", "Fecha diagnostico":"Fecha diagnóstico"})

# %%
covCol1.set_index(['Dpto', 'Municipio'], inplace = True)

# %% [markdown]
# #### Casos y poblaciones por departamento y municipio

# %%
Tasas = pd.merge(covCol1, Col, left_index=True, right_index=True).reset_index()

Tasas
# Out:
#             Dpto       Municipio Fecha de notificación    Atención  Edad Sexo  \
# 0       Amazonas         Leticia            2020-08-04  Recuperado    32    F
# 1       Amazonas         Leticia            2020-08-03  Recuperado    27    M
# 2       Amazonas         Leticia            2020-08-02  Recuperado    48    F
# 3       Amazonas         Leticia            2020-08-03  Recuperado    23    F
# 4       Amazonas         Leticia            2020-08-03  Recuperado    54    M
# ...          ...             ...                   ...         ...   ...  ...
# 245470   Vichada  Puerto Carreño            2020-08-25        Casa    37    M
# 245471   Vichada  Puerto Carreño            2020-08-25        Casa    23    M
# 245472   Vichada  Puerto Carreño            2020-08-25        Casa    24    M
# 245473   Vichada  Puerto Carreño            2020-08-25        Casa    35    M
# 245474   Vichada  Puerto Carreño            2020-08-25        Casa    42    M
#
#               Tipo Estado País de procedencia Fecha de muerte  \
# 0       En estudio   Leve                 NaN             NaT
# 1       En estudio   Leve                 NaN             NaT
# 2       En estudio   Leve                 NaN             NaT
# 3       En estudio   Leve                 NaN             NaT
# 4       En estudio   Leve                 NaN             NaT
# ...            ...    ...                 ...             ...
# 245470  En estudio   Leve                 NaN             NaT
# 245471  En estudio   Leve                 NaN             NaT
# 245472  En estudio   Leve                 NaN             NaT
# 245473  En estudio   Leve                 NaN             NaT
# 245474  En estudio   Leve                 NaN             NaT
#
#        Fecha diagnóstico Fecha recuperado Tipo recuperación   2020
# 0                    NaT       2020-08-26            Tiempo  49737
# 1             2020-08-09       2020-08-27            Tiempo  49737
# 2             2020-08-09       2020-08-26            Tiempo  49737
# 3             2020-08-09       2020-08-25            Tiempo  49737
# 4             2020-08-09       2020-08-25            Tiempo  49737
# ...                  ...              ...               ...    ...
# 245470        2020-09-05              NaT               NaN  20294
# 245471        2020-09-05              NaT               NaN  20294
# 245472        2020-09-05              NaT               NaN  20294
# 245473        2020-09-05              NaT               NaN  20294
# 245474        2020-09-05              NaT               NaN  20294
#
# [245475 rows x 14 columns]

# %% [markdown]
# #### Municipios con casos reportados por SARS CoV-2 a:

# %%
pd.Timestamp.today()
# Out:
# Timestamp('2020-09-07 14:18:46.895566')

# %%
Tasas['Municipio'].unique()
# Out:
# array(['Leticia', 'Abejorral', 'Abriaquí', 'Alejandría', 'Amagá',
#        'Amalfi', 'Andes', 'Angostura', 'Anorí', 'Apartadó', 'Arboletes',
#        'Argelia', 'Armenia', 'Barbosa', 'Bello', 'Betania', 'Buriticá',
#        'Caicedo', 'Caldas', 'Campamento', 'Caramanta', 'Carepa',
#        'Carolina', 'Caucasia', 'Cañasgordas', 'Chigorodó', 'Cisneros',
#        'Ciudad Bolívar', 'Cocorná', 'Concepción', 'Copacabana', 'Cáceres',
#        'Dabeiba', 'Ebéjico', 'El Bagre', 'El Carmen de Viboral',
#        'El Santuario', 'Envigado', 'Fredonia', 'Frontino', 'Giraldo',
#        'Girardota', 'Granada', 'Guadalupe', 'Guarne', 'Guatapé',
#        'Gómez Plata', 'Heliconia', 'Ituango', 'Jardín', 'Jericó',
#        'La Ceja', 'La Estrella', 'La Pintada', 'La Unión', 'Liborina',
#        'Maceo', 'Marinilla', 'Medellín', 'Murindó', 'Mutatá', 'Nechí',
#        'Necoclí', 'Olaya', 'Peque', 'Peñol', 'Puerto Berrío',
#        'Puerto Nare', 'Puerto Triunfo', 'Remedios', 'Retiro', 'Rionegro',
#        'Sabanalarga', 'Sabaneta', 'Salgar', 'San Andrés de Cuerquía',
#        'San Carlos', 'San Francisco', 'San Jerónimo', 'San Juan de Urabá',
#        'San Luis', 'San Pedro de Urabá', 'San Rafael', 'San Roque',
#        'Santa Bárbara', 'Santa Rosa de Osos', 'Santo Domingo', 'Segovia',
#        'Sonsón', 'Sopetrán', 'Tarazá', 'Tarso', 'Titiribí', 'Toledo',
#        'Turbo', 'Támesis', 'Uramita', 'Urrao', 'Valdivia', 'Valparaíso',
#        'Vegachí', 'Venecia', 'Vigía del Fuerte', 'Yarumal', 'Yolombó',
#        'Yondó', 'Zaragoza', 'Arauca', 'Arauquita', 'Fortul', 'Saravena',
#        'Tame', 'Providencia', 'San Andrés', 'Baranoa', 'Candelaria',
#        'Galapa', 'Juan de Acosta', 'Luruaco', 'Malambo', 'Manatí',
#        'Palmar de Varela', 'Piojó', 'Polonuevo', 'Ponedera',
#        'Puerto Colombia', 'Repelón', 'Sabanagrande', 'Santa Lucía',
#        'Santo Tomás', 'Soledad', 'Suan', 'Tubará', 'Usiacurí',
#        'Barranquilla', 'Bogotá D.C.', 'Achí', 'Altos del Rosario',
#        'Arenal', 'Arjona', 'Arroyohondo', 'Barranco de Loba', 'Calamar',
#        'Cantagallo', 'Cicuco', 'Clemencia', 'Córdoba',
#        'El Carmen de Bolívar', 'El Guamo', 'El Peñón', 'Hatillo de Loba',
#        'Magangué', 'Mahates', 'Mompós', 'Montecristo', 'Morales',
#        'Norosí', 'Pinillos', 'Regidor', 'San Cristóbal', 'San Estanislao',
#        'San Fernando', 'San Jacinto', 'San Jacinto del Cauca',
#        'San Juan Nepomuceno', 'San Martín de Loba', 'San Pablo',
#        'Santa Catalina', 'Santa Rosa', 'Santa Rosa del Sur', 'Simití',
#        'Soplaviento', 'Talaigua Nuevo', 'Tiquisio', 'Turbaco', 'Turbaná',
#        'Villanueva', 'Zambrano', 'Aquitania', 'Arcabuco', 'Belén',
#        'Boavita', 'Boyacá', 'Briceño', 'Buenavista', 'Cerinza',
#        'Chiquinquirá', 'Chiscas', 'Chita', 'Chitaraque', 'Chivatá',
#        'Chivor', 'Chíquiza', 'Ciénega', 'Coper', 'Corrales', 'Covarachía',
#        'Cubará', 'Cucaita', 'Cómbita', 'Duitama', 'El Cocuy', 'El Espino',
#        'Firavitoba', 'Gachantivá', 'Garagoa', 'Guacamayas', 'Guateque',
#        'Guayatá', 'Jenesano', 'Macanal', 'Maripí', 'Miraflores', 'Monguí',
#        'Moniquirá', 'Motavita', 'Muzo', 'Nobsa', 'Nuevo Colón', 'Oicatá',
#        'Otanche', 'Pachavita', 'Paipa', 'Pajarito', 'Panqueba', 'Pauna',
#        'Paz de Río', 'Pesca', 'Puerto Boyacá', 'Quípama', 'Ramiriquí',
#        'Ráquira', 'Saboyá', 'Samacá', 'San José de Pare',
#        'San Luis de Gaceno', 'San Pablo de Borbur', 'Santa María',
#        'Santa Rosa de Viterbo', 'Santa Sofía', 'Santana', 'Sativanorte',
#        'Sativasur', 'Siachoque', 'Soatá', 'Socha', 'Sogamoso', 'Soracá',
#        'Sotaquirá', 'Sutamarchán', 'Tenza', 'Tibasosa', 'Tinjacá',
#        'Tipacoque', 'Toca', 'Togüí', 'Tota', 'Tunja', 'Tuta', 'Tópaga',
#        'Ventaquemada', 'Villa de Leyva', 'Zetaquira', 'Buenaventura',
#        'Aguadas', 'Anserma', 'Aranzazu', 'Belalcázar', 'Chinchiná',
#        'Filadelfia', 'La Dorada', 'La Merced', 'Manizales', 'Manzanares',
#        'Marmato', 'Marquetalia', 'Neira', 'Norcasia', 'Palestina',
#        'Pácora', 'Riosucio', 'Risaralda', 'Salamina', 'Samaná',
#        'San José', 'Supía', 'Victoria', 'Villamaría', 'Viterbo',
#        'Albania', 'Cartagena del Chairá', 'Curillo', 'El Doncello',
#        'Florencia', 'La Montañita', 'Milán', 'Morelia', 'Puerto Rico',
#        'San José del Fragua', 'San Vicente del Caguán', 'Solano',
#        'Solita', 'Cartagena de Indias', 'Aguazul', 'Hato Corozal', 'Maní',
#        'Monterrey', 'Orocué', 'Paz de Ariporo', 'Pore', 'Recetor',
#        'San Luis de Palenque', 'Tauramena', 'Trinidad', 'Yopal', 'Balboa',
#        'Bolívar', 'Buenos Aires', 'Cajibío', 'Caldono', 'Caloto',
#        'Corinto', 'El Tambo', 'Inzá', 'Jambaló', 'La Sierra', 'La Vega',
#        'Mercaderes', 'Miranda', 'Padilla', 'Patía', 'Piamonte',
#        'Piendamó', 'Popayán', 'Puerto Tejada', 'Puracé', 'Rosas',
#        'San Sebastián', 'Santander de Quilichao', 'Silvia', 'Sotara',
#        'Sucre', 'Suárez', 'Timbiquí', 'Timbío', 'Totoró', 'Aguachica',
#        'Agustín Codazzi', 'Astrea', 'Becerril', 'Bosconia', 'Chimichagua',
#        'Chiriguaná', 'Curumaní', 'El Copey', 'El Paso', 'Gamarra',
#        'González', 'La Gloria', 'La Jagua de Ibirico', 'La Paz',
#        'Pailitas', 'Pelaya', 'Pueblo Bello', 'Río de Oro', 'San Alberto',
#        'San Diego', 'San Martín', 'Tamalameque', 'Valledupar', 'Acandí',
#        'Atrato', 'Bahía Solano', 'Bajo Baudó', 'Condoto', 'Cértegui',
#        'El Carmen de Atrato', 'Istmina', 'Lloró', 'Medio Baudó',
#        'Medio San Juan', 'Nuquí', 'Quibdó', 'Tadó', 'Unguía',
#        'Unión Panamericana', 'Agua de Dios', 'Albán', 'Anapoima',
#        'Anolaima', 'Apulo', 'Arbeláez', 'Bojacá', 'Cabrera', 'Cachipay',
#        'Cajicá', 'Caparrapí', 'Carmen de Carupa', 'Chipaque', 'Choachí',
#        'Chocontá', 'Chía', 'Cogua', 'Cota', 'Cucunubá', 'El Colegio',
#        'El Rosal', 'Facatativá', 'Fosca', 'Funza', 'Fusagasugá',
#        'Fúquene', 'Gachancipá', 'Gachetá', 'Girardot', 'Guachetá',
#        'Guaduas', 'Guasca', 'Guatavita', 'Guayabetal', 'Jerusalén',
#        'Junín', 'La Calera', 'La Mesa', 'La Palma', 'Lenguazaque',
#        'Madrid', 'Mosquera', 'Nariño', 'Nemocón', 'Nilo', 'Nimaima',
#        'Nocaima', 'Pacho', 'Paratebueno', 'Pasca', 'Puerto Salgar',
#        'Quetame', 'Quipile', 'Ricaurte', 'San Antonio del Tequendama',
#        'San Bernardo', 'Sasaima', 'Sesquilé', 'Sibaté', 'Silvania',
#        'Simijaca', 'Soacha', 'Sopó', 'Subachoque', 'Suesca', 'Supatá',
#        'Susa', 'Sutatausa', 'Tabio', 'Tausa', 'Tena', 'Tenjo', 'Tocaima',
#        'Tocancipá', 'Ubalá', 'Ubaque', 'Une', 'Vianí', 'Villapinzón',
#        'Villeta', 'Viotá', 'Yacopí', 'Zipacón', 'Zipaquirá', 'Inírida',
#        'El Retorno', 'San José del Guaviare', 'Acevedo', 'Agrado', 'Aipe',
#        'Algeciras', 'Altamira', 'Baraya', 'Campoalegre', 'Colombia',
#        'Elías', 'Garzón', 'Gigante', 'Hobo', 'Isnos', 'La Argentina',
#        'La Plata', 'Neiva', 'Nátaga', 'Oporapa', 'Paicol', 'Palermo',
#        'Pital', 'Pitalito', 'Rivera', 'Saladoblanco', 'San Agustín',
#        'Suaza', 'Tarqui', 'Tello', 'Teruel', 'Tesalia', 'Timaná',
#        'Villavieja', 'Yaguará', 'Barrancas', 'Dibulla', 'Distracción',
#        'El Molino', 'Fonseca', 'Hatonuevo', 'La Jagua del Pilar',
#        'Maicao', 'Manaure', 'Riohacha', 'San Juan del Cesar', 'Uribia',
#        'Urumita', 'Algarrobo', 'Aracataca', 'Ariguaní', 'Chivolo',
#        'Ciénaga', 'Concordia', 'El Banco', 'El Retén', 'Fundación',
#        'Guamal', 'Nueva Granada', 'Pedraza', 'Pijiño del Carmen',
#        'Pivijay', 'Plato', 'Puebloviejo', 'Remolino',
#        'San Sebastián de Buenavista', 'San Zenón', 'Santa Ana',
#        'Santa Bárbara de Pinto', 'Sitionuevo', 'Tenerife', 'Zapayán',
#        'Zona Bananera', 'Acacías', 'Barranca de Upía', 'Cabuyaro',
#        'Castilla la Nueva', 'Cumaral', 'El Castillo', 'El Dorado',
#        'Fuente de Oro', 'La Macarena', 'Lejanías', 'Mapiripán', 'Mesetas',
#        'Puerto Concordia', 'Puerto Gaitán', 'Puerto Lleras',
#        'Puerto López', 'Restrepo', 'San Carlos de Guaroa', 'Uribe',
#        'Villavicencio', 'Vistahermosa', 'Aldana', 'Ancuyá', 'Arboleda',
#        'Barbacoas', 'Buesaco', 'Chachagüí', 'Colón', 'Contadero',
#        'Cumbal', 'Cumbitara', 'El Charco', 'El Peñol', 'Funes',
#        'Guachucal', 'Guaitarilla', 'Gualmatán', 'Iles', 'Imués',
#        'Ipiales', 'La Cruz', 'La Florida', 'La Llanada', 'La Tola',
#        'Leiva', 'Linares', 'Mallama', 'Ospina', 'Pasto', 'Policarpa',
#        'Potosí', 'Puerres', 'Pupiales', 'Roberto Payán', 'Samaniego',
#        'San Andrés de Tumaco', 'San Lorenzo', 'San Pedro de Cartago',
#        'Sandoná', 'Sapuyes', 'Taminango', 'Tangua', 'Túquerres',
#        'Yacuanquer', 'Arboledas', 'Bochalema', 'Bucarasica', 'Chinácota',
#        'Chitagá', 'Convención', 'Cucutilla', 'Cúcuta', 'Durania',
#        'El Carmen', 'El Tarra', 'El Zulia', 'Gramalote', 'Hacarí',
#        'Herrán', 'La Esperanza', 'Labateca', 'Los Patios', 'Lourdes',
#        'Mutiscua', 'Ocaña', 'Pamplona', 'Pamplonita', 'Puerto Santander',
#        'Salazar', 'San Calixto', 'San Cayetano', 'Santiago', 'Sardinata',
#        'Silos', 'Teorama', 'Tibú', 'Villa del Rosario', 'Mocoa', 'Orito',
#        'Puerto Asís', 'Puerto Caicedo', 'Puerto Guzmán', 'San Miguel',
#        'Sibundoy', 'Valle del Guamuez', 'Villagarzón', 'Circasia',
#        'Filandia', 'La Tebaida', 'Montenegro', 'Pijao', 'Quimbaya',
#        'Salento', 'Apía', 'Belén de Umbría', 'Dosquebradas', 'Guática',
#        'La Celia', 'La Virginia', 'Marsella', 'Mistrató', 'Pereira',
#        'Pueblo Rico', 'Quinchía', 'Santa Rosa de Cabal', 'Santuario',
#        'Santa Marta', 'Aguada', 'Aratoca', 'Barichara', 'Barrancabermeja',
#        'Betulia', 'Bucaramanga', 'Capitanejo', 'Carcasí', 'Cerrito',
#        'Charalá', 'Chima', 'Chipatá', 'Cimitarra', 'Contratación',
#        'Curití', 'El Carmen de Chucurí', 'El Guacamayo', 'El Playón',
#        'Encino', 'Floridablanca', 'Florián', 'Girón', 'Guaca',
#        'La Belleza', 'Landázuri', 'Lebrija', 'Los Santos', 'Matanza',
#        'Mogotes', 'Molagavita', 'Málaga', 'Oiba', 'Piedecuesta',
#        'Pinchote', 'Puerto Parra', 'Puerto Wilches', 'Páramo',
#        'Sabana de Torres', 'San Benito', 'San Gil', 'San Joaquín',
#        'San José de Miranda', 'San Vicente de Chucurí',
#        'Santa Helena del Opón', 'Socorro', 'Suaita', 'Tona',
#        'Valle de San José', 'Vetas', 'Vélez', 'Zapatoca', 'Caimito',
#        'Chalán', 'Coloso', 'Corozal', 'Coveñas', 'El Roble', 'Galeras',
#        'Guaranda', 'Los Palmitos', 'Majagual', 'Morroa', 'Ovejas',
#        'Palmito', 'Sampués', 'San Juan de Betulia', 'San Luis de Sincé',
#        'San Marcos', 'San Onofre', 'San Pedro', 'Santiago de Tolú',
#        'Sincelejo', 'Tolú Viejo', 'Alvarado', 'Anzoátegui', 'Armero',
#        'Ataco', 'Cajamarca', 'Carmen de Apicalá', 'Chaparral', 'Coello',
#        'Coyaima', 'Cunday', 'Dolores', 'Espinal', 'Flandes', 'Fresno',
#        'Guamo', 'Honda', 'Ibagué', 'Icononzo', 'Lérida', 'Líbano',
#        'Melgar', 'Natagaima', 'Ortega', 'Palocabildo', 'Piedras',
#        'Planadas', 'Prado', 'Purificación', 'Rioblanco', 'Rovira',
#        'Saldaña', 'San Antonio', 'Venadillo', 'Villahermosa',
#        'Villarrica', 'Alcalá', 'Andalucía', 'Ansermanuevo',
#        'Bugalagrande', 'Caicedonia', 'Cali', 'Calima', 'Cartago', 'Dagua',
#        'El Cerrito', 'El Dovio', 'El Águila', 'Florida', 'Ginebra',
#        'Guacarí', 'Guadalajara de Buga', 'Jamundí', 'La Cumbre',
#        'La Victoria', 'Obando', 'Palmira', 'Pradera', 'Riofrío',
#        'Roldanillo', 'Sevilla', 'Toro', 'Trujillo', 'Tuluá', 'Ulloa',
#        'Vijes', 'Yotoco', 'Yumbo', 'Zarzal', 'Mitú', 'Taraira',
#        'Cumaribo', 'Puerto Carreño'], dtype=object)

# %%
Casos_a_Fecha = Tasas.groupby(['Dpto', 'Municipio'])[['Fecha de notificación', 'Fecha de muerte',
        'Fecha recuperado']].count().loc[[departamento, municipio]]

# %%
Cuadro_Tasas = pd.merge(Casos_a_Fecha, Col, left_index=True, right_index=True)

# %%
Cuadro_Tasas.rename({'Fecha de notificación':'Total casos', 
                     'Fecha de muerte':'Fallecidos', 
                     'Fecha recuperado': 'Recuperados', 
                     '2020': 'Población'}, axis = 'columns', inplace=True)

# %%
Cuadro_Tasas['Tasa de letalidad por 100 habitantes'] = (Cuadro_Tasas['Fallecidos']/Cuadro_Tasas['Total casos'])*100
Cuadro_Tasas['Tasa de mortalidad por 100.000 habitantes'] = (Cuadro_Tasas['Fallecidos']/Cuadro_Tasas['Población'])*100000

# %% [markdown]
# #### Tasas de letalidad y de mortalidad por Departamento o Municipio

# %%
Cuadro_Tasas
# Out:
#                     Total casos  Fallecidos  Recuperados  Población  \
# Dpto   Municipio
# Caldas La Merced              8           0            4       5882
#        Supía                 68           1           40      29363
#        Norcasia               2           1            0       6128
#        Samaná                 1           0            0      19967
#        Neira                 14           2            7      21114
#        Victoria               6           0            1      10351
#        Palestina              7           1            0      15681
#        Marquetalia            2           0            1      13490
#        Filadelfia             1           0            0      11400
#        Manizales           1047          32          436     446160
#        Chinchiná            115           3           51      52267
#        Salamina               4           1            3      19393
#        Anserma               32           0            5      36691
#        Manzanares             7           0            1      17794
#        Pácora                 7           0            1      15324
#        Aguadas               24           0           15      23048
#        Marmato               75           0           39       9167
#        Viterbo               20           1            5      12853
#        Villamaría            76           4           32      67429
#        Risaralda              8           0            2      10568
#        Riosucio              60           2           27      51956
#        San José               3           2            0       4916
#        Aranzazu               1           0            1      10556
#        Belalcázar            26           0           21      10650
#        La Dorada            373          11          189      74006
#
#                     Tasa de letalidad por 100 habitantes  \
# Dpto   Municipio
# Caldas La Merced                                    0.00
#        Supía                                        1.47
#        Norcasia                                    50.00
#        Samaná                                       0.00
#        Neira                                       14.29
#        Victoria                                     0.00
#        Palestina                                   14.29
#        Marquetalia                                  0.00
#        Filadelfia                                   0.00
#        Manizales                                    3.06
#        Chinchiná                                    2.61
#        Salamina                                    25.00
#        Anserma                                      0.00
#        Manzanares                                   0.00
#        Pácora                                       0.00
#        Aguadas                                      0.00
#        Marmato                                      0.00
#        Viterbo                                      5.00
#        Villamaría                                   5.26
#        Risaralda                                    0.00
#        Riosucio                                     3.33
#        San José                                    66.67
#        Aranzazu                                     0.00
#        Belalcázar                                   0.00
#        La Dorada                                    2.95
#
#                     Tasa de mortalidad por 100.000 habitantes
# Dpto   Municipio
# Caldas La Merced                                         0.00
#        Supía                                             3.41
#        Norcasia                                         16.32
#        Samaná                                            0.00
#        Neira                                             9.47
#        Victoria                                          0.00
#        Palestina                                         6.38
#        Marquetalia                                       0.00
#        Filadelfia                                        0.00
#        Manizales                                         7.17
#        Chinchiná                                         5.74
#        Salamina                                          5.16
#        Anserma                                           0.00
#        Manzanares                                        0.00
#        Pácora                                            0.00
#        Aguadas                                           0.00
#        Marmato                                           0.00
#        Viterbo                                           7.78
#        Villamaría                                        5.93
#        Risaralda                                         0.00
#        Riosucio                                          3.85
#        San José                                         40.68
#        Aranzazu                                          0.00
#        Belalcázar                                        0.00
#        La Dorada                                        14.86

# %%
if departamento == '' and municipio== '':
    print('Debe ingresar mínimo el Departamento.  Inténtelo nuevamente')
    pass
else:
    if municipio == '':
        Total_casos = Cuadro_Tasas.loc[departamento, 'Total casos'].astype(int) 
        Fallecidos_dpto_munic = Cuadro_Tasas.loc[(departamento), 'Fallecidos'].astype(int)
        Poblacion_dpto_munic = Cuadro_Tasas.loc[(departamento), 'Población'].astype(int)
    
    else:
        Total_casos = Cuadro_Tasas.loc[(departamento, municipio), 'Total casos'].astype(int)
        Fallecidos_dpto_munic = Cuadro_Tasas.loc[(departamento, municipio), 'Fallecidos'].astype(int)
        Poblacion_dpto_munic = Cuadro_Tasas.loc[(departamento, municipio), 'Población'].astype(int)

# %%
#total_casos_covid_colombia

# %% [markdown]
# #### Fallecidos por municipio

# %%
Fallecidos_dpto_munic
# Out:
# Municipio
# La Merced       0
# Supía           1
# Norcasia        1
# Samaná          0
# Neira           2
# Victoria        0
# Palestina       1
# Marquetalia     0
# Filadelfia      0
# Manizales      32
# Chinchiná       3
# Salamina        1
# Anserma         0
# Manzanares      0
# Pácora          0
# Aguadas         0
# Marmato         0
# Viterbo         1
# Villamaría      4
# Risaralda       0
# Riosucio        2
# San José        2
# Aranzazu        0
# Belalcázar      0
# La Dorada      11
# Name: Fallecidos, dtype: int64

# %% [markdown]
# #### Población por municipio  (municipios afectados por CoV-2)

# %%
#Fallecidos_pais

# %%
Poblacion_dpto_munic
# Out:
# Municipio
# La Merced        5882
# Supía           29363
# Norcasia         6128
# Samaná          19967
# Neira           21114
# Victoria        10351
# Palestina       15681
# Marquetalia     13490
# Filadelfia      11400
# Manizales      446160
# Chinchiná       52267
# Salamina        19393
# Anserma         36691
# Manzanares      17794
# Pácora          15324
# Aguadas         23048
# Marmato          9167
# Viterbo         12853
# Villamaría      67429
# Risaralda       10568
# Riosucio        51956
# San José         4916
# Aranzazu        10556
# Belalcázar      10650
# La Dorada       74006
# Name: Población, dtype: int64

# %% [markdown]
# #### Total población en áreas afectadas del departamento o municipio

# %%
Poblacion_dpto_munic.sum()
# Out:
# 996154

# %% [markdown]
# #### Población Departamental o Municipal

# %%
poblacionDpto = Col.loc[(departamento),'2020'].sum()
poblacionDpto
# Out:
# 1018453

# %%
#Poblacion_pais

# %% [markdown]
# #### Casos por municipio

# %%
Total_casos
# Out:
# Municipio
# La Merced         8
# Supía            68
# Norcasia          2
# Samaná            1
# Neira            14
# Victoria          6
# Palestina         7
# Marquetalia       2
# Filadelfia        1
# Manizales      1047
# Chinchiná       115
# Salamina          4
# Anserma          32
# Manzanares        7
# Pácora            7
# Aguadas          24
# Marmato          75
# Viterbo          20
# Villamaría       76
# Risaralda         8
# Riosucio         60
# San José          3
# Aranzazu          1
# Belalcázar       26
# La Dorada       373
# Name: Total casos, dtype: int64

# %% [markdown]
# #### Casos en el departamento

# %%
Total_casos_dpto = Total_casos.sum()

Total_casos_dpto
# Out:
# 1987

# %% [markdown]
# #### Resumen situacional

# %%
hoy = pd.Timestamp.today()

# %%
filtro= Tasas[variable_buscar]== estado
if municipio == '':
    Cuadro_filtrados = Tasas.loc[filtro, 'Atención': 'Tipo recuperación'].loc[(Tasas['Dpto'] == departamento)]
    numero_estados= Cuadro_filtrados.loc[:, variable_buscar].count()
    print('Según datos reportados al ', hoy, ' por el INS Colombiano, de los ' + str(Total_casos_dpto)
          + ' casos de '+ departamento + ', ' + str(numero_estados) +' casos, es decir el '
          + str(((numero_estados/Total_casos_dpto)*100).round(2))+' %, está en condición: '
          + variable_buscar + ' ' + estado + ' y representan el ' 
          + str(((numero_estados/Col.loc[(departamento),'2020'].sum())*100).round(6)) 
          + ' %  de los '+ str(Col.loc[(departamento),'2020'].sum()) + ' habitantes de ' + departamento)
   
    print('La tasa de mortalidad en los municipios del Departamento de ' + departamento + ' por cien mil habitantes es: '
          + str(((Fallecidos_dpto_munic/poblacionDpto)*100000).round(2)))
    
    print('La tasa de letalidad en los municipios del Departamento de ' + departamento + 
          ' por cien enfermos de CoVid-19, es: ' + str(((Fallecidos_dpto_munic/Total_casos)*100).round(2)))

else:
    Cuadro_filtrados = Tasas.loc[filtro, 'Atención': 'Tipo recuperación'].loc[(Tasas['Dpto'] == departamento) & (Tasas['Municipio']== municipio)]
    numero_estados= Cuadro_filtrados.loc[:, variable_buscar].count()
    print('Según datos reportados al', hoy, 'por el INS Colombiano, de los ' + str(Total_casos) + ' casos de '+ municipio + ', ' 
          + str(numero_estados) +' casos, es decir el '+ str(((numero_estados/Total_casos)*100).round(2))
          +' %, están en '+ variable_buscar + ': ' + estado + ' y representan el '
          + str(((numero_estados/Poblacion_dpto_munic.sum())*100).round(6)) 
          + ' % de los ' + str(Poblacion_dpto_munic.sum()) + ' habitantes de ' + municipio +'.','\n')
    
    print('La tasa de letalidad en el municipio de '+ municipio + ',' + ' Departamento de ' 
          + departamento + ' es de ' + str(((Fallecidos_dpto_munic/Total_casos)*100).round(2)) 
          + ' por cien enfermos de CoVid-19.','\n')
    
    print('La tasa de mortalidad en el municipio de '+ municipio + ',' + ' Departamento de ' 
          + departamento + ' es de ' + str(((Fallecidos_dpto_munic/Poblacion_dpto_munic)*100000).round(2)) 
          + ' por cien mil habitantes.','\n')
    
print('La tasa de mortalidad de ' + pais+ ' por CoV-2 ' + 'es de ' + str(((Fallecidos_pais/Poblacion_pais)*1000000).round(1))+ ' por millón de habitantes.','\n')

print('La tasa de letalidad de '+pais+ ' por CoV-2 ' + 'es de ' + str(((Fallecidos_pais/total_casos_covid_colombia)*100).round(2))+ ' por cien enfermos de CoVid-19.','\n')
# Out:
# Según datos reportados al  2020-09-07 14:18:47.264901  por el INS Colombiano, de los 1987 casos de Caldas, 2 casos, es decir el 0.1 %, está en condición: Atención Hospital UCI y representan el 0.000196 %  de los 1018453 habitantes de Caldas
# La tasa de mortalidad en los municipios del Departamento de Caldas por cien mil habitantes es: Municipio
# La Merced      0.00
# Supía          0.10
# Norcasia       0.10
# Samaná         0.00
# Neira          0.20
# Victoria       0.00
# Palestina      0.10
# Marquetalia    0.00
# Filadelfia     0.00
# Manizales      3.14
# Chinchiná      0.29
# Salamina       0.10
# Anserma        0.00
# Manzanares     0.00
# Pácora         0.00
# Aguadas        0.00
# Marmato        0.00
# Viterbo        0.10
# Villamaría     0.39
# Risaralda      0.00
# Riosucio       0.20
# San José       0.20
# Aranzazu       0.00
# Belalcázar     0.00
# La Dorada      1.08
# Name: Fallecidos, dtype: float64
# La tasa de letalidad en los municipios del Departamento de Caldas por cien enfermos de CoVid-19, es: Municipio
# La Merced       0.00
# Supía           1.47
# Norcasia       50.00
# Samaná          0.00
# Neira          14.29
# Victoria        0.00
# Palestina      14.29
# Marquetalia     0.00
# Filadelfia      0.00
# Manizales       3.06
# Chinchiná       2.61
# Salamina       25.00
# Anserma         0.00
# Manzanares      0.00
# Pácora          0.00
# Aguadas         0.00
# Marmato         0.00
# Viterbo         5.00
# Villamaría      5.26
# Risaralda       0.00
# Riosucio        3.33
# San José       66.67
# Aranzazu        0.00
# Belalcázar      0.00
# La Dorada       2.95
# dtype: float64
# La tasa de mortalidad de Colombia por CoV-2 es de 131.2 por millón de habitantes.
#
# La tasa de letalidad de Colombia por CoV-2 es de 2.6 por cien enfermos de CoVid-19.

# %%
Cuadro_Tasas.columns
# Out:
# Index(['Total casos', 'Fallecidos', 'Recuperados', 'Población',
#        'Tasa de letalidad por 100 habitantes',
#        'Tasa de mortalidad por 100.000 habitantes'],
#       dtype='object')

# %%
# %matplotlib inline

# %%
casos = Cuadro_Tasas['Total casos']

y = Cuadro_Tasas['Recuperados']

dev_x = casos
dev_y = y

plt.scatter(casos, dev_y, color= 'g', linestyle = '--', linewidth= 3, label='Recuperados')

y1= Cuadro_Tasas['Fallecidos']

plt.scatter(casos, y1, color ='k', linewidth=1, label= 'Fallecidos')


plt.title('Fallecidos con relación al número de casos')
plt.xlabel('Número de casos')
plt.ylabel('Total')
plt.legend()
#plt.grid(True)

plt.tight_layout()
#plt.savefig('figure.png')
plt.show()

# %%
cuadro_basico
# Out:
#        Fecha de notificación  Ciudad de ubicación Departamento o Distrito   \
# 0                 2020-03-02          Bogotá D.C.              Bogotá D.C.
# 1                 2020-03-06  Guadalajara de Buga          Valle del Cauca
# 2                 2020-03-07             Medellín                Antioquia
# 3                 2020-03-09             Medellín                Antioquia
# 4                 2020-03-09             Medellín                Antioquia
# ...                      ...                  ...                      ...
# 666516            2020-08-29                 Cali          Valle del Cauca
# 666517            2020-08-28                 Cali          Valle del Cauca
# 666518            2020-08-24                 Cali          Valle del Cauca
# 666519            2020-08-28                 Cali          Valle del Cauca
# 666520            2020-08-28                 Cali          Valle del Cauca
#
#           atención  Edad Sexo         Tipo Estado País de procedencia  \
# 0       Recuperado    19    F    Importado   Leve              ITALIA
# 1       Recuperado    34    M    Importado   Leve              ESPAÑA
# 2       Recuperado    50    F    Importado   Leve              ESPAÑA
# 3       Recuperado    55    M  Relacionado   Leve                 NaN
# 4       Recuperado    25    M  Relacionado   Leve                 NaN
# ...            ...   ...  ...          ...    ...                 ...
# 666516        Casa    86    M   En estudio   Leve                 NaN
# 666517        Casa    58    M   En estudio   Leve                 NaN
# 666518        Casa    38    F   En estudio   Leve                 NaN
# 666519        Casa    68    M   En estudio   Leve                 NaN
# 666520        Casa    39    F   En estudio   Leve                 NaN
#
#        Fecha de muerte Fecha diagnostico Fecha recuperado Tipo recuperación
# 0                  NaT        2020-03-06       2020-03-13               PCR
# 1                  NaT        2020-03-09       2020-03-19               PCR
# 2                  NaT        2020-03-09       2020-03-15               PCR
# 3                  NaT        2020-03-11       2020-03-26               PCR
# 4                  NaT        2020-03-11       2020-03-23               PCR
# ...                ...               ...              ...               ...
# 666516             NaT        2020-08-30              NaT               NaN
# 666517             NaT        2020-08-30              NaT               NaN
# 666518             NaT        2020-08-30              NaT               NaN
# 666519             NaT        2020-08-30              NaT               NaN
# 666520             NaT        2020-08-30              NaT               NaN
#
# [666521 rows x 13 columns]

# %%
cuadro_basico.columns
# Out:
# Index(['Fecha de notificación', 'Ciudad de ubicación',
#        'Departamento o Distrito ', 'atención', 'Edad', 'Sexo', 'Tipo',
#        'Estado', 'País de procedencia', 'Fecha de muerte', 'Fecha diagnostico',
#        'Fecha recuperado', 'Tipo recuperación'],
#       dtype='object')

# %%
cuadro_basico.index
# Out:
# RangeIndex(start=0, stop=666521, step=1)

# %%
cuadro_basico.sort_values(by= ['Fecha de notificación'], inplace=True)

# %%
x = cuadro_basico['Fecha de notificación']

y = cuadro_basico['Edad']

dev_x = x
dev_y = y

#plt.plot_date(dev_x, dev_y, color= 'g', linestyle = '--', linewidth= 3, label='Recuperados')
plt.scatter(dev_x, dev_y, color= 'g', label='Edad personas afectadas')

plt.gcf().autofmt_xdate()
#y1= Cuadro_Tasas['Fallecidos']

#plt.scatter(dev_x, y1, color ='k', linewidth=1, label= 'Fallecidos')


plt.title('Colombia COVID-19. Fuente:  INS')

plt.xlabel('Fechas')
plt.ylabel('Edad')
plt.legend()
#plt.grid(True)

plt.tight_layout()
#plt.savefig('figure.png')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
