# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 500)

# %%
gompertz = pd.read_csv('CovidColombia.csv', low_memory=False, usecols= ['ID de caso', 'Fecha de notificación', 
                                                                        'Ciudad de ubicación', 
                                                                        'Departamento o Distrito '], 
                                                                        parse_dates=['Fecha de notificación'] )

# %%
gompertz.sort_values(by=['Fecha de notificación'],inplace=True)

# %%
df = pd.DataFrame(gompertz['Fecha de notificación']).loc[0]

# %%
a = gompertz.loc[0,'Fecha de notificación']

# %%
b = np.datetime64('today') 
b
# Out:
# numpy.datetime64('2020-07-26')

# %%
longitud = (b-a)/ np.timedelta64(1, 'D')
longitud=int(longitud)-1
longitud
# Out:
# 145

# %%
df_fechas = pd.DataFrame(df).transpose()
df_fechas
# Out:
#   Fecha de notificación
# 0            2020-03-02

# %%
df_fechas['ID de caso']=0

# %%
df_fechas
# Out:
#   Fecha de notificación  ID de caso
# 0            2020-03-02           0

# %%
pd.to_datetime([df_fechas.loc[0,'Fecha de notificación']])
# Out:
# DatetimeIndex(['2020-03-02'], dtype='datetime64[ns]', freq=None)

# %%
(np.datetime64(df_fechas.loc[0, 'Fecha de notificación']) + np.timedelta64(1,'D'))
# Out:
# numpy.datetime64('2020-03-03T00:00:00.000000')

# %%
for i in range(1,longitud):
    df_fechas.loc[(i)] = [(np.datetime64(df_fechas.loc[i-1, 'Fecha de notificación']) + np.timedelta64(1,'D')),0]

# %%
df_fechas
# Out:
#     Fecha de notificación  ID de caso
# 0              2020-03-02           0
# 1              2020-03-03           0
# 2              2020-03-04           0
# 3              2020-03-05           0
# 4              2020-03-06           0
# 5              2020-03-07           0
# 6              2020-03-08           0
# 7              2020-03-09           0
# 8              2020-03-10           0
# 9              2020-03-11           0
# 10             2020-03-12           0
# 11             2020-03-13           0
# 12             2020-03-14           0
# 13             2020-03-15           0
# 14             2020-03-16           0
# 15             2020-03-17           0
# 16             2020-03-18           0
# 17             2020-03-19           0
# 18             2020-03-20           0
# 19             2020-03-21           0
# 20             2020-03-22           0
# 21             2020-03-23           0
# 22             2020-03-24           0
# 23             2020-03-25           0
# 24             2020-03-26           0
# 25             2020-03-27           0
# 26             2020-03-28           0
# 27             2020-03-29           0
# 28             2020-03-30           0
# 29             2020-03-31           0
# 30             2020-04-01           0
# 31             2020-04-02           0
# 32             2020-04-03           0
# 33             2020-04-04           0
# 34             2020-04-05           0
# 35             2020-04-06           0
# 36             2020-04-07           0
# 37             2020-04-08           0
# 38             2020-04-09           0
# 39             2020-04-10           0
# 40             2020-04-11           0
# 41             2020-04-12           0
# 42             2020-04-13           0
# 43             2020-04-14           0
# 44             2020-04-15           0
# 45             2020-04-16           0
# 46             2020-04-17           0
# 47             2020-04-18           0
# 48             2020-04-19           0
# 49             2020-04-20           0
# 50             2020-04-21           0
# 51             2020-04-22           0
# 52             2020-04-23           0
# 53             2020-04-24           0
# 54             2020-04-25           0
# 55             2020-04-26           0
# 56             2020-04-27           0
# 57             2020-04-28           0
# 58             2020-04-29           0
# 59             2020-04-30           0
# 60             2020-05-01           0
# 61             2020-05-02           0
# 62             2020-05-03           0
# 63             2020-05-04           0
# 64             2020-05-05           0
# 65             2020-05-06           0
# 66             2020-05-07           0
# 67             2020-05-08           0
# 68             2020-05-09           0
# 69             2020-05-10           0
# 70             2020-05-11           0
# 71             2020-05-12           0
# 72             2020-05-13           0
# 73             2020-05-14           0
# 74             2020-05-15           0
# 75             2020-05-16           0
# 76             2020-05-17           0
# 77             2020-05-18           0
# 78             2020-05-19           0
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 240935                    Huila
# 240936                   Caldas
# 240937                   Caldas
# 240938                  Quindío
# 240939                   Caldas
#
# [240940 rows x 4 columns]

# %%
longitud = gompertz_Colombia['ID de caso'].size
longitud
# Out:
# 240940

# %%
gompertz_Colombia.columns
# Out:
# Index(['ID de caso', 'Fecha de notificación', 'Ciudad de ubicación',
#        'Departamento o Distrito '],
#       dtype='object')

# %%
for i in range(0, longitud):
    if gompertz_Colombia.loc[i, 'ID de caso'] == 0:
        pass
    else:
        gompertz_Colombia.loc[i, 'ID de caso'] = 1

# %%
gompertz_Colombia
# Out:
#         ID de caso Fecha de notificación Ciudad de ubicación  \
# 0                1            2020-03-02         Bogotá D.C.
# 1                0            2020-03-02                 NaN
# 2                0            2020-03-03                 NaN
# 3                0            2020-03-04                 NaN
# 4                0            2020-03-05                 NaN
# ...            ...                   ...                 ...
# 240935           1            2020-07-25            Colombia
# 240936           1            2020-07-25           Manizales
# 240937           1            2020-07-25           Manizales
# 240938           1            2020-07-25             Armenia
# 240939           1            2020-07-25           Manizales
#
#        Departamento o Distrito
# 0                   Bogotá D.C.
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 240935                    Huila
# 240936                   Caldas
# 240937                   Caldas
# 240938                  Quindío
# 240939                   Caldas
#
# [240940 rows x 4 columns]

# %%
gompertz_Colombia['Acumulados']= 0
gompertz_Colombia['Día número']=0
gompertz_Colombia['Penetración real']=0
gompertz_Colombia
# Out:
#         ID de caso Fecha de notificación Ciudad de ubicación  \
# 0                1            2020-03-02         Bogotá D.C.
# 1                0            2020-03-02                 NaN
# 2                0            2020-03-03                 NaN
# 3                0            2020-03-04                 NaN
# 4                0            2020-03-05                 NaN
# ...            ...                   ...                 ...
# 240935           1            2020-07-25            Colombia
# 240936           1            2020-07-25           Manizales
# 240937           1            2020-07-25           Manizales
# 240938           1            2020-07-25             Armenia
# 240939           1            2020-07-25           Manizales
#
#        Departamento o Distrito   Acumulados  Día número  Penetración real
# 0                   Bogotá D.C.           0           0                 0
# 1                           NaN           0           0                 0
# 2                           NaN           0           0                 0
# 3                           NaN           0           0                 0
# 4                           NaN           0           0                 0
# ...                         ...         ...         ...               ...
# 240935                    Huila           0           0                 0
# 240936                   Caldas           0           0                 0
# 240937                   Caldas           0           0                 0
# 240938                  Quindío           0           0                 0
# 240939                   Caldas           0           0                 0
#
# [240940 rows x 7 columns]

# %%
gompertz_Colombia.loc[0, 'Acumulados']= gompertz_Colombia.loc[0, 'ID de caso']
for i in range(1, longitud):
    gompertz_Colombia.loc[i,'Acumulados'] = gompertz_Colombia.loc[i, 'ID de caso'] + gompertz_Colombia.loc[i-1, 'Acumulados']

# %%
gompertz_Colombia.tail()
# Out:
#         ID de caso Fecha de notificación Ciudad de ubicación  \
# 240935           1            2020-07-25            Colombia
# 240936           1            2020-07-25           Manizales
# 240937           1            2020-07-25           Manizales
# 240938           1            2020-07-25             Armenia
# 240939           1            2020-07-25           Manizales
#
#        Departamento o Distrito   Acumulados  Día número  Penetración real
# 240935                    Huila      240791           0                 0
# 240936                   Caldas      240792           0                 0
# 240937                   Caldas      240793           0                 0
# 240938                  Quindío      240794           0                 0
# 240939                   Caldas      240795           0                 0

# %%
gompertz_Colombia.loc[0, 'Día número'] = 1
for i in range(1, longitud):
    gompertz_Colombia.loc[i,'Día número'] = i+1
    gompertz_Colombia.loc[i,'Penetración real'] = gompertz_Colombia.loc[i, 'Acumulados']/ gompertz_Colombia.loc[longitud-1, 'Acumulados']

# %%
gompertz_Colombia.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-5bb962f591a1> in <module>
# ----> 1 gompertz_Colombia.columns
#
# NameError: name 'gompertz_Colombia' is not defined

# %%
gompertz_Colombia.to_excel('datosTotalesparaGompertzColombia.xlsx')
