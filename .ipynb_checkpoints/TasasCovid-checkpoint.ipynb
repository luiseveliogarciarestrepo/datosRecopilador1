# %% [markdown]
# # Bases de datos
#
# Para los análisis se toman las bases de datos, última actualización, de organizaciones internacionales y nacionales:
#
#     - ONU
#     - OMS
#     - INS
#     - DANE

# %% [markdown]
# ### Variables para análisis:

# %%
pais = 'Colombia'

departamento = 'Caldas'

municipio = 'Manizales'

variable_buscar = 'Estado'  # puede ser 'Atención' o 'Estado'

estado = 'Fallecido'  # Si atención:  ['Recuperado', 'Hospital', 'Hospital UCI', nan, 'Casa']
                   # Si Estado:   ['Leve', 'Asintomático', 'Fallecido', 'Moderado', 'Grave', nan]

ano = '2020'

# %%
import pandas as pd
pd.set_option("display.precision", 2)

from matplotlib import pyplot as plt
#print(plt.style.available)
#plt.style.use('fivethirtyeight')
plt.xkcd()
from textwrap import wrap

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Población mundial por países y proyección 2020  a 2100

# %%
mundo= pd.read_csv('poblacionMundial.csv', usecols= ['Country', '2020', 'Spanish'])

mundo.set_index('Spanish', inplace=True)
mundo
# Out:
#                                                     Country        2020
# Spanish
# MUNDO                                                 WORLD  7794799000
# África                                               Africa  1340598000
# Asia                                                   Asia  4641055000
# Europa                                               Europe   747636000
# América Latina y el Caribe  Latin America and the Caribbean   653962000
# ...                                                     ...         ...
# islas Bermudas                                      Bermuda       62000
# Canadá                                               Canada    37742000
# Groenlandia                                       Greenland       57000
# San Pedro y Miquelón              Saint Pierre and Miquelon        6000
# Estados Unidos de America          United States of America   331003000
#
# [242 rows x 2 columns]

# %% [markdown]
# ## Total casos y número de fallecidos por país

# %%
covMun= pd.read_csv('CovidMundoT.csv', usecols= ['País', 'Total_Casos','Fallecidos'])
covMun
# Out:
#                                                   País  Total_Casos  \
# 0                                          Afghanistan        35289
# 1                                              Albania         3906
# 2                                              Algeria        21948
# 3                                              Andorra          880
# 4                                               Angola          638
# ..                                                 ...          ...
# 211                                           Viet Nam          382
# 212                                              Yemen         1580
# 213                                             Zambia         2810
# 214                                           Zimbabwe         1420
# 215  occupied Palestinian territory, including east...         9055
#
#      Fallecidos
# 0          1147
# 1           107
# 2          1057
# 3            52
# 4            29
# ..          ...
# 211           0
# 212         441
# 213         109
# 214          24
# 215          57
#
# [216 rows x 3 columns]

# %% [markdown]
# ## Total casos y número de fallecidos Colombia por fecha, departamento, municipio, atención, edad, género, fechas de diagnóstico, recuperación o muerte.

# %%
covCol = pd.read_csv('CovidColombia.csv', usecols= ['Fecha de notificación', 
       'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
       'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'Fecha recuperado', 'Fecha diagnostico','Fecha de muerte', 
       'Tipo recuperación'], parse_dates = ['Fecha de notificación','Fecha de muerte', 'Fecha diagnostico','Fecha recuperado'], low_memory=False)

covCol['Fecha de muerte'] = pd.to_datetime(covCol['Fecha de muerte'], errors='coerce')

fechas =['Fecha de notificación']
for i in fechas:
    covCol[i] = pd.to_datetime(covCol[i])

cuadro_basico = covCol    
    
covCol
# Out:
#        Fecha de notificación   Ciudad de ubicación Departamento o Distrito   \
# 0                 2020-03-02           Bogotá D.C.              Bogotá D.C.
# 1                 2020-03-06   Guadalajara de Buga          Valle del Cauca
# 2                 2020-03-07              Medellín                Antioquia
# 3                 2020-03-09              Medellín                Antioquia
# 4                 2020-03-09              Medellín                Antioquia
# ...                      ...                   ...                      ...
# 410448            2020-07-28             Florencia                  Caquetá
# 410449            2020-07-28             Florencia                  Caquetá
# 410450            2020-07-27                Cúcuta       Norte de Santander
# 410451            2020-07-28                 Girón                Santander
# 410452            2020-07-28  El Carmen de Chucurí                Santander
#
#           atención  Edad Sexo         Tipo Estado País de procedencia  \
# 0       Recuperado    19    F    Importado   Leve              ITALIA
# 1       Recuperado    34    M    Importado   Leve              ESPAÑA
# 2       Recuperado    50    F    Importado   Leve              ESPAÑA
# 3       Recuperado    55    M  Relacionado   Leve                 NaN
# 4       Recuperado    25    M  Relacionado   Leve                 NaN
# ...            ...   ...  ...          ...    ...                 ...
# 410448        Casa    34    M   En estudio   Leve                 NaN
# 410449        Casa     6    M   En estudio   Leve                 NaN
# 410450        Casa    61    M   En estudio   Leve                 NaN
# 410451        Casa    74    F   En estudio   Leve                 NaN
# 410452        Casa    30    M   En estudio   Leve                 NaN
#
#        Fecha de muerte Fecha diagnostico Fecha recuperado Tipo recuperación
# 0                  NaT        2020-03-06       2020-03-13               PCR
# 1                  NaT        2020-03-09       2020-03-19               PCR
# 2                  NaT        2020-03-09       2020-03-15               PCR
# 3                  NaT        2020-03-11       2020-03-26               PCR
# 4                  NaT        2020-03-11       2020-03-23               PCR
# ...                ...               ...              ...               ...
# 410448             NaT        2020-08-08              NaT               NaN
# 410449             NaT        2020-08-08              NaT               NaN
# 410450             NaT        2020-08-07              NaT               NaN
# 410451             NaT        2020-08-08              NaT               NaN
# 410452             NaT        2020-08-08              NaT               NaN
#
# [410453 rows x 13 columns]

# %% [markdown]
# ## Población Colombia por departamento, municipio y género proyectada para el año 2020.

# %%
Col = pd.read_csv('Dane2018_2023.csv').drop(columns = ['2018',
       '2019','2021', '2022', '2023' ])
Col
# Out:
#            Dpto  Municipio       Género      2020
# 0     Antioquia   Medellín  AMBOS SEXOS   2533424
# 1     Antioquia   Medellín      HOMBRES   1193791
# 2     Antioquia   Medellín      MUJERES   1339633
# 3     Antioquia  Abejorral  AMBOS SEXOS     20287
# 4     Antioquia  Abejorral      HOMBRES     10558
# ...         ...        ...          ...       ...
# 3364    Vichada   Cumaribo      HOMBRES     41840
# 3365    Vichada   Cumaribo      MUJERES     37023
# 3366   País_Col   País_Col  AMBOS SEXOS  50372424
# 3367   País_Col   País_Col      HOMBRES  24594882
# 3368   País_Col   País_Col      MUJERES  25777542
#
# [3369 rows x 4 columns]

# %% [markdown]
# #### Poblaciones

# %% [markdown]
# #### Colombia

# %%
Poblacion_pais = mundo.loc[pais, ano]
Poblacion_pais
# Out:
# 50883000

# %% [markdown]
# #### Total casos COVID-19

# %%
total_casos_covid_colombia = covCol['Fecha de notificación'].count()
total_casos_covid_colombia
# Out:
# 410453

# %% [markdown]
# #### Total Fallecidos por COVID-19

# %%
Fallecidos_pais = covCol['Fecha de muerte'].count()
Fallecidos_pais
# Out:
# 14183

# %%
filtro = Col['Género'] == 'AMBOS SEXOS'
Col = Col.loc[filtro, :].drop(columns=['Género'])

Col.set_index(['Dpto', 'Municipio'], inplace=True)

# %%
covCol.rename(columns={"Departamento o Distrito ": "Dpto", "Ciudad de ubicación": "Municipio", "atención":"Atención", "Fecha diagnostico":"Fecha diagnóstico"}, inplace=True)

covCol.set_index(['Dpto', 'Municipio'], inplace = True)

# %% [markdown]
# #### Casos y poblaciones por departamento y municipio

# %%
Tasas = pd.merge(covCol, Col, left_index=True, right_index=True).reset_index()

Tasas
# Out:
#             Dpto       Municipio Fecha de notificación    Atención  Edad Sexo  \
# 0       Amazonas         Leticia            2020-04-14  Recuperado    26    M
# 1       Amazonas         Leticia            2020-04-13  Recuperado    47    F
# 2       Amazonas         Leticia            2020-04-14  Recuperado    16    F
# 3       Amazonas         Leticia            2020-04-14  Recuperado    41    F
# 4       Amazonas         Leticia            2020-04-16  Recuperado    54    M
# ...          ...             ...                   ...         ...   ...  ...
# 394339   Vichada    La Primavera            2020-07-15  Recuperado    78    F
# 394340   Vichada  Puerto Carreño            2020-05-29  Recuperado    20    M
# 394341   Vichada  Puerto Carreño            2020-07-22        Casa    19    M
# 394342   Vichada  Puerto Carreño            2020-07-22        Casa    20    M
# 394343   Vichada  Puerto Carreño            2020-07-22        Casa    19    M
#
#                Tipo        Estado País de procedencia Fecha de muerte  \
# 0       Relacionado          Leve                 NaN             NaT
# 1         Importado          Leve              BRASIL             NaT
# 2       Relacionado          Leve                 NaN             NaT
# 3         Importado          Leve              BRASIL             NaT
# 4       Relacionado          Leve                 NaN             NaT
# ...             ...           ...                 ...             ...
# 394339   En estudio          Leve                 NaN             NaT
# 394340   En estudio  Asintomático                 NaN             NaT
# 394341  Relacionado          Leve                 NaN             NaT
# 394342  Relacionado          Leve                 NaN             NaT
# 394343  Relacionado          Leve                 NaN             NaT
#
#        Fecha diagnóstico Fecha recuperado Tipo recuperación   2020
# 0             2020-04-17       2020-05-19               PCR  49737
# 1             2020-04-18       2020-05-31            Tiempo  49737
# 2             2020-04-18       2020-05-29               PCR  49737
# 3             2020-04-18       2020-05-29               PCR  49737
# 4             2020-04-21       2020-04-29               PCR  49737
# ...                  ...              ...               ...    ...
# 394339        2020-07-17       2020-08-01               PCR   9608
# 394340        2020-05-29       2020-06-07               PCR  20294
# 394341        2020-08-02              NaT               NaN  20294
# 394342        2020-08-02              NaT               NaN  20294
# 394343        2020-08-02              NaT               NaN  20294
#
# [394344 rows x 14 columns]

# %% [markdown]
# #### Municipios con casos reportados por SARS CoV-2 a:

# %%
pd.Timestamp.today()
# Out:
# Timestamp('2020-08-12 15:44:45.080362')

# %%
Tasas['Municipio'].unique()
# Out:
# array(['Leticia', 'Puerto Nariño', 'Abejorral', 'Abriaquí', 'Alejandría',
#        'Amagá', 'Amalfi', 'Andes', 'Angostura', 'Anorí', 'Apartadó',
#        'Arboletes', 'Argelia', 'Armenia', 'Barbosa', 'Bello', 'Belmira',
#        'Betania', 'Betulia', 'Briceño', 'Buriticá', 'Caicedo', 'Caldas',
#        'Campamento', 'Caracolí', 'Caramanta', 'Carepa', 'Carolina',
#        'Caucasia', 'Cañasgordas', 'Chigorodó', 'Cisneros',
#        'Ciudad Bolívar', 'Cocorná', 'Concepción', 'Concordia',
#        'Copacabana', 'Cáceres', 'Dabeiba', 'Ebéjico', 'El Bagre',
#        'El Carmen de Viboral', 'El Santuario', 'Envigado', 'Fredonia',
#        'Frontino', 'Giraldo', 'Girardota', 'Granada', 'Guadalupe',
#        'Guarne', 'Guatapé', 'Gómez Plata', 'Heliconia', 'Hispania',
#        'Ituango', 'Jericó', 'La Ceja', 'La Estrella', 'La Pintada',
#        'La Unión', 'Liborina', 'Maceo', 'Marinilla', 'Medellín',
#        'Montebello', 'Murindó', 'Mutatá', 'Nechí', 'Necoclí', 'Olaya',
#        'Peque', 'Peñol', 'Pueblorrico', 'Puerto Berrío', 'Puerto Nare',
#        'Puerto Triunfo', 'Remedios', 'Retiro', 'Rionegro', 'Sabanalarga',
#        'Sabaneta', 'Salgar', 'San Andrés de Cuerquía', 'San Carlos',
#        'San Francisco', 'San Jerónimo', 'San Juan de Urabá', 'San Luis',
#        'San Pedro de Urabá', 'San Rafael', 'San Roque', 'Santa Bárbara',
#        'Santa Rosa de Osos', 'Santo Domingo', 'Segovia', 'Sonsón',
#        'Sopetrán', 'Tarazá', 'Tarso', 'Titiribí', 'Toledo', 'Turbo',
#        'Támesis', 'Uramita', 'Urrao', 'Valdivia', 'Valparaíso', 'Venecia',
#        'Vigía del Fuerte', 'Yarumal', 'Yolombó', 'Yondó', 'Zaragoza',
#        'Arauca', 'Arauquita', 'Fortul', 'Saravena', 'Tame', 'Providencia',
#        'San Andrés', 'Baranoa', 'Candelaria', 'Galapa', 'Juan de Acosta',
#        'Luruaco', 'Malambo', 'Manatí', 'Palmar de Varela', 'Piojó',
#        'Polonuevo', 'Ponedera', 'Puerto Colombia', 'Repelón',
#        'Sabanagrande', 'Santa Lucía', 'Santo Tomás', 'Soledad', 'Suan',
#        'Tubará', 'Usiacurí', 'Barranquilla', 'Bogotá D.C.', 'Achí',
#        'Altos del Rosario', 'Arenal', 'Arjona', 'Arroyohondo',
#        'Barranco de Loba', 'Calamar', 'Cantagallo', 'Cicuco', 'Clemencia',
#        'Córdoba', 'El Carmen de Bolívar', 'El Guamo', 'El Peñón',
#        'Hatillo de Loba', 'Magangué', 'Mahates', 'Margarita', 'Mompós',
#        'Montecristo', 'Morales', 'Norosí', 'Pinillos', 'Regidor',
#        'San Cristóbal', 'San Estanislao', 'San Jacinto',
#        'San Jacinto del Cauca', 'San Juan Nepomuceno',
#        'San Martín de Loba', 'San Pablo', 'Santa Catalina', 'Santa Rosa',
#        'Santa Rosa del Sur', 'Soplaviento', 'Talaigua Nuevo', 'Tiquisio',
#        'Turbaco', 'Turbaná', 'Villanueva', 'Zambrano', 'Almeida',
#        'Aquitania', 'Arcabuco', 'Belén', 'Boyacá', 'Buenavista',
#        'Chiquinquirá', 'Chíquiza', 'Coper', 'Corrales', 'Covarachía',
#        'Cubará', 'Cucaita', 'Cuítiva', 'Cómbita', 'Duitama', 'Firavitoba',
#        'Garagoa', 'Guateque', 'Guayatá', 'Iza', 'La Uvita', 'Maripí',
#        'Miraflores', 'Monguí', 'Moniquirá', 'Motavita', 'Muzo', 'Nobsa',
#        'Nuevo Colón', 'Oicatá', 'Otanche', 'Pachavita', 'Paipa', 'Pauna',
#        'Paya', 'Pesca', 'Puerto Boyacá', 'Quípama', 'Ramiriquí', 'Saboyá',
#        'Samacá', 'San Miguel de Sema', 'San Pablo de Borbur',
#        'Santa Rosa de Viterbo', 'Santa Sofía', 'Santana', 'Sativasur',
#        'Siachoque', 'Soatá', 'Socha', 'Sogamoso', 'Soracá', 'Sotaquirá',
#        'Susacón', 'Sutamarchán', 'Sáchica', 'Tasco', 'Tenza', 'Tibaná',
#        'Tibasosa', 'Tinjacá', 'Tipacoque', 'Toca', 'Togüí', 'Tunja',
#        'Turmequé', 'Tuta', 'Tópaga', 'Ventaquemada', 'Villa de Leyva',
#        'Viracachá', 'Zetaquira', 'Buenaventura', 'Aguadas', 'Anserma',
#        'Aranzazu', 'Belalcázar', 'Chinchiná', 'La Dorada', 'La Merced',
#        'Manizales', 'Manzanares', 'Marmato', 'Marquetalia', 'Neira',
#        'Norcasia', 'Palestina', 'Pensilvania', 'Pácora', 'Riosucio',
#        'Risaralda', 'Salamina', 'Samaná', 'Supía', 'Villamaría',
#        'Viterbo', 'Albania', 'Cartagena del Chairá', 'Curillo',
#        'El Doncello', 'Florencia', 'La Montañita', 'Milán', 'Morelia',
#        'Puerto Rico', 'San José del Fragua', 'San Vicente del Caguán',
#        'Solano', 'Solita', 'Cartagena de Indias', 'Aguazul',
#        'Hato Corozal', 'Maní', 'Monterrey', 'Orocué', 'Paz de Ariporo',
#        'Pore', 'Tauramena', 'Trinidad', 'Yopal', 'Balboa', 'Bolívar',
#        'Buenos Aires', 'Cajibío', 'Caldono', 'Caloto', 'Corinto',
#        'El Tambo', 'Inzá', 'Jambaló', 'La Sierra', 'La Vega',
#        'Mercaderes', 'Miranda', 'Padilla', 'Patía', 'Piendamó', 'Popayán',
#        'Puerto Tejada', 'Puracé', 'Rosas', 'Santander de Quilichao',
#        'Silvia', 'Sucre', 'Suárez', 'Timbiquí', 'Timbío', 'Totoró',
#        'Aguachica', 'Agustín Codazzi', 'Astrea', 'Becerril', 'Bosconia',
#        'Chimichagua', 'Chiriguaná', 'Curumaní', 'El Copey', 'El Paso',
#        'Gamarra', 'González', 'La Gloria', 'La Jagua de Ibirico',
#        'La Paz', 'Pailitas', 'Pelaya', 'Pueblo Bello', 'Río de Oro',
#        'San Alberto', 'San Diego', 'San Martín', 'Tamalameque',
#        'Valledupar', 'Acandí', 'Atrato', 'Bagadó', 'Bahía Solano',
#        'Bajo Baudó', 'Condoto', 'Cértegui', 'El Carmen de Atrato',
#        'Istmina', 'Lloró', 'Medio Baudó', 'Medio San Juan', 'Nuquí',
#        'Nóvita', 'Quibdó', 'Río Quito', 'Tadó', 'Unguía',
#        'Unión Panamericana', 'Agua de Dios', 'Albán', 'Anapoima',
#        'Anolaima', 'Apulo', 'Arbeláez', 'Beltrán', 'Bituima', 'Bojacá',
#        'Cabrera', 'Cachipay', 'Cajicá', 'Carmen de Carupa', 'Chaguaní',
#        'Chipaque', 'Choachí', 'Chocontá', 'Chía', 'Cogua', 'Cota',
#        'Cucunubá', 'El Colegio', 'El Rosal', 'Facatativá', 'Fosca',
#        'Funza', 'Fusagasugá', 'Fúquene', 'Gachancipá', 'Gachetá', 'Gama',
#        'Girardot', 'Guachetá', 'Guaduas', 'Guasca', 'Guataquí',
#        'Guatavita', 'Guayabetal', 'Junín', 'La Calera', 'La Mesa',
#        'La Palma', 'Lenguazaque', 'Madrid', 'Manta', 'Mosquera', 'Nariño',
#        'Nemocón', 'Nilo', 'Nimaima', 'Nocaima', 'Pacho', 'Pandi', 'Pasca',
#        'Puerto Salgar', 'Quebradanegra', 'Quetame', 'Ricaurte',
#        'San Antonio del Tequendama', 'San Bernardo', 'Sasaima',
#        'Sesquilé', 'Sibaté', 'Silvania', 'Simijaca', 'Soacha', 'Sopó',
#        'Subachoque', 'Suesca', 'Tabio', 'Tausa', 'Tena', 'Tenjo',
#        'Tocaima', 'Tocancipá', 'Ubalá', 'Ubaque', 'Une', 'Vergara',
#        'Vianí', 'Villapinzón', 'Villeta', 'Viotá', 'Yacopí', 'Zipacón',
#        'Zipaquirá', 'Útica', 'Inírida', 'San José del Guaviare',
#        'Acevedo', 'Agrado', 'Aipe', 'Algeciras', 'Altamira', 'Baraya',
#        'Campoalegre', 'Colombia', 'Elías', 'Garzón', 'Gigante', 'Hobo',
#        'Isnos', 'La Argentina', 'La Plata', 'Neiva', 'Nátaga', 'Oporapa',
#        'Paicol', 'Palermo', 'Pital', 'Pitalito', 'Rivera', 'Saladoblanco',
#        'San Agustín', 'Santa María', 'Suaza', 'Tarqui', 'Tello', 'Teruel',
#        'Timaná', 'Villavieja', 'Yaguará', 'Barrancas', 'Dibulla',
#        'Distracción', 'El Molino', 'Fonseca', 'Hatonuevo',
#        'La Jagua del Pilar', 'Maicao', 'Manaure', 'Riohacha',
#        'San Juan del Cesar', 'Uribia', 'Urumita', 'Algarrobo',
#        'Aracataca', 'Ariguaní', 'Chivolo', 'Ciénaga', 'El Banco',
#        'El Retén', 'Fundación', 'Guamal', 'Nueva Granada', 'Pedraza',
#        'Pijiño del Carmen', 'Pivijay', 'Plato', 'Puebloviejo', 'Remolino',
#        'San Sebastián de Buenavista', 'San Zenón', 'Santa Ana',
#        'Santa Bárbara de Pinto', 'Sitionuevo', 'Zapayán', 'Zona Bananera',
#        'Acacías', 'Cabuyaro', 'Castilla la Nueva', 'Cumaral',
#        'El Castillo', 'Fuente de Oro', 'Mapiripán', 'Mesetas',
#        'Puerto Gaitán', 'Puerto López', 'Restrepo',
#        'San Carlos de Guaroa', 'San Juan de Arama', 'Villavicencio',
#        'Aldana', 'Ancuyá', 'Arboleda', 'Barbacoas', 'Buesaco',
#        'Chachagüí', 'Colón', 'Contadero', 'Cumbal', 'Cumbitara',
#        'El Charco', 'El Peñol', 'Francisco Pizarro', 'Funes', 'Guachucal',
#        'Guaitarilla', 'Gualmatán', 'Iles', 'Imués', 'Ipiales', 'La Cruz',
#        'La Florida', 'La Llanada', 'La Tola', 'Leiva', 'Linares',
#        'Los Andes', 'Mallama', 'Olaya Herrera', 'Pasto', 'Potosí',
#        'Puerres', 'Pupiales', 'Roberto Payán', 'Samaniego',
#        'San Andrés de Tumaco', 'San Lorenzo', 'San Pedro de Cartago',
#        'Sandoná', 'Santacruz', 'Sapuyes', 'Taminango', 'Tangua',
#        'Túquerres', 'Yacuanquer', 'Arboledas', 'Bochalema', 'Bucarasica',
#        'Chinácota', 'Chitagá', 'Convención', 'Cucutilla', 'Cácota',
#        'Cúcuta', 'Durania', 'El Carmen', 'El Tarra', 'El Zulia',
#        'Gramalote', 'La Esperanza', 'La Playa', 'Labateca', 'Los Patios',
#        'Lourdes', 'Mutiscua', 'Ocaña', 'Pamplona', 'Pamplonita',
#        'Puerto Santander', 'Ragonvalia', 'San Calixto', 'San Cayetano',
#        'Santiago', 'Sardinata', 'Silos', 'Teorama', 'Tibú', 'Villa Caro',
#        'Villa del Rosario', 'Mocoa', 'Orito', 'Puerto Asís',
#        'Puerto Caicedo', 'Puerto Guzmán', 'San Miguel', 'Sibundoy',
#        'Valle del Guamuez', 'Villagarzón', 'Circasia', 'Filandia',
#        'Génova', 'La Tebaida', 'Montenegro', 'Quimbaya', 'Salento',
#        'Apía', 'Belén de Umbría', 'Dosquebradas', 'La Celia',
#        'La Virginia', 'Marsella', 'Pereira', 'Pueblo Rico', 'Quinchía',
#        'Santa Rosa de Cabal', 'Santuario', 'Santa Marta', 'Aguada',
#        'Aratoca', 'Barichara', 'Barrancabermeja', 'Bucaramanga',
#        'California', 'Carcasí', 'Cepitá', 'Chipatá', 'Cimitarra',
#        'Confines', 'Coromoro', 'Curití', 'El Carmen de Chucurí',
#        'El Guacamayo', 'El Playón', 'Floridablanca', 'Galán', 'Girón',
#        'Guaca', 'Guapotá', 'Guavatá', 'Hato', 'La Belleza', 'Landázuri',
#        'Lebrija', 'Los Santos', 'Matanza', 'Mogotes', 'Molagavita',
#        'Málaga', 'Oiba', 'Onzaga', 'Piedecuesta', 'Pinchote',
#        'Puerto Parra', 'Puerto Wilches', 'Páramo', 'Sabana de Torres',
#        'San Benito', 'San Gil', 'San Joaquín', 'San José de Miranda',
#        'San Vicente de Chucurí', 'Santa Helena del Opón', 'Socorro',
#        'Suaita', 'Tona', 'Valle de San José', 'Vetas', 'Vélez',
#        'Zapatoca', 'Caimito', 'Chalán', 'Coloso', 'Corozal', 'Coveñas',
#        'El Roble', 'Galeras', 'Guaranda', 'Los Palmitos', 'Majagual',
#        'Morroa', 'Ovejas', 'Palmito', 'Sampués', 'San Juan de Betulia',
#        'San Luis de Sincé', 'San Marcos', 'San Onofre', 'San Pedro',
#        'Santiago de Tolú', 'Sincelejo', 'Tolú Viejo', 'Alpujarra',
#        'Alvarado', 'Ambalema', 'Anzoátegui', 'Armero', 'Ataco',
#        'Cajamarca', 'Carmen de Apicalá', 'Casabianca', 'Chaparral',
#        'Coyaima', 'Dolores', 'Espinal', 'Flandes', 'Fresno', 'Guamo',
#        'Herveo', 'Honda', 'Ibagué', 'Icononzo', 'Lérida', 'Líbano',
#        'Melgar', 'Natagaima', 'Ortega', 'Palocabildo', 'Piedras',
#        'Planadas', 'Prado', 'Purificación', 'Rioblanco', 'Rovira',
#        'Saldaña', 'San Antonio', 'Valle de San Juan', 'Venadillo',
#        'Villarrica', 'Alcalá', 'Andalucía', 'Ansermanuevo',
#        'Bugalagrande', 'Caicedonia', 'Cali', 'Calima', 'Cartago', 'Dagua',
#        'El Cairo', 'El Cerrito', 'El Dovio', 'El Águila', 'Florida',
#        'Ginebra', 'Guacarí', 'Guadalajara de Buga', 'Jamundí',
#        'La Cumbre', 'La Victoria', 'Obando', 'Palmira', 'Pradera',
#        'Roldanillo', 'Sevilla', 'Toro', 'Trujillo', 'Tuluá', 'Ulloa',
#        'Versalles', 'Vijes', 'Yotoco', 'Yumbo', 'Zarzal', 'Mitú',
#        'Taraira', 'La Primavera', 'Puerto Carreño'], dtype=object)

# %%
Casos_a_Fecha = Tasas.groupby(['Dpto', 'Municipio'])[['Fecha de notificación', 'Fecha de muerte',
        'Fecha recuperado']].count().loc[[departamento, municipio]]

# %%
Cuadro_Tasas = pd.merge(Casos_a_Fecha, Col, left_index=True, right_index=True)

# %%
Cuadro_Tasas.rename({'Fecha de notificación':'Total casos', 
                     'Fecha de muerte':'Fallecidos', 
                     'Fecha recuperado': 'Recuperados', 
                     '2020': 'Población'}, axis = 'columns', inplace=True)

# %%
Cuadro_Tasas['Tasa de letalidad por 100 habitantes'] = (Cuadro_Tasas['Fallecidos']/Cuadro_Tasas['Total casos'])*100
Cuadro_Tasas['Tasa de mortalidad por 100.000 habitantes'] = (Cuadro_Tasas['Fallecidos']/Cuadro_Tasas['Población'])*100000
Cuadro_Tasas
# Out:
#                     Total casos  Fallecidos  Recuperados  Población  \
# Dpto   Municipio
# Caldas Risaralda              2           0            1      10568
#        Manzanares            19           1            7      17794
#        La Dorada            214           3          102      74006
#        Marquetalia            8           0            8      13490
#        Aranzazu               4           0            2      10556
#        Pensilvania            1           0            0      19755
#        Marmato               59           0           21       9167
#        Pácora                 3           0            1      15324
#        Manizales            763          11          246     446160
#        Belalcázar             6           0            0      10650
#        Riosucio              37           2           10      51956
#        Norcasia               1           1            0       6128
#        Aguadas               51           0            6      23048
#        La Merced              5           0            0       5882
#        Salamina               5           0            0      19393
#        Viterbo               12           1            3      12853
#        Villamaría            60           2           23      67429
#        Anserma               25           0           10      36691
#        Palestina              3           0            1      15681
#        Supía                 39           2            3      29363
#        Neira                 13           2            5      21114
#        Chinchiná             81           1           25      52267
#        Samaná                 5           0            2      19967
#
#                     Tasa de letalidad por 100 habitantes  \
# Dpto   Municipio
# Caldas Risaralda                                    0.00
#        Manzanares                                   5.26
#        La Dorada                                    1.40
#        Marquetalia                                  0.00
#        Aranzazu                                     0.00
#        Pensilvania                                  0.00
#        Marmato                                      0.00
#        Pácora                                       0.00
#        Manizales                                    1.44
#        Belalcázar                                   0.00
#        Riosucio                                     5.41
#        Norcasia                                   100.00
#        Aguadas                                      0.00
#        La Merced                                    0.00
#        Salamina                                     0.00
#        Viterbo                                      8.33
#        Villamaría                                   3.33
#        Anserma                                      0.00
#        Palestina                                    0.00
#        Supía                                        5.13
#        Neira                                       15.38
#        Chinchiná                                    1.23
#        Samaná                                       0.00
#
#                     Tasa de mortalidad por 100.000 habitantes
# Dpto   Municipio
# Caldas Risaralda                                         0.00
#        Manzanares                                        5.62
#        La Dorada                                         4.05
#        Marquetalia                                       0.00
#        Aranzazu                                          0.00
#        Pensilvania                                       0.00
#        Marmato                                           0.00
#        Pácora                                            0.00
#        Manizales                                         2.47
#        Belalcázar                                        0.00
#        Riosucio                                          3.85
#        Norcasia                                         16.32
#        Aguadas                                           0.00
#        La Merced                                         0.00
#        Salamina                                          0.00
#        Viterbo                                           7.78
#        Villamaría                                        2.97
#        Anserma                                           0.00
#        Palestina                                         0.00
#        Supía                                             6.81
#        Neira                                             9.47
#        Chinchiná                                         1.91
#        Samaná                                            0.00

# %% [markdown]
# #### Tasas de letalidad y de mortalidad por Departamento o Municipio

# %%
Cuadro_Tasas.sort_values(by=['Tasa de mortalidad por 100.000 habitantes'], inplace=True)
Cuadro_Tasas
# Out:
#                     Total casos  Fallecidos  Recuperados  Población  \
# Dpto   Municipio
# Caldas Risaralda              2           0            1      10568
#        Palestina              3           0            1      15681
#        Anserma               25           0           10      36691
#        Salamina               5           0            0      19393
#        La Merced              5           0            0       5882
#        Aguadas               51           0            6      23048
#        Belalcázar             6           0            0      10650
#        Samaná                 5           0            2      19967
#        Marmato               59           0           21       9167
#        Pensilvania            1           0            0      19755
#        Aranzazu               4           0            2      10556
#        Marquetalia            8           0            8      13490
#        Pácora                 3           0            1      15324
#        Chinchiná             81           1           25      52267
#        Manizales            763          11          246     446160
#        Villamaría            60           2           23      67429
#        Riosucio              37           2           10      51956
#        La Dorada            214           3          102      74006
#        Manzanares            19           1            7      17794
#        Supía                 39           2            3      29363
#        Viterbo               12           1            3      12853
#        Neira                 13           2            5      21114
#        Norcasia               1           1            0       6128
#
#                     Tasa de letalidad por 100 habitantes  \
# Dpto   Municipio
# Caldas Risaralda                                    0.00
#        Palestina                                    0.00
#        Anserma                                      0.00
#        Salamina                                     0.00
#        La Merced                                    0.00
#        Aguadas                                      0.00
#        Belalcázar                                   0.00
#        Samaná                                       0.00
#        Marmato                                      0.00
#        Pensilvania                                  0.00
#        Aranzazu                                     0.00
#        Marquetalia                                  0.00
#        Pácora                                       0.00
#        Chinchiná                                    1.23
#        Manizales                                    1.44
#        Villamaría                                   3.33
#        Riosucio                                     5.41
#        La Dorada                                    1.40
#        Manzanares                                   5.26
#        Supía                                        5.13
#        Viterbo                                      8.33
#        Neira                                       15.38
#        Norcasia                                   100.00
#
#                     Tasa de mortalidad por 100.000 habitantes
# Dpto   Municipio
# Caldas Risaralda                                         0.00
#        Palestina                                         0.00
#        Anserma                                           0.00
#        Salamina                                          0.00
#        La Merced                                         0.00
#        Aguadas                                           0.00
#        Belalcázar                                        0.00
#        Samaná                                            0.00
#        Marmato                                           0.00
#        Pensilvania                                       0.00
#        Aranzazu                                          0.00
#        Marquetalia                                       0.00
#        Pácora                                            0.00
#        Chinchiná                                         1.91
#        Manizales                                         2.47
#        Villamaría                                        2.97
#        Riosucio                                          3.85
#        La Dorada                                         4.05
#        Manzanares                                        5.62
#        Supía                                             6.81
#        Viterbo                                           7.78
#        Neira                                             9.47
#        Norcasia                                         16.32

# %%
Cuadro_Tasas.transpose().unstack()
# Out:
# Dpto    Municipio
# Caldas  Risaralda  Total casos                                      2.00
#                    Fallecidos                                       0.00
#                    Recuperados                                      1.00
#                    Población                                    10568.00
#                    Tasa de letalidad por 100 habitantes             0.00
#                                                                   ...
#         Norcasia   Fallecidos                                       1.00
#                    Recuperados                                      0.00
#                    Población                                     6128.00
#                    Tasa de letalidad por 100 habitantes           100.00
#                    Tasa de mortalidad por 100.000 habitantes       16.32
# Length: 138, dtype: float64

# %%
if departamento == '' and municipio== '':
    print('Debe ingresar mínimo el Departamento.  Inténtelo nuevamente')
    pass
else:
    if municipio == '':
        Total_casos = Cuadro_Tasas.loc[departamento, 'Total casos'].astype(int) 
        Fallecidos_dpto_munic = Cuadro_Tasas.loc[(departamento), 'Fallecidos'].astype(int)
        Poblacion_dpto_munic = Cuadro_Tasas.loc[(departamento), 'Población'].astype(int)
    
    else:
        Total_casos = Cuadro_Tasas.loc[(departamento, municipio), 'Total casos'].astype(int)
        Fallecidos_dpto_munic = Cuadro_Tasas.loc[(departamento, municipio), 'Fallecidos'].astype(int)
        Poblacion_dpto_munic = Cuadro_Tasas.loc[(departamento, municipio), 'Población'].astype(int)

# %%
#total_casos_covid_colombia

# %% [markdown]
# #### Fallecidos por municipio

# %%
Fallecidos_dpto_munic
# Out:
# 11

# %% [markdown]
# #### Población por municipio  (municipios afectados por CoV-2)

# %%
#Fallecidos_pais

# %%
Poblacion_dpto_munic
# Out:
# 446160

# %% [markdown]
# #### Total población en áreas afectadas del departamento o municipio

# %%
Poblacion_dpto_munic.sum()
# Out:
# 446160

# %% [markdown]
# #### Población Departamental o Municipal

# %%
poblacionDpto = Col.loc[(departamento),'2020'].sum()
poblacionDpto
# Out:
# 1018453

# %%
#Poblacion_pais

# %% [markdown]
# #### Casos por municipio

# %%
Total_casos
# Out:
# 763

# %% [markdown]
# #### Casos en el departamento

# %%
Total_casos_dpto = Total_casos.sum()

Total_casos_dpto
# Out:
# 763

# %% [markdown]
# #### Resumen situacional

# %%
hoy = pd.Timestamp.today()

# %%
filtro= Tasas[variable_buscar]== estado
if municipio == '':
    Cuadro_filtrados = Tasas.loc[filtro, 'Atención': 'Tipo recuperación'].loc[(Tasas['Dpto'] == departamento)]
    numero_estados= Cuadro_filtrados.loc[:, variable_buscar].count()
    print('Según datos reportados al ', hoy, ' por el INS Colombiano, de los ' + str(Total_casos_dpto)
          + ' casos de '+ departamento + ', ' + str(numero_estados) +' casos, es decir el '
          + str(((numero_estados/Total_casos_dpto)*100).round(2))+' %, está en condición: '
          + variable_buscar + ' ' + estado + ' y representan el ' 
          + str(((numero_estados/Col.loc[(departamento),'2020'].sum())*100).round(6)) 
          + ' %  de los '+ str(Col.loc[(departamento),'2020'].sum()) + ' habitantes de ' + departamento)
   
    print('La tasa de mortalidad en los municipios del Departamento de ' + departamento + ' por cien mil habitantes es: '
          + str(((Fallecidos_dpto_munic/poblacionDpto)*100000).round(2)))
    
    print('La tasa de letalidad en los municipios del Departamento de ' + departamento + 
          ' por cien enfermos de CoVid-19, es: ' + str(((Fallecidos_dpto_munic/Total_casos)*100).round(2)))

else:
    Cuadro_filtrados = Tasas.loc[filtro, 'Atención': 'Tipo recuperación'].loc[(Tasas['Dpto'] == departamento) & (Tasas['Municipio']== municipio)]
    numero_estados= Cuadro_filtrados.loc[:, variable_buscar].count()
    print('Según datos reportados al', hoy, 'por el INS Colombiano, de los ' + str(Total_casos) + ' casos de '+ municipio + ', ' 
          + str(numero_estados) +' casos, es decir el '+ str(((numero_estados/Total_casos)*100).round(2))
          +' %, están en '+ variable_buscar + ': ' + estado + ' y representan el '
          + str(((numero_estados/Poblacion_dpto_munic.sum())*100).round(6)) 
          + ' % de los ' + str(Poblacion_dpto_munic.sum()) + ' habitantes de ' + municipio +'.','\n')
    
    print('La tasa de letalidad en el municipio de '+ municipio + ',' + ' Departamento de ' 
          + departamento + ' es de ' + str(((Fallecidos_dpto_munic/Total_casos)*100).round(2)) 
          + ' por cien enfermos de CoVid-19.','\n')
    
    print('La tasa de mortalidad en el municipio de '+ municipio + ',' + ' Departamento de ' 
          + departamento + ' es de ' + str(((Fallecidos_dpto_munic/Poblacion_dpto_munic)*100000).round(2)) 
          + ' por cien mil habitantes.','\n')
    
print('La tasa de mortalidad de ' + pais+ ' por CoV-2 ' + 'es de ' + str(((Fallecidos_pais/Poblacion_pais)*1000000).round(1))+ ' por millón de habitantes.','\n')

print('La tasa de letalidad de '+pais+ ' por CoV-2 ' + 'es de ' + str(((Fallecidos_pais/total_casos_covid_colombia)*100).round(2))+ ' por cien enfermos de CoVid-19.','\n')
# Out:
# Según datos reportados al 2020-08-12 15:44:45.732201 por el INS Colombiano, de los 763 casos de Manizales, 9 casos, es decir el 1.18 %, están en Estado: Fallecido y representan el 0.002017 % de los 446160 habitantes de Manizales.
#
# La tasa de letalidad en el municipio de Manizales, Departamento de Caldas es de 1.44 por cien enfermos de CoVid-19.
#
# La tasa de mortalidad en el municipio de Manizales, Departamento de Caldas es de 2.47 por cien mil habitantes.
#
# La tasa de mortalidad de Colombia por CoV-2 es de 278.7 por millón de habitantes.
#
# La tasa de letalidad de Colombia por CoV-2 es de 3.46 por cien enfermos de CoVid-19.

# %%
Cuadro_Tasas.columns
# Out:
# Index(['Total casos', 'Fallecidos', 'Recuperados', 'Población',
#        'Tasa de letalidad por 100 habitantes',
#        'Tasa de mortalidad por 100.000 habitantes'],
#       dtype='object')

# %%
# %matplotlib inline

# %%
casos = Cuadro_Tasas['Total casos']

y = Cuadro_Tasas['Recuperados']

dev_x = casos
dev_y = y

plt.scatter(casos, dev_y, color= 'g', linestyle = '--', linewidth= 3, label='Recuperados')

y1= Cuadro_Tasas['Fallecidos']

plt.scatter(casos, y1, color ='k', linewidth=1, label= 'Fallecidos')


plt.title('Fallecidos con relación al número de casos')
plt.xlabel('Número de casos')
plt.ylabel('Total')
plt.legend()
#plt.grid(True)

plt.tight_layout()
#plt.savefig('figure.png')
plt.show()

# %%
cuadro_basico
# Out:
#                                         Fecha de notificación    Atención  \
# Dpto               Municipio
# Bogotá D.C.        Bogotá D.C.                     2020-03-02  Recuperado
# Valle del Cauca    Guadalajara de Buga             2020-03-06  Recuperado
# Antioquia          Medellín                        2020-03-07  Recuperado
#                    Medellín                        2020-03-09  Recuperado
#                    Medellín                        2020-03-09  Recuperado
# ...                                                       ...         ...
# Caquetá            Florencia                       2020-07-28        Casa
#                    Florencia                       2020-07-28        Casa
# Norte de Santander Cúcuta                          2020-07-27        Casa
# Santander          Girón                           2020-07-28        Casa
#                    El Carmen de Chucurí            2020-07-28        Casa
#
#                                          Edad Sexo         Tipo Estado  \
# Dpto               Municipio
# Bogotá D.C.        Bogotá D.C.             19    F    Importado   Leve
# Valle del Cauca    Guadalajara de Buga     34    M    Importado   Leve
# Antioquia          Medellín                50    F    Importado   Leve
#                    Medellín                55    M  Relacionado   Leve
#                    Medellín                25    M  Relacionado   Leve
# ...                                       ...  ...          ...    ...
# Caquetá            Florencia               34    M   En estudio   Leve
#                    Florencia                6    M   En estudio   Leve
# Norte de Santander Cúcuta                  61    M   En estudio   Leve
# Santander          Girón                   74    F   En estudio   Leve
#                    El Carmen de Chucurí    30    M   En estudio   Leve
#
#                                         País de procedencia Fecha de muerte  \
# Dpto               Municipio
# Bogotá D.C.        Bogotá D.C.                       ITALIA             NaT
# Valle del Cauca    Guadalajara de Buga               ESPAÑA             NaT
# Antioquia          Medellín                          ESPAÑA             NaT
#                    Medellín                             NaN             NaT
#                    Medellín                             NaN             NaT
# ...                                                     ...             ...
# Caquetá            Florencia                            NaN             NaT
#                    Florencia                            NaN             NaT
# Norte de Santander Cúcuta                               NaN             NaT
# Santander          Girón                                NaN             NaT
#                    El Carmen de Chucurí                 NaN             NaT
#
#                                         Fecha diagnóstico Fecha recuperado  \
# Dpto               Municipio
# Bogotá D.C.        Bogotá D.C.                 2020-03-06       2020-03-13
# Valle del Cauca    Guadalajara de Buga         2020-03-09       2020-03-19
# Antioquia          Medellín                    2020-03-09       2020-03-15
#                    Medellín                    2020-03-11       2020-03-26
#                    Medellín                    2020-03-11       2020-03-23
# ...                                                   ...              ...
# Caquetá            Florencia                   2020-08-08              NaT
#                    Florencia                   2020-08-08              NaT
# Norte de Santander Cúcuta                      2020-08-07              NaT
# Santander          Girón                       2020-08-08              NaT
#                    El Carmen de Chucurí        2020-08-08              NaT
#
#                                         Tipo recuperación
# Dpto               Municipio
# Bogotá D.C.        Bogotá D.C.                        PCR
# Valle del Cauca    Guadalajara de Buga                PCR
# Antioquia          Medellín                           PCR
#                    Medellín                           PCR
#                    Medellín                           PCR
# ...                                                   ...
# Caquetá            Florencia                          NaN
#                    Florencia                          NaN
# Norte de Santander Cúcuta                             NaN
# Santander          Girón                              NaN
#                    El Carmen de Chucurí               NaN
#
# [410453 rows x 11 columns]

# %%
cuadro_basico.columns
# Out:
# Index(['Fecha de notificación', 'Atención', 'Edad', 'Sexo', 'Tipo', 'Estado',
#        'País de procedencia', 'Fecha de muerte', 'Fecha diagnóstico',
#        'Fecha recuperado', 'Tipo recuperación'],
#       dtype='object')

# %%
cuadro_basico.index
# Out:
# MultiIndex([(        'Bogotá D.C.',          'Bogotá D.C.'),
#             (    'Valle del Cauca',  'Guadalajara de Buga'),
#             (          'Antioquia',             'Medellín'),
#             (          'Antioquia',             'Medellín'),
#             (          'Antioquia',             'Medellín'),
#             (          'Antioquia',               'Itagüí'),
#             ('Cartagena D.T. y C.',  'Cartagena de Indias'),
#             (        'Bogotá D.C.',          'Bogotá D.C.'),
#             (        'Bogotá D.C.',          'Bogotá D.C.'),
#             (        'Bogotá D.C.',          'Bogotá D.C.'),
#             ...
#             (            'Caquetá',            'Florencia'),
#             (            'Caquetá',            'Florencia'),
#             (            'Caquetá',            'Florencia'),
#             (            'Caquetá',            'Florencia'),
#             (            'Caquetá',            'Florencia'),
#             (            'Caquetá',            'Florencia'),
#             (            'Caquetá',            'Florencia'),
#             ( 'Norte de Santander',               'Cúcuta'),
#             (          'Santander',                'Girón'),
#             (          'Santander', 'El Carmen de Chucurí')],
#            names=['Dpto', 'Municipio'], length=410453)

# %%
cuadro_basico.sort_values(by= ['Fecha de notificación'], inplace=True)

# %%
x = cuadro_basico['Fecha de notificación']

y = cuadro_basico['Edad']

dev_x = x
dev_y = y

#plt.plot_date(dev_x, dev_y, color= 'g', linestyle = '--', linewidth= 3, label='Recuperados')
plt.scatter(dev_x, dev_y, color= 'g', label='Edad personas afectadas')

plt.gcf().autofmt_xdate()
#y1= Cuadro_Tasas['Fallecidos']

#plt.scatter(dev_x, y1, color ='k', linewidth=1, label= 'Fallecidos')


plt.title('Colombia COVID-19. Fuente:  INS')

plt.xlabel('Fechas')
plt.ylabel('Edad')
plt.legend()
#plt.grid(True)

plt.tight_layout()
#plt.savefig('figure.png')
plt.show()

# %%
Tasas.sort_values(by=['Fecha de notificación'], inplace=True)

# %%
Tasas
# Out:
#                        Dpto            Municipio Fecha de notificación  \
# 112755          Bogotá D.C.          Bogotá D.C.            2020-03-02
# 390783      Valle del Cauca  Guadalajara de Buga            2020-03-06
# 17982             Antioquia             Medellín            2020-03-07
# 265997  Cartagena D.T. y C.  Cartagena de Indias            2020-03-08
# 112757          Bogotá D.C.          Bogotá D.C.            2020-03-08
# ...                     ...                  ...                   ...
# 352147            Santander                Sucre            2020-08-10
# 78673             Atlántico              Soledad            2020-08-10
# 112630    Barranquilla D.E.         Barranquilla            2020-08-11
# 283386  Cartagena D.T. y C.  Cartagena de Indias            2020-08-11
# 13331             Antioquia           Copacabana            2020-08-11
#
#           Atención  Edad Sexo        Tipo Estado País de procedencia  \
# 112755  Recuperado    19    F   Importado   Leve              ITALIA
# 390783  Recuperado    34    M   Importado   Leve              ESPAÑA
# 17982   Recuperado    50    F   Importado   Leve              ESPAÑA
# 265997  Recuperado    85    F   Importado   Leve      ESTADOS UNIDOS
# 112757  Recuperado    28    F   Importado   Leve              ESPAÑA
# ...            ...   ...  ...         ...    ...                 ...
# 352147        Casa    73    F  En estudio   Leve                 NaN
# 78673         Casa    19    F  En estudio   Leve                 NaN
# 112630        Casa    44    M  En estudio   Leve                 NaN
# 283386        Casa    21    M  En estudio   Leve                 NaN
# 13331         Casa    37    M  En estudio   Leve                 NaN
#
#        Fecha de muerte Fecha diagnóstico Fecha recuperado Tipo recuperación  \
# 112755             NaT        2020-03-06       2020-03-13               PCR
# 390783             NaT        2020-03-09       2020-03-19               PCR
# 17982              NaT        2020-03-09       2020-03-15               PCR
# 265997             NaT        2020-03-11       2020-03-17               PCR
# 112757             NaT        2020-03-11       2020-03-23               PCR
# ...                ...               ...              ...               ...
# 352147             NaT        2020-08-10              NaT               NaN
# 78673              NaT        2020-08-11              NaT               NaN
# 112630             NaT        2020-08-10              NaT               NaN
# 283386             NaT        2020-08-10              NaT               NaN
# 13331              NaT        2020-08-11              NaT               NaN
#
#            2020
# 112755  7743955
# 390783   128945
# 17982   2533424
# 265997  1028736
# 112757  7743955
# ...         ...
# 352147     7064
# 78673    665021
# 112630  1274250
# 283386  1028736
# 13331     81820
#
# [394344 rows x 14 columns]

# %%
type(Tasas.loc[0,'Fecha de muerte'])
# Out:
# pandas._libs.tslibs.nattype.NaTType

# %%
fallecidos = []
acumulados = []

# %%
Tasas['Fecha de notificación'].size
# Out:
# 394344

# %%
x = Tasas['Fecha de notificación'].size
for i in range(0, x):
    if pd.isnull(Tasas.loc[i, 'Fecha de muerte']):
        fallecidos.append(0)
        if i == x:
            break
        else:
            acumulados.append(0)

    else:
        fallecidos.append(1)
        if i == x:
            break
        else:
            acumulados.append(0)

# %%
Tasas['Fallecidos'] = fallecidos

# %%
Tasas['Fallecidos_acumulados'] = acumulados

# %%
Tasas
# Out:
#                        Dpto            Municipio Fecha de notificación  \
# 112755          Bogotá D.C.          Bogotá D.C.            2020-03-02
# 390783      Valle del Cauca  Guadalajara de Buga            2020-03-06
# 17982             Antioquia             Medellín            2020-03-07
# 265997  Cartagena D.T. y C.  Cartagena de Indias            2020-03-08
# 112757          Bogotá D.C.          Bogotá D.C.            2020-03-08
# ...                     ...                  ...                   ...
# 352147            Santander                Sucre            2020-08-10
# 78673             Atlántico              Soledad            2020-08-10
# 112630    Barranquilla D.E.         Barranquilla            2020-08-11
# 283386  Cartagena D.T. y C.  Cartagena de Indias            2020-08-11
# 13331             Antioquia           Copacabana            2020-08-11
#
#           Atención  Edad Sexo        Tipo Estado País de procedencia  \
# 112755  Recuperado    19    F   Importado   Leve              ITALIA
# 390783  Recuperado    34    M   Importado   Leve              ESPAÑA
# 17982   Recuperado    50    F   Importado   Leve              ESPAÑA
# 265997  Recuperado    85    F   Importado   Leve      ESTADOS UNIDOS
# 112757  Recuperado    28    F   Importado   Leve              ESPAÑA
# ...            ...   ...  ...         ...    ...                 ...
# 352147        Casa    73    F  En estudio   Leve                 NaN
# 78673         Casa    19    F  En estudio   Leve                 NaN
# 112630        Casa    44    M  En estudio   Leve                 NaN
# 283386        Casa    21    M  En estudio   Leve                 NaN
# 13331         Casa    37    M  En estudio   Leve                 NaN
#
#        Fecha de muerte Fecha diagnóstico Fecha recuperado Tipo recuperación  \
# 112755             NaT        2020-03-06       2020-03-13               PCR
# 390783             NaT        2020-03-09       2020-03-19               PCR
# 17982              NaT        2020-03-09       2020-03-15               PCR
# 265997             NaT        2020-03-11       2020-03-17               PCR
# 112757             NaT        2020-03-11       2020-03-23               PCR
# ...                ...               ...              ...               ...
# 352147             NaT        2020-08-10              NaT               NaN
# 78673              NaT        2020-08-11              NaT               NaN
# 112630             NaT        2020-08-10              NaT               NaN
# 283386             NaT        2020-08-10              NaT               NaN
# 13331              NaT        2020-08-11              NaT               NaN
#
#            2020  Fallecidos  Fallecidos_acumulados
# 112755  7743955           0                      0
# 390783   128945           0                      0
# 17982   2533424           0                      0
# 265997  1028736           0                      0
# 112757  7743955           0                      0
# ...         ...         ...                    ...
# 352147     7064           0                      0
# 78673    665021           0                      0
# 112630  1274250           0                      0
# 283386  1028736           0                      0
# 13331     81820           0                      0
#
# [394344 rows x 16 columns]

# %%
for i in range(1, Tasas['Fallecidos'].size):
    Tasas.loc[i, 'Fallecidos_acumulados'] = (Tasas.loc[i-1,'Fallecidos_acumulados'] + Tasas.loc[i, 'Fallecidos'])

# %%
Tasas.loc[394343,'Fallecidos_acumulados']
# Out:
# 13141

# %%
Tasas
# Out:
#                        Dpto            Municipio Fecha de notificación  \
# 112755          Bogotá D.C.          Bogotá D.C.            2020-03-02
# 390783      Valle del Cauca  Guadalajara de Buga            2020-03-06
# 17982             Antioquia             Medellín            2020-03-07
# 265997  Cartagena D.T. y C.  Cartagena de Indias            2020-03-08
# 112757          Bogotá D.C.          Bogotá D.C.            2020-03-08
# ...                     ...                  ...                   ...
# 352147            Santander                Sucre            2020-08-10
# 78673             Atlántico              Soledad            2020-08-10
# 112630    Barranquilla D.E.         Barranquilla            2020-08-11
# 283386  Cartagena D.T. y C.  Cartagena de Indias            2020-08-11
# 13331             Antioquia           Copacabana            2020-08-11
#
#           Atención  Edad Sexo        Tipo Estado País de procedencia  \
# 112755  Recuperado    19    F   Importado   Leve              ITALIA
# 390783  Recuperado    34    M   Importado   Leve              ESPAÑA
# 17982   Recuperado    50    F   Importado   Leve              ESPAÑA
# 265997  Recuperado    85    F   Importado   Leve      ESTADOS UNIDOS
# 112757  Recuperado    28    F   Importado   Leve              ESPAÑA
# ...            ...   ...  ...         ...    ...                 ...
# 352147        Casa    73    F  En estudio   Leve                 NaN
# 78673         Casa    19    F  En estudio   Leve                 NaN
# 112630        Casa    44    M  En estudio   Leve                 NaN
# 283386        Casa    21    M  En estudio   Leve                 NaN
# 13331         Casa    37    M  En estudio   Leve                 NaN
#
#        Fecha de muerte Fecha diagnóstico Fecha recuperado Tipo recuperación  \
# 112755             NaT        2020-03-06       2020-03-13               PCR
# 390783             NaT        2020-03-09       2020-03-19               PCR
# 17982              NaT        2020-03-09       2020-03-15               PCR
# 265997             NaT        2020-03-11       2020-03-17               PCR
# 112757             NaT        2020-03-11       2020-03-23               PCR
# ...                ...               ...              ...               ...
# 352147             NaT        2020-08-10              NaT               NaN
# 78673              NaT        2020-08-11              NaT               NaN
# 112630             NaT        2020-08-10              NaT               NaN
# 283386             NaT        2020-08-10              NaT               NaN
# 13331              NaT        2020-08-11              NaT               NaN
#
#            2020  Fallecidos  Fallecidos_acumulados
# 112755  7743955           0                   3838
# 390783   128945           0                  13003
# 17982   2533424           0                    569
# 265997  1028736           0                   9001
# 112757  7743955           0                   3838
# ...         ...         ...                    ...
# 352147     7064           0                  11683
# 78673    665021           0                   2614
# 112630  1274250           0                   3834
# 283386  1028736           0                   9545
# 13331     81820           0                    424
#
# [394344 rows x 16 columns]

# %%
len(acumulados)
# Out:
# 394344

# %%
len(fallecidos)
# Out:
# 394344

# %%
Tasas.columns
# Out:
# Index(['Dpto', 'Municipio', 'Fecha de notificación', 'Atención', 'Edad',
#        'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'Fecha de muerte',
#        'Fecha diagnóstico', 'Fecha recuperado', 'Tipo recuperación', '2020',
#        'Fallecidos', 'Fallecidos_acumulados'],
#       dtype='object')

# %%
Tasas['Fallecidos'].sum()
# Out:
# 13141
