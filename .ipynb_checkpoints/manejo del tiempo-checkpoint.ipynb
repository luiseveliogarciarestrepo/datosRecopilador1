# %%
import pandas as pd

# %%
#d_parser = lambda x:pd.datetime.strptime(x, '%Y-%m-%d')
df = pd.read_csv('CovidColombia.csv', 
                 parse_dates= ['Fecha de notificación','Fecha diagnostico', 'FIS', 'Fecha de muerte',
                              'Fecha recuperado','fecha reporte web'],
                low_memory=False)

# %%
df
# Out:
#        ID de caso Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0               1            2020-03-02            11001          Bogotá D.C.
# 1               2            2020-03-06            76111  Guadalajara de Buga
# 2               3            2020-03-07             5001             Medellín
# 3               4            2020-03-09             5001             Medellín
# 4               5            2020-03-09             5001             Medellín
# ...           ...                   ...              ...                  ...
# 73567       73608            2020-06-20             8758              Soledad
# 73568       73609            2020-06-20             8758              Soledad
# 73569       73610            2020-06-20             8758              Soledad
# 73570       73611            2020-06-20             8001         Barranquilla
# 73571       73612            2020-06-20             8001         Barranquilla
#
# ...

# %%
df.shape
# Out:
# (73572, 21)

# %%
df.loc[0, 'Fecha de notificación'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-698024867634> in <module>
# ----> 1 df.loc[0, 'Fecha de notificación'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Fecha de notificación'] = pd.to_datetime(df['Fecha de notificación'])

# %%
df
# Out:
#        ID de caso Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0               1            2020-03-02            11001          Bogotá D.C.
# 1               2            2020-03-06            76111  Guadalajara de Buga
# 2               3            2020-03-07             5001             Medellín
# 3               4            2020-03-09             5001             Medellín
# 4               5            2020-03-09             5001             Medellín
# ...           ...                   ...              ...                  ...
# 73567       73608            2020-06-20             8758              Soledad
# 73568       73609            2020-06-20             8758              Soledad
# 73569       73610            2020-06-20             8758              Soledad
# 73570       73611            2020-06-20             8001         Barranquilla
# 73571       73612            2020-06-20             8001         Barranquilla
#
# ...

# %%
df['Fecha de notificación']
# Out:
# 0       2020-03-02
# 1       2020-03-06
# 2       2020-03-07
# 3       2020-03-09
# 4       2020-03-09
#            ...
# 73567   2020-06-20
# 73568   2020-06-20
# 73569   2020-06-20
# 73570   2020-06-20
# 73571   2020-06-20
# Name: Fecha de notificación, Length: 73572, dtype: datetime64[ns]

# %%
df.loc[0, 'Fecha de notificación'].day_name()
# Out:
# 'Monday'

# %%
df['Fecha de notificación'].dt.day_name()
# Out:
# 0          Monday
# 1          Friday
# 2        Saturday
# 3          Monday
# 4          Monday
#            ...
# 73567    Saturday
# 73568    Saturday
# 73569    Saturday
# 73570    Saturday
# 73571    Saturday
# Name: Fecha de notificación, Length: 73572, dtype: object

# %%
df['Día de la semana']= df['Fecha de notificación'].dt.day_name()

# %%
df
# Out:
#        ID de caso Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0               1            2020-03-02            11001          Bogotá D.C.
# 1               2            2020-03-06            76111  Guadalajara de Buga
# 2               3            2020-03-07             5001             Medellín
# 3               4            2020-03-09             5001             Medellín
# 4               5            2020-03-09             5001             Medellín
# ...           ...                   ...              ...                  ...
# 73567       73608            2020-06-20             8758              Soledad
# 73568       73609            2020-06-20             8758              Soledad
# 73569       73610            2020-06-20             8758              Soledad
# 73570       73611            2020-06-20             8001         Barranquilla
# 73571       73612            2020-06-20             8001         Barranquilla
#
# ...

# %%
df['Fecha de notificación'].min()
# Out:
# Timestamp('2020-03-02 00:00:00')

# %%
df['Fecha de notificación'].max()
# Out:
# Timestamp('2020-06-23 00:00:00')

# %%
df['Fecha de notificación'].max() - df['Fecha de notificación'].min()
# Out:
# Timedelta('113 days 00:00:00')

# %%
filt = (df['Fecha de notificación'] >= '2020-04-04') & (df['Fecha de notificación'] <= '2020-04-04')
df.loc[filt]
# Out:
#        ID de caso Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 1312         1313            2020-04-04            25754               Soacha
# 1387         1388            2020-04-04            11001          Bogotá D.C.
# 1410         1411            2020-04-04             5001             Medellín
# 1411         1412            2020-04-04             5266             Envigado
# 1413         1414            2020-04-04             5360               Itagüí
# ...           ...                   ...              ...                  ...
# 6147         6188            2020-04-04            11001          Bogotá D.C.
# 6461         6502            2020-04-04            11001          Bogotá D.C.
# 10158       10199            2020-04-04            13001  Cartagena de Indias
# 10369       10410            2020-04-04            11001          Bogotá D.C.
# 23839       23880            2020-04-04            11001          Bogotá D.C.
#
# ...

# %%
df.set_index('Fecha de notificación', inplace=True)

# %%
df
# Out:
#                        ID de caso  Código DIVIPOLA  Ciudad de ubicación  \
# Fecha de notificación
# 2020-03-02                      1            11001          Bogotá D.C.
# 2020-03-06                      2            76111  Guadalajara de Buga
# 2020-03-07                      3             5001             Medellín
# 2020-03-09                      4             5001             Medellín
# 2020-03-09                      5             5001             Medellín
# ...                           ...              ...                  ...
# 2020-06-20                  73608             8758              Soledad
# 2020-06-20                  73609             8758              Soledad
# 2020-06-20                  73610             8758              Soledad
# 2020-06-20                  73611             8001         Barranquilla
# 2020-06-20                  73612             8001         Barranquilla
#
#                       Departamento o Distrito     atención  Edad Sexo  \
# ...

# %%
df['2020-06-20']
# Out:
#                        ID de caso  Código DIVIPOLA Ciudad de ubicación  \
# Fecha de notificación
# 2020-06-20                  64156            25473            Mosquera
# 2020-06-20                  64268            27600           Río Quito
# 2020-06-20                  64429             5790              Tarazá
# 2020-06-20                  64431             5790              Tarazá
# 2020-06-20                  64433             5120             Cáceres
# ...                           ...              ...                 ...
# 2020-06-20                  73608             8758             Soledad
# 2020-06-20                  73609             8758             Soledad
# 2020-06-20                  73610             8758             Soledad
# 2020-06-20                  73611             8001        Barranquilla
# 2020-06-20                  73612             8001        Barranquilla
#
#                       Departamento o Distrito  atención  Edad Sexo  \
# ...

# %%
df['2020-06-19':'2020-06-20']
# Out:
#                        ID de caso  Código DIVIPOLA Ciudad de ubicación  \
# Fecha de notificación
# 2020-06-19                  59419             5001            Medellín
# 2020-06-19                  62102            44430              Maicao
# 2020-06-19                  62236            68001         Bucaramanga
# 2020-06-19                  63318            47001         Santa Marta
# 2020-06-19                  63319            52320         Guaitarilla
# ...                           ...              ...                 ...
# 2020-06-20                  73608             8758             Soledad
# 2020-06-20                  73609             8758             Soledad
# 2020-06-20                  73610             8758             Soledad
# 2020-06-20                  73611             8001        Barranquilla
# 2020-06-20                  73612             8001        Barranquilla
#
#                       Departamento o Distrito  atención  Edad Sexo  \
# ...

# %%
df['2020-06-19':'2020-06-20']['Edad'].min()
# Out:
# 0

# %%
df['2020-06-19']['Edad'].max()
# Out:
# 90

# %%
df['Edad'].resample('d').max()
# Out:
# Fecha de notificación
# 2020-03-02    19.0
# 2020-03-03     NaN
# 2020-03-04     NaN
# 2020-03-05     NaN
# 2020-03-06    34.0
#               ...
# 2020-06-19    90.0
# 2020-06-20    87.0
# 2020-06-21    89.0
# 2020-06-22    91.0
# 2020-06-23    10.0
# Freq: D, Name: Edad, Length: 114, dtype: float64

# %%
mayores = df['Edad'].resample('W').max()
mayores['2020-06-07']
# Out:
# 102

# %%
# %matplotlib inline

# %%
mayores.plot()

# %%
df
# Out:
#                        ID de caso  Código DIVIPOLA  Ciudad de ubicación  \
# Fecha de notificación
# 2020-03-02                      1            11001          Bogotá D.C.
# 2020-03-06                      2            76111  Guadalajara de Buga
# 2020-03-07                      3             5001             Medellín
# 2020-03-09                      4             5001             Medellín
# 2020-03-09                      5             5001             Medellín
# ...                           ...              ...                  ...
# 2020-06-20                  73608             8758              Soledad
# 2020-06-20                  73609             8758              Soledad
# 2020-06-20                  73610             8758              Soledad
# 2020-06-20                  73611             8001         Barranquilla
# 2020-06-20                  73612             8001         Barranquilla
#
#                       Departamento o Distrito     atención  Edad Sexo  \
# ...

# %%
df.resample('W').mean()
# Out:
#                          ID de caso  Código DIVIPOLA       Edad  \
# Fecha de notificación
# 2020-03-08                 4.400000     23223.000000  43.200000
# 2020-03-15               183.320513     29341.000000  40.423077
# 2020-03-22               948.829384     30041.983412  42.372038
# 2020-03-29              1928.874510     27549.588235  42.347059
# 2020-04-05              2638.664987     27630.019312  44.371117
# 2020-04-12              4682.780220     29891.557692  41.716117
# 2020-04-19              7162.108165     31807.226099  39.681786
# 2020-04-26              7382.612568     34419.287978  38.681967
# 2020-05-03              9288.069767     34004.006223  38.435637
# 2020-05-10             13721.868399     32231.984530  38.249381
# 2020-05-17             20261.728794     29654.559973  38.035785
# 2020-05-24             26205.002222     26724.531868  38.971465
# 2020-05-31             34652.647539     23921.689045  38.757428
# ...

# %%
df
# Out:
#                        ID de caso  Código DIVIPOLA  Ciudad de ubicación  \
# Fecha de notificación
# 2020-03-02                      1            11001          Bogotá D.C.
# 2020-03-06                      2            76111  Guadalajara de Buga
# 2020-03-07                      3             5001             Medellín
# 2020-03-09                      4             5001             Medellín
# 2020-03-09                      5             5001             Medellín
# ...                           ...              ...                  ...
# 2020-06-20                  73608             8758              Soledad
# 2020-06-20                  73609             8758              Soledad
# 2020-06-20                  73610             8758              Soledad
# 2020-06-20                  73611             8001         Barranquilla
# 2020-06-20                  73612             8001         Barranquilla
#
#                       Departamento o Distrito     atención  Edad Sexo  \
# ...

# %%
df.resample('M').agg({'Edad':'mean', 'Codigo departamento':'max', 'Codigo pais':'min'})
# Out:
#                             Edad  Codigo departamento  Codigo pais
# Fecha de notificación
# 2020-03-31             42.675393                   88         32.0
# 2020-04-30             40.091751                   91         32.0
# 2020-05-31             38.546571                   99         32.0
# 2020-06-30             39.297173                   97        218.0

# %%
filtro = df['Ciudad de ubicación'] == 'Manizales'
manizales_df = df.loc[filtro]
manizales_df.head()
# Out:
#      ID de caso Fecha de notificación  Código DIVIPOLA Ciudad de ubicación  \
# 30           31            2020-03-12            17001           Manizales
# 180         181            2020-03-18            17001           Manizales
# 371         372            2020-03-21            17001           Manizales
# 452         453            2020-03-25            17001           Manizales
# 538         539            2020-03-24            17001           Manizales
#
#     Departamento o Distrito     atención  Edad Sexo        Tipo Estado  ...  \
# 30                    Caldas  Recuperado    65    M   Importado   Leve  ...
# 180                   Caldas  Recuperado    22    F   Importado   Leve  ...
# 371                   Caldas  Recuperado    70    M   Importado   Leve  ...
# 452                   Caldas  Recuperado    26    F   Importado   Leve  ...
# 538                   Caldas  Recuperado    81    M  En estudio   Leve  ...
#
# ...

# %%
manizales_df.to_csv('mzles.csv')

# %%
manizales_df.to_csv('mzles.tsv', sep='\t')

# %%
manizales_df.to_excel('mzles.xlsx')

# %%
test = pd.read_excel('mzles.xlsx', index_col= 'ID de caso')

# %%
test.head()
# Out:
#             Unnamed: 0 Fecha de notificación  Código DIVIPOLA  \
# ID de caso
# 31                  30            2020-03-12            17001
# 181                180            2020-03-18            17001
# 372                371            2020-03-21            17001
# 453                452            2020-03-25            17001
# 539                538            2020-03-24            17001
#
#            Ciudad de ubicación Departamento o Distrito    atención  Edad Sexo  \
# ID de caso
# 31                   Manizales                  Caldas  Recuperado    65    M
# 181                  Manizales                  Caldas  Recuperado    22    F
# 372                  Manizales                  Caldas  Recuperado    70    M
# 453                  Manizales                  Caldas  Recuperado    26    F
# 539                  Manizales                  Caldas  Recuperado    81    M
#
#                   Tipo Estado  ...                      FIS Fecha de muerte  \
# ...
