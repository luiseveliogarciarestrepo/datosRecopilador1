# %%
import pandas as pd

# %%
df = pd.read_csv('CovidColombia.csv', index_col= 'Ciudad de ubicación', low_memory= False)

# %%
df['Ciudad de ubicación'].head()
# Out:
# 0            Bogotá D.C.
# 1    Guadalajara de Buga
# 2               Medellín
# 3               Medellín
# 4               Medellín
# Name: Ciudad de ubicación, dtype: object

# %%
df.sort_index()
# Out:
#                      ID de caso    Fecha de notificación  Código DIVIPOLA  \
# Ciudad de ubicación
# Acacías                    5936  2020-04-25T00:00:00.000            50006
# Acacías                   93586  2020-06-24T00:00:00.000            50006
# Acacías                   93585  2020-06-24T00:00:00.000            50006
# Acacías                   71250  2020-06-12T00:00:00.000            50006
# Acacías                    5968  2020-04-25T00:00:00.000            50006
# ...                         ...                      ...              ...
# Zona Bananera             90307  2020-06-22T00:00:00.000            47980
# Zona Bananera              6244  2020-04-25T00:00:00.000            47980
# Zona Bananera             62190  2020-06-18T00:00:00.000            47980
# Zona Bananera             13712  2020-05-13T00:00:00.000            47980
# Ábrego                     7057  2020-04-26T00:00:00.000            54003
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102009 entries, 0 to 102008
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID de caso                102009 non-null  int64
#  1   Fecha de notificación     102009 non-null  object
#  2   Código DIVIPOLA           102009 non-null  int64
#  3   Ciudad de ubicación       102009 non-null  object
#  4   Departamento o Distrito   102009 non-null  object
#  5   atención                  101830 non-null  object
#  6   Edad                      102009 non-null  int64
#  7   Sexo                      102009 non-null  object
#  8   Tipo                      102009 non-null  object
#  9   Estado                    101828 non-null  object
#  10  País de procedencia       934 non-null     object
#  11  FIS                       102009 non-null  object
#  12  Fecha de muerte           3420 non-null    object
# ...

# %%
df
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 0                1  2020-03-02T00:00:00.000            11001
# 1                2  2020-03-06T00:00:00.000            76111
# 2                3  2020-03-07T00:00:00.000             5001
# 3                4  2020-03-09T00:00:00.000             5001
# 4                5  2020-03-09T00:00:00.000             5001
# ...            ...                      ...              ...
# 102004      102045  2020-06-23T00:00:00.000            11001
# 102005      102046  2020-06-24T00:00:00.000            11001
# 102006      102047  2020-06-26T00:00:00.000            11001
# 102007      102048  2020-06-29T00:00:00.000            11001
# 102008      102049  2020-06-29T00:00:00.000            11001
#
#         Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0               Bogotá D.C.              Bogotá D.C.  Recuperado    19    F
# 1       Guadalajara de Buga          Valle del Cauca  Recuperado    34    M
# ...

# %%
df.tail(10)
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 101999      102040  2020-06-17T00:00:00.000            11001
# 102000      102041  2020-06-17T00:00:00.000            11001
# 102001      102042  2020-06-17T00:00:00.000            11001
# 102002      102043  2020-06-19T00:00:00.000            11001
# 102003      102044  2020-06-21T00:00:00.000            11001
# 102004      102045  2020-06-23T00:00:00.000            11001
# 102005      102046  2020-06-24T00:00:00.000            11001
# 102006      102047  2020-06-26T00:00:00.000            11001
# 102007      102048  2020-06-29T00:00:00.000            11001
# 102008      102049  2020-06-29T00:00:00.000            11001
#
#        Ciudad de ubicación Departamento o Distrito  atención  Edad Sexo  \
# 101999         Bogotá D.C.              Bogotá D.C.     Casa    27    M
# 102000         Bogotá D.C.              Bogotá D.C.     Casa    34    M
# 102001         Bogotá D.C.              Bogotá D.C.     Casa    40    M
# ...

# %%
df.loc['Ciudad de ubicación'] == 'Manizales'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Ciudad de ubicación'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-a9c1bc199b86> in <module>
# ----> 1 df.loc['Ciudad de ubicación'] == 'Manizales'
#
# ...

# %%
df
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 0                1  2020-03-02T00:00:00.000            11001
# 1                2  2020-03-06T00:00:00.000            76111
# 2                3  2020-03-07T00:00:00.000             5001
# 3                4  2020-03-09T00:00:00.000             5001
# 4                5  2020-03-09T00:00:00.000             5001
# ...            ...                      ...              ...
# 102004      102045  2020-06-23T00:00:00.000            11001
# 102005      102046  2020-06-24T00:00:00.000            11001
# 102006      102047  2020-06-26T00:00:00.000            11001
# 102007      102048  2020-06-29T00:00:00.000            11001
# 102008      102049  2020-06-29T00:00:00.000            11001
#
#         Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0               Bogotá D.C.              Bogotá D.C.  Recuperado    19    F
# 1       Guadalajara de Buga          Valle del Cauca  Recuperado    34    M
# ...

# %%
df1= df[['Fecha de notificación', 'Ciudad de ubicación', 'Edad', 'Estado', 'Fecha diagnostico', 'Fecha recuperado', 'fecha reporte web']].head()

# %%
df1
# Out:
#      Fecha de notificación  Ciudad de ubicación  Edad Estado  \
# 0  2020-03-02T00:00:00.000          Bogotá D.C.    19   Leve
# 1  2020-03-06T00:00:00.000  Guadalajara de Buga    34   Leve
# 2  2020-03-07T00:00:00.000             Medellín    50   Leve
# 3  2020-03-09T00:00:00.000             Medellín    55   Leve
# 4  2020-03-09T00:00:00.000             Medellín    25   Leve
#
#          Fecha diagnostico         Fecha recuperado        fecha reporte web
# 0  2020-03-06T00:00:00.000  2020-03-13T00:00:00.000  2020-03-06T00:00:00.000
# 1  2020-03-09T00:00:00.000  2020-03-19T00:00:00.000  2020-03-09T00:00:00.000
# 2  2020-03-09T00:00:00.000  2020-03-15T00:00:00.000  2020-03-09T00:00:00.000
# 3  2020-03-11T00:00:00.000  2020-03-26T00:00:00.000  2020-03-11T00:00:00.000
# 4  2020-03-11T00:00:00.000  2020-03-23T00:00:00.000  2020-03-11T00:00:00.000

# %%
df1.iloc[[0,4], 1]
# Out:
# 0    Bogotá D.C.
# 4       Medellín
# Name: Ciudad de ubicación, dtype: object

# %%
a = df1.loc[[0,4], 'Ciudad de ubicación']
print(a)
# Out:
# 0    Bogotá D.C.
# 4       Medellín
# Name: Ciudad de ubicación, dtype: object

# %%
b= df1.loc[0:4, ['Ciudad de ubicación', 'Estado', 'Edad']]
print(b)
# Out:
#    Ciudad de ubicación Estado  Edad
# 0          Bogotá D.C.   Leve    19
# 1  Guadalajara de Buga   Leve    34
# 2             Medellín   Leve    50
# 3             Medellín   Leve    55
# 4             Medellín   Leve    25

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#      Fecha de notificación  Ciudad de ubicación  Edad Estado  \
# 0  2020-03-02T00:00:00.000          Bogotá D.C.    19   Leve
# 1  2020-03-06T00:00:00.000  Guadalajara de Buga    34   Leve
# 2  2020-03-07T00:00:00.000             Medellín    50   Leve
# 3  2020-03-09T00:00:00.000             Medellín    55   Leve
# 4  2020-03-09T00:00:00.000             Medellín    25   Leve
#
#          Fecha diagnostico         Fecha recuperado        fecha reporte web
# 0  2020-03-06T00:00:00.000  2020-03-13T00:00:00.000  2020-03-06T00:00:00.000
# 1  2020-03-09T00:00:00.000  2020-03-19T00:00:00.000  2020-03-09T00:00:00.000
# 2  2020-03-09T00:00:00.000  2020-03-15T00:00:00.000  2020-03-09T00:00:00.000
# 3  2020-03-11T00:00:00.000  2020-03-26T00:00:00.000  2020-03-11T00:00:00.000
# 4  2020-03-11T00:00:00.000  2020-03-23T00:00:00.000  2020-03-11T00:00:00.000

# %%
df1.loc[0:3, ['Fecha de notificación', 'fecha reporte web','Estado']]
# Out:
#      Fecha de notificación        fecha reporte web Estado
# 0  2020-03-02T00:00:00.000  2020-03-06T00:00:00.000   Leve
# 1  2020-03-06T00:00:00.000  2020-03-09T00:00:00.000   Leve
# 2  2020-03-07T00:00:00.000  2020-03-09T00:00:00.000   Leve
# 3  2020-03-09T00:00:00.000  2020-03-11T00:00:00.000   Leve

# %%
df.head()
# Out:
#    ID de caso    Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001          Bogotá D.C.
# 1           2  2020-03-06T00:00:00.000            76111  Guadalajara de Buga
# 2           3  2020-03-07T00:00:00.000             5001             Medellín
# 3           4  2020-03-09T00:00:00.000             5001             Medellín
# 4           5  2020-03-09T00:00:00.000             5001             Medellín
#
#   Departamento o Distrito     atención  Edad Sexo         Tipo Estado  ...  \
# 0              Bogotá D.C.  Recuperado    19    F    Importado   Leve  ...
# 1          Valle del Cauca  Recuperado    34    M    Importado   Leve  ...
# 2                Antioquia  Recuperado    50    F    Importado   Leve  ...
# 3                Antioquia  Recuperado    55    M  Relacionado   Leve  ...
# 4                Antioquia  Recuperado    25    M  Relacionado   Leve  ...
#
# ...

# %%
df.shape
# Out:
# (102009, 21)

# %%
df.tail()
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 102004      102045  2020-06-23T00:00:00.000            11001
# 102005      102046  2020-06-24T00:00:00.000            11001
# 102006      102047  2020-06-26T00:00:00.000            11001
# 102007      102048  2020-06-29T00:00:00.000            11001
# 102008      102049  2020-06-29T00:00:00.000            11001
#
#        Ciudad de ubicación Departamento o Distrito  atención  Edad Sexo  \
# 102004         Bogotá D.C.              Bogotá D.C.     Casa    60    M
# 102005         Bogotá D.C.              Bogotá D.C.     Casa    41    F
# 102006         Bogotá D.C.              Bogotá D.C.     Casa    41    M
# 102007         Bogotá D.C.              Bogotá D.C.     Casa    30    M
# 102008         Bogotá D.C.              Bogotá D.C.     Casa    57    M
#
#               Tipo        Estado  ...                      FIS  \
# 102004  En estudio          Leve  ...  2020-06-23T00:00:00.000
# ...

# %%
df.head()
# Out:
#    ID de caso    Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001          Bogotá D.C.
# 1           2  2020-03-06T00:00:00.000            76111  Guadalajara de Buga
# 2           3  2020-03-07T00:00:00.000             5001             Medellín
# 3           4  2020-03-09T00:00:00.000             5001             Medellín
# 4           5  2020-03-09T00:00:00.000             5001             Medellín
#
#   Departamento o Distrito     atención  Edad Sexo         Tipo Estado  ...  \
# 0              Bogotá D.C.  Recuperado    19    F    Importado   Leve  ...
# 1          Valle del Cauca  Recuperado    34    M    Importado   Leve  ...
# 2                Antioquia  Recuperado    50    F    Importado   Leve  ...
# 3                Antioquia  Recuperado    55    M  Relacionado   Leve  ...
# 4                Antioquia  Recuperado    25    M  Relacionado   Leve  ...
#
# ...

# %%
df.head(10)
# Out:
#    ID de caso    Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001          Bogotá D.C.
# 1           2  2020-03-06T00:00:00.000            76111  Guadalajara de Buga
# 2           3  2020-03-07T00:00:00.000             5001             Medellín
# 3           4  2020-03-09T00:00:00.000             5001             Medellín
# 4           5  2020-03-09T00:00:00.000             5001             Medellín
# 5           6  2020-03-10T00:00:00.000             5360               Itagüí
# 6           7  2020-03-08T00:00:00.000            13001  Cartagena de Indias
# 7           8  2020-03-09T00:00:00.000            11001          Bogotá D.C.
# 8           9  2020-03-08T00:00:00.000            11001          Bogotá D.C.
# 9          10  2020-03-12T00:00:00.000            11001          Bogotá D.C.
#
#   Departamento o Distrito     atención  Edad Sexo         Tipo Estado  ...  \
# ...

# %%
df.iloc[:5, [3,2,1]]
# Out:
#    Ciudad de ubicación  Código DIVIPOLA    Fecha de notificación
# 0          Bogotá D.C.            11001  2020-03-02T00:00:00.000
# 1  Guadalajara de Buga            76111  2020-03-06T00:00:00.000
# 2             Medellín             5001  2020-03-07T00:00:00.000
# 3             Medellín             5001  2020-03-09T00:00:00.000
# 4             Medellín             5001  2020-03-09T00:00:00.000

# %%
df.loc[:5, ['Código DIVIPOLA', 'Sexo', 'Edad']]
# Out:
#    Código DIVIPOLA Sexo  Edad
# 0            11001    F    19
# 1            76111    M    34
# 2             5001    F    50
# 3             5001    M    55
# 4             5001    M    25
# 5             5360    F    27

# %%
df
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 0                1  2020-03-02T00:00:00.000            11001
# 1                2  2020-03-06T00:00:00.000            76111
# 2                3  2020-03-07T00:00:00.000             5001
# 3                4  2020-03-09T00:00:00.000             5001
# 4                5  2020-03-09T00:00:00.000             5001
# ...            ...                      ...              ...
# 102004      102045  2020-06-23T00:00:00.000            11001
# 102005      102046  2020-06-24T00:00:00.000            11001
# 102006      102047  2020-06-26T00:00:00.000            11001
# 102007      102048  2020-06-29T00:00:00.000            11001
# 102008      102049  2020-06-29T00:00:00.000            11001
#
#         Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0               Bogotá D.C.              Bogotá D.C.  Recuperado    19    F
# 1       Guadalajara de Buga          Valle del Cauca  Recuperado    34    M
# ...

# %%
df.loc[900:915, 'Fecha de notificación': 'Edad']
# Out:
#        Fecha de notificación  Código DIVIPOLA Ciudad de ubicación  \
# 900  2020-03-27T00:00:00.000            11001         Bogotá D.C.
# 901  2020-03-27T00:00:00.000            11001         Bogotá D.C.
# 902  2020-03-26T00:00:00.000            11001         Bogotá D.C.
# 903  2020-03-26T00:00:00.000            11001         Bogotá D.C.
# 904  2020-03-27T00:00:00.000            11001         Bogotá D.C.
# 905  2020-03-26T00:00:00.000            11001         Bogotá D.C.
# 906  2020-03-31T00:00:00.000            63470          Montenegro
# 907  2020-03-31T00:00:00.000            63470          Montenegro
# 908  2020-03-29T00:00:00.000             5088               Bello
# 909  2020-03-27T00:00:00.000             5266            Envigado
# 910  2020-03-30T00:00:00.000             5088               Bello
# 911  2020-03-27T00:00:00.000             5001            Medellín
# 912  2020-03-31T00:00:00.000             5266            Envigado
# ...

# %%
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 5)

# %%
df
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 0                1  2020-03-02T00:00:00.000            11001
# 1                2  2020-03-06T00:00:00.000            76111
# ...            ...                      ...              ...
# 102007      102048  2020-06-29T00:00:00.000            11001
# 102008      102049  2020-06-29T00:00:00.000            11001
#
#         Ciudad de ubicación Departamento o Distrito   ... Tipo recuperación  \
# 0               Bogotá D.C.              Bogotá D.C.  ...               PCR
# 1       Guadalajara de Buga          Valle del Cauca  ...               PCR
# ...                     ...                      ...  ...               ...
# 102007          Bogotá D.C.              Bogotá D.C.  ...               NaN
# 102008          Bogotá D.C.              Bogotá D.C.  ...               NaN
#
#         Codigo departamento Codigo pais Pertenencia etnica Nombre grupo etnico
# ...

# %%
df.columns
# Out:
# Index(['ID de caso', 'Fecha de notificación', 'Código DIVIPOLA',
#        'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
#        'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'FIS',
#        'Fecha de muerte', 'Fecha diagnostico', 'Fecha recuperado',
#        'fecha reporte web', 'Tipo recuperación', 'Codigo departamento',
#        'Codigo pais', 'Pertenencia etnica', 'Nombre grupo etnico'],
#       dtype='object')

# %%
df
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 0                1  2020-03-02T00:00:00.000            11001
# 1                2  2020-03-06T00:00:00.000            76111
# ...            ...                      ...              ...
# 102007      102048  2020-06-29T00:00:00.000            11001
# 102008      102049  2020-06-29T00:00:00.000            11001
#
#         Ciudad de ubicación Departamento o Distrito   ... Tipo recuperación  \
# 0               Bogotá D.C.              Bogotá D.C.  ...               PCR
# 1       Guadalajara de Buga          Valle del Cauca  ...               PCR
# ...                     ...                      ...  ...               ...
# 102007          Bogotá D.C.              Bogotá D.C.  ...               NaN
# 102008          Bogotá D.C.              Bogotá D.C.  ...               NaN
#
#         Codigo departamento Codigo pais Pertenencia etnica Nombre grupo etnico
# ...

# %%
pd.set_option('display.max_columns',6)

# %%
pd.set_option('display.max_rows', 15)

# %%
df
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  ... Codigo pais  \
# 0                1  2020-03-02T00:00:00.000            11001  ...       380.0
# 1                2  2020-03-06T00:00:00.000            76111  ...       724.0
# 2                3  2020-03-07T00:00:00.000             5001  ...       724.0
# 3                4  2020-03-09T00:00:00.000             5001  ...         NaN
# 4                5  2020-03-09T00:00:00.000             5001  ...         NaN
# ...            ...                      ...              ...  ...         ...
# 102004      102045  2020-06-23T00:00:00.000            11001  ...         NaN
# 102005      102046  2020-06-24T00:00:00.000            11001  ...         NaN
# 102006      102047  2020-06-26T00:00:00.000            11001  ...         NaN
# 102007      102048  2020-06-29T00:00:00.000            11001  ...         NaN
# 102008      102049  2020-06-29T00:00:00.000            11001  ...         NaN
#
# ...

# %%
df.shape
# Out:
# (102009, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102009 entries, 0 to 102008
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID de caso                102009 non-null  int64
#  1   Fecha de notificación     102009 non-null  object
#  2   Código DIVIPOLA           102009 non-null  int64
#  3   Ciudad de ubicación       102009 non-null  object
#  4   Departamento o Distrito   102009 non-null  object
#  5   atención                  101830 non-null  object
#  6   Edad                      102009 non-null  int64
#  7   Sexo                      102009 non-null  object
#  8   Tipo                      102009 non-null  object
#  9   Estado                    101828 non-null  object
#  10  País de procedencia       934 non-null     object
#  11  FIS                       102009 non-null  object
#  12  Fecha de muerte           3420 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['ID de caso', 'Fecha de notificación', 'Código DIVIPOLA',
#        'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
#        'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'FIS',
#        'Fecha de muerte', 'Fecha diagnostico', 'Fecha recuperado',
#        'fecha reporte web', 'Tipo recuperación', 'Codigo departamento',
#        'Codigo pais', 'Pertenencia etnica', 'Nombre grupo etnico'],
#       dtype='object')

# %%
df.loc[100:110, 'Fecha diagnostico':'Codigo pais' ].tail()
# Out:
#            Fecha diagnostico         Fecha recuperado  \
# 106  2020-03-19T00:00:00.000  2020-03-30T00:00:00.000
# 107  2020-03-19T00:00:00.000  2020-03-28T00:00:00.000
# 108  2020-03-19T00:00:00.000  2020-03-30T00:00:00.000
# 109  2020-03-19T00:00:00.000  2020-04-12T00:00:00.000
# 110  2020-03-19T00:00:00.000  2020-05-24T00:00:00.000
#
#            fecha reporte web Tipo recuperación  Codigo departamento  \
# 106  2020-03-19T00:00:00.000               PCR                    5
# 107  2020-03-19T00:00:00.000               PCR                    5
# 108  2020-03-19T00:00:00.000               PCR                   11
# 109  2020-03-19T00:00:00.000               PCR                   11
# 110  2020-03-19T00:00:00.000               PCR                   11
#
#      Codigo pais
# 106        724.0
# 107        724.0
# 108        724.0
# 109        840.0
# 110          NaN

# %%
df.loc[[200, 300, 400], ['Ciudad de ubicación', 'Edad', 'Sexo']]
# Out:
#     Ciudad de ubicación  Edad Sexo
# 200                Chía    50    F
# 300            Apartadó    29    F
# 400         Bogotá D.C.    30    F

# %%
# Out:
# (102009, 21)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ciudad de ubicación'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  ... Codigo pais  \
# 0                1  2020-03-02T00:00:00.000            11001  ...       380.0
# 1                2  2020-03-06T00:00:00.000            76111  ...       724.0
# 2                3  2020-03-07T00:00:00.000             5001  ...       724.0
# 3                4  2020-03-09T00:00:00.000             5001  ...         NaN
# 4                5  2020-03-09T00:00:00.000             5001  ...         NaN
# ...            ...                      ...              ...  ...         ...
# 102004      102045  2020-06-23T00:00:00.000            11001  ...         NaN
# 102005      102046  2020-06-24T00:00:00.000            11001  ...         NaN
# 102006      102047  2020-06-26T00:00:00.000            11001  ...         NaN
# 102007      102048  2020-06-29T00:00:00.000            11001  ...         NaN
# 102008      102049  2020-06-29T00:00:00.000            11001  ...         NaN
#
# ...

# %%
pd.set_option('display.max_columns', 21)
pd.set_option('display.max_rows', 40)

# %%
df
# Out:
#         ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 0                1  2020-03-02T00:00:00.000            11001
# 1                2  2020-03-06T00:00:00.000            76111
# 2                3  2020-03-07T00:00:00.000             5001
# 3                4  2020-03-09T00:00:00.000             5001
# 4                5  2020-03-09T00:00:00.000             5001
# ...            ...                      ...              ...
# 102004      102045  2020-06-23T00:00:00.000            11001
# 102005      102046  2020-06-24T00:00:00.000            11001
# 102006      102047  2020-06-26T00:00:00.000            11001
# 102007      102048  2020-06-29T00:00:00.000            11001
# 102008      102049  2020-06-29T00:00:00.000            11001
#
#         Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0               Bogotá D.C.              Bogotá D.C.  Recuperado    19    F
# 1       Guadalajara de Buga          Valle del Cauca  Recuperado    34    M
# ...

# %%
df.set_index('Fecha de notificación', inplace = True)

# %%
df.index
# Out:
# Index(['2020-03-02T00:00:00.000', '2020-03-06T00:00:00.000',
#        '2020-03-07T00:00:00.000', '2020-03-09T00:00:00.000',
#        '2020-03-09T00:00:00.000', '2020-03-10T00:00:00.000',
#        '2020-03-08T00:00:00.000', '2020-03-09T00:00:00.000',
#        '2020-03-08T00:00:00.000', '2020-03-12T00:00:00.000',
#        ...
#        '2020-06-17T00:00:00.000', '2020-06-17T00:00:00.000',
#        '2020-06-17T00:00:00.000', '2020-06-19T00:00:00.000',
#        '2020-06-21T00:00:00.000', '2020-06-23T00:00:00.000',
#        '2020-06-24T00:00:00.000', '2020-06-26T00:00:00.000',
#        '2020-06-29T00:00:00.000', '2020-06-29T00:00:00.000'],
#       dtype='object', name='Fecha de notificación', length=102009)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#           Fecha de notificación  ID de caso  Código DIVIPOLA  \
# 0       2020-03-02T00:00:00.000           1            11001
# 1       2020-03-06T00:00:00.000           2            76111
# 2       2020-03-07T00:00:00.000           3             5001
# 3       2020-03-09T00:00:00.000           4             5001
# 4       2020-03-09T00:00:00.000           5             5001
# ...                         ...         ...              ...
# 102004  2020-06-23T00:00:00.000      102045            11001
# 102005  2020-06-24T00:00:00.000      102046            11001
# 102006  2020-06-26T00:00:00.000      102047            11001
# 102007  2020-06-29T00:00:00.000      102048            11001
# 102008  2020-06-29T00:00:00.000      102049            11001
#
#         Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0               Bogotá D.C.              Bogotá D.C.  Recuperado    19    F
# 1       Guadalajara de Buga          Valle del Cauca  Recuperado    34    M
# ...

# %%
df.set_index('Departamento o Distrito')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-ef9585acf7e4> in <module>
# ----> 1 df.set_index('Departamento o Distrito')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Departamento o Distrito'] are in the columns"

# %%
df.columns
# Out:
# Index(['Fecha de notificación', 'ID de caso', 'Código DIVIPOLA',
#        'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
#        'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'FIS',
#        'Fecha de muerte', 'Fecha diagnostico', 'Fecha recuperado',
#        'fecha reporte web', 'Tipo recuperación', 'Codigo departamento',
#        'Codigo pais', 'Pertenencia etnica', 'Nombre grupo etnico'],
#       dtype='object')

# %%
df.set_index('Departamento o Distrito ')
# Out:
#                             Fecha de notificación  ID de caso  \
# Departamento o Distrito
# Bogotá D.C.               2020-03-02T00:00:00.000           1
# Valle del Cauca           2020-03-06T00:00:00.000           2
# Antioquia                 2020-03-07T00:00:00.000           3
# Antioquia                 2020-03-09T00:00:00.000           4
# Antioquia                 2020-03-09T00:00:00.000           5
# ...                                           ...         ...
# Bogotá D.C.               2020-06-23T00:00:00.000      102045
# Bogotá D.C.               2020-06-24T00:00:00.000      102046
# Bogotá D.C.               2020-06-26T00:00:00.000      102047
# Bogotá D.C.               2020-06-29T00:00:00.000      102048
# Bogotá D.C.               2020-06-29T00:00:00.000      102049
#
#                           Código DIVIPOLA  Ciudad de ubicación    atención  \
# Departamento o Distrito
# Bogotá D.C.                         11001          Bogotá D.C.  Recuperado
# ...

# %%
df
# Out:
#           Fecha de notificación  ID de caso  Código DIVIPOLA  \
# 0       2020-03-02T00:00:00.000           1            11001
# 1       2020-03-06T00:00:00.000           2            76111
# 2       2020-03-07T00:00:00.000           3             5001
# 3       2020-03-09T00:00:00.000           4             5001
# 4       2020-03-09T00:00:00.000           5             5001
# ...                         ...         ...              ...
# 102004  2020-06-23T00:00:00.000      102045            11001
# 102005  2020-06-24T00:00:00.000      102046            11001
# 102006  2020-06-26T00:00:00.000      102047            11001
# 102007  2020-06-29T00:00:00.000      102048            11001
# 102008  2020-06-29T00:00:00.000      102049            11001
#
#         Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0               Bogotá D.C.              Bogotá D.C.  Recuperado    19    F
# 1       Guadalajara de Buga          Valle del Cauca  Recuperado    34    M
# ...

# %%
df.head(
)
# Out:
#                      ID de caso    Fecha de notificación  Código DIVIPOLA  \
# Ciudad de ubicación
# Bogotá D.C.                   1  2020-03-02T00:00:00.000            11001
# Guadalajara de Buga           2  2020-03-06T00:00:00.000            76111
# Medellín                      3  2020-03-07T00:00:00.000             5001
# Medellín                      4  2020-03-09T00:00:00.000             5001
# Medellín                      5  2020-03-09T00:00:00.000             5001
#
#                     Departamento o Distrito     atención  Edad Sexo  \
# Ciudad de ubicación
# Bogotá D.C.                      Bogotá D.C.  Recuperado    19    F
# Guadalajara de Buga          Valle del Cauca  Recuperado    34    M
# Medellín                           Antioquia  Recuperado    50    F
# Medellín                           Antioquia  Recuperado    55    M
# Medellín                           Antioquia  Recuperado    25    M
#
#                             Tipo Estado País de procedencia  \
# ...

# %%
df.reset_index(inplace= True)

# %%
df
# Out:
#         Ciudad de ubicación  ID de caso    Fecha de notificación  \
# 0               Bogotá D.C.           1  2020-03-02T00:00:00.000
# 1       Guadalajara de Buga           2  2020-03-06T00:00:00.000
# 2                  Medellín           3  2020-03-07T00:00:00.000
# 3                  Medellín           4  2020-03-09T00:00:00.000
# 4                  Medellín           5  2020-03-09T00:00:00.000
# ...                     ...         ...                      ...
# 102004          Bogotá D.C.      102045  2020-06-23T00:00:00.000
# 102005          Bogotá D.C.      102046  2020-06-24T00:00:00.000
# 102006          Bogotá D.C.      102047  2020-06-26T00:00:00.000
# 102007          Bogotá D.C.      102048  2020-06-29T00:00:00.000
# 102008          Bogotá D.C.      102049  2020-06-29T00:00:00.000
#
#         Código DIVIPOLA Departamento o Distrito     atención  Edad Sexo  \
# 0                 11001              Bogotá D.C.  Recuperado    19    F
# ...

# %%
filtro = (df['Departamento o Distrito '] == 'Antioquia') & (df['Ciudad de ubicación'] == 'Caldas') & (df['Sexo']== 'F')

# %%
df[filtro]
# Out:
#        Ciudad de ubicación  ID de caso    Fecha de notificación  \
# 1495                Caldas        1496  2020-04-03T00:00:00.000
# 37915               Caldas       37956  2020-05-29T00:00:00.000
# 53837               Caldas       53878  2020-06-09T00:00:00.000
# 67504               Caldas       67545  2020-06-16T00:00:00.000
# 73700               Caldas       73741  2020-06-22T00:00:00.000
# 78042               Caldas       78083  2020-06-23T00:00:00.000
# 78550               Caldas       78591  2020-06-24T00:00:00.000
# 79060               Caldas       79101  2020-06-16T00:00:00.000
# 91452               Caldas       91493  2020-06-23T00:00:00.000
# 100309              Caldas      100350  2020-06-23T00:00:00.000
# 100310              Caldas      100351  2020-06-23T00:00:00.000
#
#         Código DIVIPOLA Departamento o Distrito     atención  Edad Sexo  \
# 1495               5129                Antioquia  Recuperado    33    F
# ...

# %%
df.loc[filtro, ['Departamento o Distrito ','Edad', 'Sexo', 'Estado']]
# Out:
#        Departamento o Distrito   Edad Sexo        Estado
# 1495                  Antioquia    33    F  Asintomático
# 37915                 Antioquia    39    F          Leve
# 53837                 Antioquia    23    F          Leve
# 67504                 Antioquia    36    F          Leve
# 73700                 Antioquia    58    F          Leve
# 78042                 Antioquia    34    F          Leve
# 78550                 Antioquia    32    F          Leve
# 79060                 Antioquia    24    F          Leve
# 91452                 Antioquia    48    F          Leve
# 100309                Antioquia    39    F          Leve
# 100310                Antioquia    36    F          Leve
